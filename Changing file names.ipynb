# %%
#CHANGING NAMES OF AUGMENTED, RESIZED, NORMLIZED FILES TO ORDER WELL (BIRD AND UAV)

# %%
import os

# Dosyaların bulunduğu klasörün yolu
folder_path = 'C:/Users/edana/Desktop/dataset_new/Bird_and_UAV/augmented_images'

# Dosya isimlerini değiştirmek için başlangıç numarası
start_number = 1
end_number = 20

# Klasördeki tüm dosyaları al
files = os.listdir(folder_path)

# Sadece dosya olanları al (klasörleri hariç tut)
files = [f for f in files if os.path.isfile(os.path.join(folder_path, f))]

# Dosyaları sıralı olarak yeniden isimlendirme işlemi
for i, file_name in enumerate(files):
    if i < end_number:
        # Dosyanın uzantısını al
        file_extension = os.path.splitext(file_name)[1]
        # Yeni dosya adını oluştur
        new_name = f"{start_number + i}{file_extension}"
        # Eski ve yeni dosya yollarını oluştur
        old_file_path = os.path.join(folder_path, file_name)
        new_file_path = os.path.join(folder_path, new_name)
        # Dosya ismini değiştir
        os.rename(old_file_path, new_file_path)
        print(f"'{file_name}' dosyası '{new_name}' olarak değiştirildi.")
    else:
        break

print("Dosya isimlendirme işlemi tamamlandı.")
# Out:
# '1549371e-drone2-99.jpg' dosyası '1.jpg' olarak değiştirildi.
# '25a0aca6-drone-avcisi.jpg' dosyası '2.jpg' olarak değiştirildi.
# '2b98a0b8-1389024_f33bb478af9f04e59404ba274aa09dcb_640x640.jpg' dosyası '3.jpg' olarak değiştirildi.
# '34cd1409-1.webp' dosyası '4.webp' olarak değiştirildi.
# '48e58072-kartal-drone.jpg' dosyası '5.jpg' olarak değiştirildi.
# '5661908b-bir-kusun-ucan-drone-a-saldirdigi-anlari-gosteren-video-1632665154.jpg' dosyası '6.jpg' olarak değiştirildi.
# '649c4118-1389024_b9293acc226a5239f59cc91bf7914b15_640x640.jpg' dosyası '7.jpg' olarak değiştirildi.
# '6a253148-589e4556e50aa90ef48b0741.webp' dosyası '8.webp' olarak değiştirildi.
# '6e7a4217-07eaa856-b021-4307-82a5-6bf9179512d6_tv_w408_r1.jpg' dosyası '9.jpg' olarak değiştirildi.
# '8bcea290-6df067c152e0a24c8d76fa0aa20bb12f3a9c6c0f.jpeg' dosyası '10.jpeg' olarak değiştirildi.
# '927f6bcc-1389024_d2457ac3cf3966e0e2ce5a40494e6b5c_640x640.jpg' dosyası '11.jpg' olarak değiştirildi.
# '9e12c047-KUSLAR.webp' dosyası '12.webp' olarak değiştirildi.
# 'c961e753-michigan-da-kartal-drone-dusurdu.jpeg' dosyası '13.jpeg' olarak değiştirildi.
# 'cbd7af45-56e490ac67b0a931607da223.webp' dosyası '14.webp' olarak değiştirildi.
# 'd5bcd6b2-6a51e736877992ec472fa04b99267392499d0a73_1.jpeg' dosyası '15.jpeg' olarak değiştirildi.
# 'dddb1546-1389024_66ebc55b6df5c925b72c5a179e1dbf12_640x640.jpg' dosyası '16.jpg' olarak değiştirildi.
# 'fc6074ba-589e455661361f0b14f19fd3.webp' dosyası '17.webp' olarak değiştirildi.
# 'ff93d03a-64884.webp' dosyası '18.webp' olarak değiştirildi.
# Dosya isimlendirme işlemi tamamlandı.

# %%
import os

# Dosyaların bulunduğu klasörün yolu
folder_path = 'C:/Users/edana/Desktop/dataset_new/Bird_and_UAV/normalized_images'

# Dosya isimlerini değiştirmek için başlangıç numarası
start_number = 19
end_number = 40

# Klasördeki tüm dosyaları al
files = os.listdir(folder_path)

# Sadece dosya olanları al (klasörleri hariç tut)
files = [f for f in files if os.path.isfile(os.path.join(folder_path, f))]

# Dosyaları sıralı olarak yeniden isimlendirme işlemi
for i, file_name in enumerate(files):
    if i < end_number:
        # Dosyanın uzantısını al
        file_extension = os.path.splitext(file_name)[1]
        # Yeni dosya adını oluştur
        new_name = f"{start_number + i}{file_extension}"
        # Eski ve yeni dosya yollarını oluştur
        old_file_path = os.path.join(folder_path, file_name)
        new_file_path = os.path.join(folder_path, new_name)
        # Dosya ismini değiştir
        os.rename(old_file_path, new_file_path)
        print(f"'{file_name}' dosyası '{new_name}' olarak değiştirildi.")
    else:
        break

print("Dosya isimlendirme işlemi tamamlandı.")
# Out:
# '1549371e-drone2-99.jpg' dosyası '19.jpg' olarak değiştirildi.
# '25a0aca6-drone-avcisi.jpg' dosyası '20.jpg' olarak değiştirildi.
# '2b98a0b8-1389024_f33bb478af9f04e59404ba274aa09dcb_640x640.jpg' dosyası '21.jpg' olarak değiştirildi.
# '34cd1409-1.webp' dosyası '22.webp' olarak değiştirildi.
# '48e58072-kartal-drone.jpg' dosyası '23.jpg' olarak değiştirildi.
# '5661908b-bir-kusun-ucan-drone-a-saldirdigi-anlari-gosteren-video-1632665154.jpg' dosyası '24.jpg' olarak değiştirildi.
# '649c4118-1389024_b9293acc226a5239f59cc91bf7914b15_640x640.jpg' dosyası '25.jpg' olarak değiştirildi.
# '6a253148-589e4556e50aa90ef48b0741.webp' dosyası '26.webp' olarak değiştirildi.
# '6e7a4217-07eaa856-b021-4307-82a5-6bf9179512d6_tv_w408_r1.jpg' dosyası '27.jpg' olarak değiştirildi.
# '8bcea290-6df067c152e0a24c8d76fa0aa20bb12f3a9c6c0f.jpeg' dosyası '28.jpeg' olarak değiştirildi.
# '927f6bcc-1389024_d2457ac3cf3966e0e2ce5a40494e6b5c_640x640.jpg' dosyası '29.jpg' olarak değiştirildi.
# '9e12c047-KUSLAR.webp' dosyası '30.webp' olarak değiştirildi.
# 'c961e753-michigan-da-kartal-drone-dusurdu.jpeg' dosyası '31.jpeg' olarak değiştirildi.
# 'cbd7af45-56e490ac67b0a931607da223.webp' dosyası '32.webp' olarak değiştirildi.
# 'd5bcd6b2-6a51e736877992ec472fa04b99267392499d0a73_1.jpeg' dosyası '33.jpeg' olarak değiştirildi.
# 'dddb1546-1389024_66ebc55b6df5c925b72c5a179e1dbf12_640x640.jpg' dosyası '34.jpg' olarak değiştirildi.
# 'fc6074ba-589e455661361f0b14f19fd3.webp' dosyası '35.webp' olarak değiştirildi.
# 'ff93d03a-64884.webp' dosyası '36.webp' olarak değiştirildi.
# Dosya isimlendirme işlemi tamamlandı.

# %%
import os

# Dosyaların bulunduğu klasörün yolu
folder_path = 'C:/Users/edana/Desktop/dataset_new/Bird_and_UAV/resized_images'

# Dosya isimlerini değiştirmek için başlangıç numarası
start_number = 37
end_number = 60

# Klasördeki tüm dosyaları al
files = os.listdir(folder_path)

# Sadece dosya olanları al (klasörleri hariç tut)
files = [f for f in files if os.path.isfile(os.path.join(folder_path, f))]

# Dosyaları sıralı olarak yeniden isimlendirme işlemi
for i, file_name in enumerate(files):
    if i < end_number:
        # Dosyanın uzantısını al
        file_extension = os.path.splitext(file_name)[1]
        # Yeni dosya adını oluştur
        new_name = f"{start_number + i}{file_extension}"
        # Eski ve yeni dosya yollarını oluştur
        old_file_path = os.path.join(folder_path, file_name)
        new_file_path = os.path.join(folder_path, new_name)
        # Dosya ismini değiştir
        os.rename(old_file_path, new_file_path)
        print(f"'{file_name}' dosyası '{new_name}' olarak değiştirildi.")
    else:
        break

print("Dosya isimlendirme işlemi tamamlandı.")
# Out:
# '1549371e-drone2-99.jpg' dosyası '37.jpg' olarak değiştirildi.
# '25a0aca6-drone-avcisi.jpg' dosyası '38.jpg' olarak değiştirildi.
# '2b98a0b8-1389024_f33bb478af9f04e59404ba274aa09dcb_640x640.jpg' dosyası '39.jpg' olarak değiştirildi.
# '34cd1409-1.webp' dosyası '40.webp' olarak değiştirildi.
# '48e58072-kartal-drone.jpg' dosyası '41.jpg' olarak değiştirildi.
# '5661908b-bir-kusun-ucan-drone-a-saldirdigi-anlari-gosteren-video-1632665154.jpg' dosyası '42.jpg' olarak değiştirildi.
# '649c4118-1389024_b9293acc226a5239f59cc91bf7914b15_640x640.jpg' dosyası '43.jpg' olarak değiştirildi.
# '6a253148-589e4556e50aa90ef48b0741.webp' dosyası '44.webp' olarak değiştirildi.
# '6e7a4217-07eaa856-b021-4307-82a5-6bf9179512d6_tv_w408_r1.jpg' dosyası '45.jpg' olarak değiştirildi.
# '8bcea290-6df067c152e0a24c8d76fa0aa20bb12f3a9c6c0f.jpeg' dosyası '46.jpeg' olarak değiştirildi.
# '927f6bcc-1389024_d2457ac3cf3966e0e2ce5a40494e6b5c_640x640.jpg' dosyası '47.jpg' olarak değiştirildi.
# '9e12c047-KUSLAR.webp' dosyası '48.webp' olarak değiştirildi.
# 'c961e753-michigan-da-kartal-drone-dusurdu.jpeg' dosyası '49.jpeg' olarak değiştirildi.
# 'cbd7af45-56e490ac67b0a931607da223.webp' dosyası '50.webp' olarak değiştirildi.
# 'd5bcd6b2-6a51e736877992ec472fa04b99267392499d0a73_1.jpeg' dosyası '51.jpeg' olarak değiştirildi.
# 'dddb1546-1389024_66ebc55b6df5c925b72c5a179e1dbf12_640x640.jpg' dosyası '52.jpg' olarak değiştirildi.
# 'fc6074ba-589e455661361f0b14f19fd3.webp' dosyası '53.webp' olarak değiştirildi.
# 'ff93d03a-64884.webp' dosyası '54.webp' olarak değiştirildi.
# Dosya isimlendirme işlemi tamamlandı.

# %%
#CHANGING NAMES OF AUGMENTED, RESIZED, NORMLIZED FILES TO ORDER WELL (BIRD)

# %%
import os

# Dosyaların bulunduğu klasörün yolu
folder_path = 'C:/Users/edana/Desktop/dataset_new/Bird/augmented_images'

# Dosya isimlerini değiştirmek için başlangıç numarası
start_number = 1
end_number = 400

# Klasördeki tüm dosyaları al
files = os.listdir(folder_path)

# Sadece dosya olanları al (klasörleri hariç tut)
files = [f for f in files if os.path.isfile(os.path.join(folder_path, f))]

# Dosyaları sıralı olarak yeniden isimlendirme işlemi
for i, file_name in enumerate(files):
    if i < end_number:
        # Dosyanın uzantısını al
        file_extension = os.path.splitext(file_name)[1]
        # Yeni dosya adını oluştur
        new_name = f"{start_number + i}{file_extension}"
        # Eski ve yeni dosya yollarını oluştur
        old_file_path = os.path.join(folder_path, file_name)
        new_file_path = os.path.join(folder_path, new_name)
        # Dosya ismini değiştir
        os.rename(old_file_path, new_file_path)
        print(f"'{file_name}' dosyası '{new_name}' olarak değiştirildi.")
    else:
        break

print("Dosya isimlendirme işlemi tamamlandı.")
# Out:
# '00c384a2-singleBirdinsky50.jpeg' dosyası '1.jpeg' olarak değiştirildi.
# '01706918-singleBirdinsky81.jpeg' dosyası '2.jpeg' olarak değiştirildi.
# '0319e725-singleBirdinsky24.jpeg' dosyası '3.jpeg' olarak değiştirildi.
# '0496a2af-BirdsFlying_2.jpg' dosyası '4.jpg' olarak değiştirildi.
# '04af7fdd-BirdsFlying_38.jpg' dosyası '5.jpg' olarak değiştirildi.
# '05a04b01-BirdsFlying_18.jpg' dosyası '6.jpg' olarak değiştirildi.
# '0652642b-BirdsFlying_91.jpg' dosyası '7.jpg' olarak değiştirildi.
# '06e09c85-BirdsFlying_98.jpg' dosyası '8.jpg' olarak değiştirildi.
# '083588e5-BirdsFlying_23.jpg' dosyası '9.jpg' olarak değiştirildi.
# '096c5b6a-singleBirdinsky253.jpeg' dosyası '10.jpeg' olarak değiştirildi.
# '096ca146-BirdsFlying_72.jpg' dosyası '11.jpg' olarak değiştirildi.
# '09f4a437-BirdsFlying_67.jpg' dosyası '12.jpg' olarak değiştirildi.
# '0a818092-singleBirdinsky306.jpeg' dosyası '13.jpeg' olarak değiştirildi.
# '0c154f58-singleBirdinsky3.jpeg' dosyası '14.jpeg' olarak değiştirildi.
# '0c7232be-singleBirdinsky336.jpeg' dosyası '15.jpeg' olarak değiştirildi.
# '0da11122-singleBirdinsky393.jpeg' dosyası '16.jpeg' olarak değiştirildi.
# '0e900c14-singleBirdinsky288.jpeg' dosyası '17.jpeg' olarak değiştirildi.
# '0ebc3a4f-singleBirdinsky41.jpeg' dosyası '18.jpeg' olarak değiştirildi.
# '10a41ba2-BirdsFlying_22.jpg' dosyası '19.jpg' olarak değiştirildi.
# '10e665f5-singleBirdinsky264.jpeg' dosyası '20.jpeg' olarak değiştirildi.
# '1103dfd4-singleBirdinsky383.jpeg' dosyası '21.jpeg' olarak değiştirildi.
# '11782edd-BirdsFlying_36.jpg' dosyası '22.jpg' olarak değiştirildi.
# '118daf0d-singleBirdinsky18.webp' dosyası '23.webp' olarak değiştirildi.
# '12fe3e3a-singleBirdinsky89.jpeg' dosyası '24.jpeg' olarak değiştirildi.
# '12fed2b4-singleBirdinsky102.jpeg' dosyası '25.jpeg' olarak değiştirildi.
# '151b71a7-singleBirdinsky66.jpeg' dosyası '26.jpeg' olarak değiştirildi.
# '15c3d099-singleBirdinsky284.jpeg' dosyası '27.jpeg' olarak değiştirildi.
# '15e1590b-singleBirdinsky5.jpeg' dosyası '28.jpeg' olarak değiştirildi.
# '1687157c-singleBirdinsky400.jpeg' dosyası '29.jpeg' olarak değiştirildi.
# '17772976-BirdsFlying_74.jpg' dosyası '30.jpg' olarak değiştirildi.
# '180fbf18-BirdsFlying_100.jpg' dosyası '31.jpg' olarak değiştirildi.
# '182e77e9-singleBirdinsky339.jpeg' dosyası '32.jpeg' olarak değiştirildi.
# '18eb8f35-BirdsFlying_5.jpg' dosyası '33.jpg' olarak değiştirildi.
# '1978edc0-singleBirdinsky328.jpeg' dosyası '34.jpeg' olarak değiştirildi.
# '1b748c32-singleBirdinsky273.jpeg' dosyası '35.jpeg' olarak değiştirildi.
# '1c2cddb7-singleBirdinsky398.jpeg' dosyası '36.jpeg' olarak değiştirildi.
# '1c8f463b-BirdsFlying_76.jpg' dosyası '37.jpg' olarak değiştirildi.
# '1d91fb02-singleBirdinsky67.jpeg' dosyası '38.jpeg' olarak değiştirildi.
# '1db47a06-BirdsFlying_1.jpg' dosyası '39.jpg' olarak değiştirildi.
# '1dffb844-BirdsFlying_39.jpg' dosyası '40.jpg' olarak değiştirildi.
# '1e5b48e9-singleBirdinsky80.jpeg' dosyası '41.jpeg' olarak değiştirildi.
# '1e6921bf-BirdsFlying_24.jpg' dosyası '42.jpg' olarak değiştirildi.
# '1f1e669a-BirdsFlying_11.jpg' dosyası '43.jpg' olarak değiştirildi.
# '1f8d389c-BirdsFlying_84.jpg' dosyası '44.jpg' olarak değiştirildi.
# '20e841c9-BirdsFlying_47.jpg' dosyası '45.jpg' olarak değiştirildi.
# '20f647c6-singleBirdinsky292.jpeg' dosyası '46.jpeg' olarak değiştirildi.
# '2185b228-singleBirdinsky331.jpeg' dosyası '47.jpeg' olarak değiştirildi.
# '240fa050-singleBirdinsky377.jpeg' dosyası '48.jpeg' olarak değiştirildi.
# '242dc811-singleBirdinsky311.jpeg' dosyası '49.jpeg' olarak değiştirildi.
# '243fa17c-BirdsFlying_90.jpg' dosyası '50.jpg' olarak değiştirildi.
# '2532d08c-singleBirdinsky1.jpeg' dosyası '51.jpeg' olarak değiştirildi.
# '26e07423-singleBirdinsky392.jpeg' dosyası '52.jpeg' olarak değiştirildi.
# '27934706-BirdsFlying_10.jpg' dosyası '53.jpg' olarak değiştirildi.
# '281dce8d-singleBirdinsky256.jpeg' dosyası '54.jpeg' olarak değiştirildi.
# '284b8596-singleBirdinsky19.webp' dosyası '55.webp' olarak değiştirildi.
# '2925913b-singleBirdinsky337.jpeg' dosyası '56.jpeg' olarak değiştirildi.
# '2954b105-singleBirdinsky348.jpeg' dosyası '57.jpeg' olarak değiştirildi.
# '2c41a790-singleBirdinsky318.jpeg' dosyası '58.jpeg' olarak değiştirildi.
# '2c7494c4-singleBirdinsky394.jpeg' dosyası '59.jpeg' olarak değiştirildi.
# '2e2d65d7-singleBirdinsky43.jpeg' dosyası '60.jpeg' olarak değiştirildi.
# '2e8bd394-BirdsFlying_46.jpg' dosyası '61.jpg' olarak değiştirildi.
# '3147891e-singleBirdinsky399.jpeg' dosyası '62.jpeg' olarak değiştirildi.
# '317da91e-singleBirdinsky314.jpeg' dosyası '63.jpeg' olarak değiştirildi.
# '320b39e4-singleBirdinsky369.jpeg' dosyası '64.jpeg' olarak değiştirildi.
# '33233d28-singleBirdinsky42.jpeg' dosyası '65.jpeg' olarak değiştirildi.
# '34caa1ff-singleBirdinsky338.jpeg' dosyası '66.jpeg' olarak değiştirildi.
# '37cf37fc-singleBirdinsky366.jpeg' dosyası '67.jpeg' olarak değiştirildi.
# '397d805a-singleBirdinsky57.jpeg' dosyası '68.jpeg' olarak değiştirildi.
# '3a905dcf-singleBirdinsky299.jpeg' dosyası '69.jpeg' olarak değiştirildi.
# '3a9135e9-singleBirdinsky75.jpeg' dosyası '70.jpeg' olarak değiştirildi.
# '3a9e9ee2-BirdsFlying_19.jpg' dosyası '71.jpg' olarak değiştirildi.
# '3aa3fe5f-singleBirdinsky258.jpeg' dosyası '72.jpeg' olarak değiştirildi.
# '3ba7e70c-singleBirdinsky382.jpeg' dosyası '73.jpeg' olarak değiştirildi.
# '3c62bfb4-singleBirdinsky32.jpeg' dosyası '74.jpeg' olarak değiştirildi.
# '3cd0c759-singleBirdinsky390.jpeg' dosyası '75.jpeg' olarak değiştirildi.
# '3d0d363d-singleBirdinsky334.jpeg' dosyası '76.jpeg' olarak değiştirildi.
# '3ea5c6d9-singleBirdinsky293.jpeg' dosyası '77.jpeg' olarak değiştirildi.
# '3efc5f53-singleBirdinsky92.jpeg' dosyası '78.jpeg' olarak değiştirildi.
# '3f58aaad-singleBirdinsky345.jpeg' dosyası '79.jpeg' olarak değiştirildi.
# '407710d3-singleBirdinsky294.jpeg' dosyası '80.jpeg' olarak değiştirildi.
# '41054a5b-singleBirdinsky25.jpeg' dosyası '81.jpeg' olarak değiştirildi.
# '44498f6e-BirdsFlying_87.jpg' dosyası '82.jpg' olarak değiştirildi.
# '44869a98-singleBirdinsky52.jpeg' dosyası '83.jpeg' olarak değiştirildi.
# '458dfb12-BirdsFlying_88.jpg' dosyası '84.jpg' olarak değiştirildi.
# '45a86580-singleBirdinsky78.jpeg' dosyası '85.jpeg' olarak değiştirildi.
# '46350bc4-singleBirdinsky267.jpeg' dosyası '86.jpeg' olarak değiştirildi.
# '46409030-singleBirdinsky0.jpeg' dosyası '87.jpeg' olarak değiştirildi.
# '46cfbe96-singleBirdinsky268.jpeg' dosyası '88.jpeg' olarak değiştirildi.
# '47245b8d-singleBirdinsky94.jpeg' dosyası '89.jpeg' olarak değiştirildi.
# '48d6e2d5-singleBirdinsky257.jpeg' dosyası '90.jpeg' olarak değiştirildi.
# '4938aa51-singleBirdinsky90.jpeg' dosyası '91.jpeg' olarak değiştirildi.
# '49511e80-singleBirdinsky85.jpeg' dosyası '92.jpeg' olarak değiştirildi.
# '49819b2b-singleBirdinsky275.jpeg' dosyası '93.jpeg' olarak değiştirildi.
# '49ea09fc-singleBirdinsky39.jpeg' dosyası '94.jpeg' olarak değiştirildi.
# '49fadd0d-singleBirdinsky378.jpeg' dosyası '95.jpeg' olarak değiştirildi.
# '4b49fd33-singleBirdinsky351.jpeg' dosyası '96.jpeg' olarak değiştirildi.
# '4c531435-BirdsFlying_48.jpg' dosyası '97.jpg' olarak değiştirildi.
# '4f771275-singleBirdinsky391.jpeg' dosyası '98.jpeg' olarak değiştirildi.
# '4fde41b8-singleBirdinsky286.jpeg' dosyası '99.jpeg' olarak değiştirildi.
# '50502e52-singleBirdinsky340.jpeg' dosyası '100.jpeg' olarak değiştirildi.
# '519f56ef-BirdsFlying_77.jpg' dosyası '101.jpg' olarak değiştirildi.
# '5227372a-BirdsFlying_85.jpg' dosyası '102.jpg' olarak değiştirildi.
# '52336bdd-BirdsFlying_41.jpg' dosyası '103.jpg' olarak değiştirildi.
# '5261e3b8-BirdsFlying_70.jpg' dosyası '104.jpg' olarak değiştirildi.
# '52e5791f-singleBirdinsky54.jpeg' dosyası '105.jpeg' olarak değiştirildi.
# '530b50a6-singleBirdinsky374.jpeg' dosyası '106.jpeg' olarak değiştirildi.
# '53ee8b29-singleBirdinsky263.jpeg' dosyası '107.jpeg' olarak değiştirildi.
# '573c8f9e-singleBirdinsky262.jpeg' dosyası '108.jpeg' olarak değiştirildi.
# '57a2fb68-singleBirdinsky343.jpeg' dosyası '109.jpeg' olarak değiştirildi.
# '57f6335b-singleBirdinsky310.jpeg' dosyası '110.jpeg' olarak değiştirildi.
# '588d79df-singleBirdinsky10.jpeg' dosyası '111.jpeg' olarak değiştirildi.
# '58f4b780-BirdsFlying_28.jpg' dosyası '112.jpg' olarak değiştirildi.
# '59aae686-singleBirdinsky64.jpeg' dosyası '113.jpeg' olarak değiştirildi.
# '59c3d30d-singleBirdinsky359.jpeg' dosyası '114.jpeg' olarak değiştirildi.
# '5a4f74f7-singleBirdinsky23.jpeg' dosyası '115.jpeg' olarak değiştirildi.
# '5ac8b469-BirdsFlying_53.jpg' dosyası '116.jpg' olarak değiştirildi.
# '5b0b6e27-singleBirdinsky271.jpeg' dosyası '117.jpeg' olarak değiştirildi.
# '5b6fee58-singleBirdinsky283.jpeg' dosyası '118.jpeg' olarak değiştirildi.
# '5ba67ffd-singleBirdinsky363.jpeg' dosyası '119.jpeg' olarak değiştirildi.
# '5c4c41fd-singleBirdinsky70.jpeg' dosyası '120.jpeg' olarak değiştirildi.
# '5c6afd5d-BirdsFlying_17.jpg' dosyası '121.jpg' olarak değiştirildi.
# '5cbdc193-singleBirdinsky62.jpeg' dosyası '122.jpeg' olarak değiştirildi.
# '5d035a49-singleBirdinsky58.jpeg' dosyası '123.jpeg' olarak değiştirildi.
# '5d74c23d-singleBirdinsky290.jpeg' dosyası '124.jpeg' olarak değiştirildi.
# '5db6e053-singleBirdinsky53.jpeg' dosyası '125.jpeg' olarak değiştirildi.
# '5db9d7a8-singleBirdinsky88.jpeg' dosyası '126.jpeg' olarak değiştirildi.
# '5f851c6f-singleBirdinsky297.jpeg' dosyası '127.jpeg' olarak değiştirildi.
# '6072ed54-singleBirdinsky389.jpeg' dosyası '128.jpeg' olarak değiştirildi.
# '60779026-singleBirdinsky301.jpeg' dosyası '129.jpeg' olarak değiştirildi.
# '6262f3d0-singleBirdinsky87.jpeg' dosyası '130.jpeg' olarak değiştirildi.
# '632c7e69-singleBirdinsky63.jpeg' dosyası '131.jpeg' olarak değiştirildi.
# '63bb9223-BirdsFlying_35.jpg' dosyası '132.jpg' olarak değiştirildi.
# '63bdbf5e-singleBirdinsky26.jpeg' dosyası '133.jpeg' olarak değiştirildi.
# '63d2068f-BirdsFlying_15.jpg' dosyası '134.jpg' olarak değiştirildi.
# '64233198-singleBirdinsky255.jpeg' dosyası '135.jpeg' olarak değiştirildi.
# '64b441d4-BirdsFlying_86.jpg' dosyası '136.jpg' olarak değiştirildi.
# '6531fc8a-BirdsFlying_45.jpg' dosyası '137.jpg' olarak değiştirildi.
# '664cc429-BirdsFlying_92.jpg' dosyası '138.jpg' olarak değiştirildi.
# '681b5c56-singleBirdinsky274.jpeg' dosyası '139.jpeg' olarak değiştirildi.
# '693018be-singleBirdinsky282.jpeg' dosyası '140.jpeg' olarak değiştirildi.
# '6a3e85c5-singleBirdinsky387.jpeg' dosyası '141.jpeg' olarak değiştirildi.
# '6b092561-singleBirdinsky55.jpeg' dosyası '142.jpeg' olarak değiştirildi.
# '6c6f03ed-singleBirdinsky51.jpeg' dosyası '143.jpeg' olarak değiştirildi.
# '6ccb67b0-singleBirdinsky312.jpeg' dosyası '144.jpeg' olarak değiştirildi.
# '6df7c599-BirdsFlying_13.jpg' dosyası '145.jpg' olarak değiştirildi.
# '6e15ba0d-singleBirdinsky397.jpeg' dosyası '146.jpeg' olarak değiştirildi.
# '6e50e3dd-singleBirdinsky22.jpeg' dosyası '147.jpeg' olarak değiştirildi.
# '6f21a479-BirdsFlying_26.jpg' dosyası '148.jpg' olarak değiştirildi.
# '6f96a256-BirdsFlying_66.jpg' dosyası '149.jpg' olarak değiştirildi.
# '70f0ec8e-singleBirdinsky99.jpeg' dosyası '150.jpeg' olarak değiştirildi.
# '71509d84-BirdsFlying_57.jpg' dosyası '151.jpg' olarak değiştirildi.
# '7193c155-singleBirdinsky21.jpeg' dosyası '152.jpeg' olarak değiştirildi.
# '71a74a62-BirdsFlying_49.jpg' dosyası '153.jpg' olarak değiştirildi.
# '7202a32a-singleBirdinsky289.jpeg' dosyası '154.jpeg' olarak değiştirildi.
# '74d3336e-singleBirdinsky68.jpeg' dosyası '155.jpeg' olarak değiştirildi.
# '76e96f39-singleBirdinsky295.jpeg' dosyası '156.jpeg' olarak değiştirildi.
# '7711fc38-singleBirdinsky279.jpeg' dosyası '157.jpeg' olarak değiştirildi.
# '771919f4-BirdsFlying_33.jpg' dosyası '158.jpg' olarak değiştirildi.
# '772a0264-BirdsFlying_82.jpg' dosyası '159.jpg' olarak değiştirildi.
# '78584bc3-singleBirdinsky380.jpeg' dosyası '160.jpeg' olarak değiştirildi.
# '78fec515-singleBirdinsky13.jpeg' dosyası '161.jpeg' olarak değiştirildi.
# '79194f64-singleBirdinsky4.jpeg' dosyası '162.jpeg' olarak değiştirildi.
# '7933e628-singleBirdinsky388.jpeg' dosyası '163.jpeg' olarak değiştirildi.
# '7a13198b-singleBirdinsky303.jpeg' dosyası '164.jpeg' olarak değiştirildi.
# '7a2cd2b4-singleBirdinsky371.jpeg' dosyası '165.jpeg' olarak değiştirildi.
# '7a7546fe-singleBirdinsky17.jpeg' dosyası '166.jpeg' olarak değiştirildi.
# '7ae22701-singleBirdinsky45.jpeg' dosyası '167.jpeg' olarak değiştirildi.
# '7c5fc42f-singleBirdinsky365.jpeg' dosyası '168.jpeg' olarak değiştirildi.
# '7cde6cde-singleBirdinsky44.jpeg' dosyası '169.jpeg' olarak değiştirildi.
# '8053ae54-BirdsFlying_12.jpg' dosyası '170.jpg' olarak değiştirildi.
# '80d92f41-singleBirdinsky280.jpeg' dosyası '171.jpeg' olarak değiştirildi.
# '8162cbbb-singleBirdinsky324.jpeg' dosyası '172.jpeg' olarak değiştirildi.
# '81b67b84-singleBirdinsky379.jpeg' dosyası '173.jpeg' olarak değiştirildi.
# '8275ef4b-singleBirdinsky83.jpeg' dosyası '174.jpeg' olarak değiştirildi.
# '82d36d13-BirdsFlying_61.jpg' dosyası '175.jpg' olarak değiştirildi.
# '82e7089d-singleBirdinsky350.jpeg' dosyası '176.jpeg' olarak değiştirildi.
# '830b0046-singleBirdinsky360.jpeg' dosyası '177.jpeg' olarak değiştirildi.
# '847a8c83-singleBirdinsky269.jpeg' dosyası '178.jpeg' olarak değiştirildi.
# '855af4b4-singleBirdinsky335.jpeg' dosyası '179.jpeg' olarak değiştirildi.
# '861f5e5a-BirdsFlying_58.jpg' dosyası '180.jpg' olarak değiştirildi.
# '885a647a-BirdsFlying_68.jpg' dosyası '181.jpg' olarak değiştirildi.
# '8907c212-singleBirdinsky20.jpeg' dosyası '182.jpeg' olarak değiştirildi.
# '8c2bb288-BirdsFlying_65.jpg' dosyası '183.jpg' olarak değiştirildi.
# '8c54c00d-singleBirdinsky56.jpeg' dosyası '184.jpeg' olarak değiştirildi.
# '8cc41cb5-singleBirdinsky276.jpeg' dosyası '185.jpeg' olarak değiştirildi.
# '8cfe1708-singleBirdinsky270.jpeg' dosyası '186.jpeg' olarak değiştirildi.
# '8f331e26-singleBirdinsky356.jpeg' dosyası '187.jpeg' olarak değiştirildi.
# '8f422e83-singleBirdinsky34.jpeg' dosyası '188.jpeg' olarak değiştirildi.
# '906a30c4-singleBirdinsky259.jpeg' dosyası '189.jpeg' olarak değiştirildi.
# '91434aab-singleBirdinsky346.jpeg' dosyası '190.jpeg' olarak değiştirildi.
# '9245f1f4-singleBirdinsky296.jpeg' dosyası '191.jpeg' olarak değiştirildi.
# '93f58bcc-singleBirdinsky278.jpeg' dosyası '192.jpeg' olarak değiştirildi.
# '94041976-singleBirdinsky93.jpeg' dosyası '193.jpeg' olarak değiştirildi.
# '948eaec8-singleBirdinsky395.jpeg' dosyası '194.jpeg' olarak değiştirildi.
# '95fa5d36-singleBirdinsky364.jpeg' dosyası '195.jpeg' olarak değiştirildi.
# '9691cc03-BirdsFlying_37.jpg' dosyası '196.jpg' olarak değiştirildi.
# '96e12139-BirdsFlying_6.jpg' dosyası '197.jpg' olarak değiştirildi.
# '96e6abef-singleBirdinsky2.jpeg' dosyası '198.jpeg' olarak değiştirildi.
# '96e926d8-BirdsFlying_16.jpg' dosyası '199.jpg' olarak değiştirildi.
# '96f47643-singleBirdinsky375.jpeg' dosyası '200.jpeg' olarak değiştirildi.
# '97da69e6-BirdsFlying_9.jpg' dosyası '201.jpg' olarak değiştirildi.
# '991c5f0d-BirdsFlying_43.jpg' dosyası '202.jpg' olarak değiştirildi.
# '9a224791-singleBirdinsky95.jpeg' dosyası '203.jpeg' olarak değiştirildi.
# '9b9a31cb-singleBirdinsky308.jpeg' dosyası '204.jpeg' olarak değiştirildi.
# '9bf4b3d6-BirdsFlying_93.jpg' dosyası '205.jpg' olarak değiştirildi.
# '9cf82070-BirdsFlying_32.jpg' dosyası '206.jpg' olarak değiştirildi.
# '9dfe2852-singleBirdinsky84.jpeg' dosyası '207.jpeg' olarak değiştirildi.
# '9e6644bb-singleBirdinsky317.jpeg' dosyası '208.jpeg' olarak değiştirildi.
# '9fdfc9b7-singleBirdinsky38.jpeg' dosyası '209.jpeg' olarak değiştirildi.
# 'a04f7d3c-singleBirdinsky353.jpeg' dosyası '210.jpeg' olarak değiştirildi.
# 'a0a22a09-singleBirdinsky7.jpeg' dosyası '211.jpeg' olarak değiştirildi.
# 'a1eabb9b-singleBirdinsky355.jpeg' dosyası '212.jpeg' olarak değiştirildi.
# 'a2531b9c-singleBirdinsky16.jpeg' dosyası '213.jpeg' olarak değiştirildi.
# 'a3667e49-singleBirdinsky362.jpeg' dosyası '214.jpeg' olarak değiştirildi.
# 'a36afc79-singleBirdinsky326.jpeg' dosyası '215.jpeg' olarak değiştirildi.
# 'a36e273a-BirdsFlying_81.jpg' dosyası '216.jpg' olarak değiştirildi.
# 'a4cff496-BirdsFlying_55.jpg' dosyası '217.jpg' olarak değiştirildi.
# 'a4e00d62-singleBirdinsky300.jpeg' dosyası '218.jpeg' olarak değiştirildi.
# 'a68afb5f-BirdsFlying_31.jpg' dosyası '219.jpg' olarak değiştirildi.
# 'a69bd298-singleBirdinsky49.jpeg' dosyası '220.jpeg' olarak değiştirildi.
# 'a69cdddf-singleBirdinsky98.jpeg' dosyası '221.jpeg' olarak değiştirildi.
# 'a793430d-BirdsFlying_75.jpg' dosyası '222.jpg' olarak değiştirildi.
# 'a8857efe-singleBirdinsky323.jpeg' dosyası '223.jpeg' olarak değiştirildi.
# 'ab497272-BirdsFlying_20.jpg' dosyası '224.jpg' olarak değiştirildi.
# 'ad2e65d8-singleBirdinsky386.jpeg' dosyası '225.jpeg' olarak değiştirildi.
# 'ad989ce9-BirdsFlying_56.jpg' dosyası '226.jpg' olarak değiştirildi.
# 'aec4235a-singleBirdinsky27.jpeg' dosyası '227.jpeg' olarak değiştirildi.
# 'afae4680-singleBirdinsky319.jpeg' dosyası '228.jpeg' olarak değiştirildi.
# 'afe2f869-BirdsFlying_73.jpg' dosyası '229.jpg' olarak değiştirildi.
# 'b15212e1-singleBirdinsky60.jpeg' dosyası '230.jpeg' olarak değiştirildi.
# 'b168e71f-BirdsFlying_71.jpg' dosyası '231.jpg' olarak değiştirildi.
# 'b20dd9f1-singleBirdinsky305.jpeg' dosyası '232.jpeg' olarak değiştirildi.
# 'b337d171-singleBirdinsky260.jpeg' dosyası '233.jpeg' olarak değiştirildi.
# 'b34934dc-singleBirdinsky6.jpeg' dosyası '234.jpeg' olarak değiştirildi.
# 'b37a6528-BirdsFlying_60.jpg' dosyası '235.jpg' olarak değiştirildi.
# 'b41625e8-singleBirdinsky28.jpeg' dosyası '236.jpeg' olarak değiştirildi.
# 'b4369565-singleBirdinsky76.jpeg' dosyası '237.jpeg' olarak değiştirildi.
# 'b492a3e7-BirdsFlying_95.jpg' dosyası '238.jpg' olarak değiştirildi.
# 'b56c2240-BirdsFlying_50.jpg' dosyası '239.jpg' olarak değiştirildi.
# 'b59337b7-BirdsFlying_54.jpg' dosyası '240.jpg' olarak değiştirildi.
# 'b5f73620-singleBirdinsky100.jpeg' dosyası '241.jpeg' olarak değiştirildi.
# 'b7a0aaef-BirdsFlying_34.jpg' dosyası '242.jpg' olarak değiştirildi.
# 'b8f93a93-singleBirdinsky291.jpeg' dosyası '243.jpeg' olarak değiştirildi.
# 'bab4f15b-singleBirdinsky47.jpeg' dosyası '244.jpeg' olarak değiştirildi.
# 'baf46f79-BirdsFlying_40.jpg' dosyası '245.jpg' olarak değiştirildi.
# 'bc1cfd29-BirdsFlying_3.jpg' dosyası '246.jpg' olarak değiştirildi.
# 'bc900bc9-singleBirdinsky82.jpeg' dosyası '247.jpeg' olarak değiştirildi.
# 'bdb2c939-singleBirdinsky327.jpeg' dosyası '248.jpeg' olarak değiştirildi.
# 'bdf43445-singleBirdinsky254.jpeg' dosyası '249.jpeg' olarak değiştirildi.
# 'bed2730b-BirdsFlying_7.jpg' dosyası '250.jpg' olarak değiştirildi.
# 'c0338078-BirdsFlying_62.jpg' dosyası '251.jpg' olarak değiştirildi.
# 'c0c0fa95-singleBirdinsky74.jpeg' dosyası '252.jpeg' olarak değiştirildi.
# 'c0e329a3-singleBirdinsky272.jpeg' dosyası '253.jpeg' olarak değiştirildi.
# 'c2888d94-singleBirdinsky40.jpeg' dosyası '254.jpeg' olarak değiştirildi.
# 'c2ac1144-singleBirdinsky31.jpeg' dosyası '255.jpeg' olarak değiştirildi.
# 'c2c9b4cb-singleBirdinsky30.jpeg' dosyası '256.jpeg' olarak değiştirildi.
# 'c3cb682a-singleBirdinsky37.jpeg' dosyası '257.jpeg' olarak değiştirildi.
# 'c3f66c65-singleBirdinsky329.jpeg' dosyası '258.jpeg' olarak değiştirildi.
# 'c44f8fc1-singleBirdinsky14.jpeg' dosyası '259.jpeg' olarak değiştirildi.
# 'c540d90a-singleBirdinsky33.jpeg' dosyası '260.jpeg' olarak değiştirildi.
# 'c6386cba-singleBirdinsky352.jpeg' dosyası '261.jpeg' olarak değiştirildi.
# 'c79fde15-singleBirdinsky376.jpeg' dosyası '262.jpeg' olarak değiştirildi.
# 'c7abc7ae-singleBirdinsky61.jpeg' dosyası '263.jpeg' olarak değiştirildi.
# 'c7b7afed-singleBirdinsky349.jpeg' dosyası '264.jpeg' olarak değiştirildi.
# 'c7dc6a8e-singleBirdinsky330.jpeg' dosyası '265.jpeg' olarak değiştirildi.
# 'c97ddb6b-singleBirdinsky281.jpeg' dosyası '266.jpeg' olarak değiştirildi.
# 'ca727928-singleBirdinsky385.jpeg' dosyası '267.jpeg' olarak değiştirildi.
# 'cfd3e618-singleBirdinsky373.jpeg' dosyası '268.jpeg' olarak değiştirildi.
# 'd0d4c5c2-BirdsFlying_44.jpg' dosyası '269.jpg' olarak değiştirildi.
# 'd420bb3b-singleBirdinsky315.jpeg' dosyası '270.jpeg' olarak değiştirildi.
# 'd45de038-BirdsFlying_63.jpg' dosyası '271.jpg' olarak değiştirildi.
# 'd5850b02-singleBirdinsky370.jpeg' dosyası '272.jpeg' olarak değiştirildi.
# 'd70ed0f3-singleBirdinsky69.jpeg' dosyası '273.jpeg' olarak değiştirildi.
# 'd976db0a-singleBirdinsky65.jpeg' dosyası '274.jpeg' olarak değiştirildi.
# 'd97b08fd-BirdsFlying_29.jpg' dosyası '275.jpg' olarak değiştirildi.
# 'da4c61de-singleBirdinsky313.jpeg' dosyası '276.jpeg' olarak değiştirildi.
# 'db9075ce-singleBirdinsky35.jpeg' dosyası '277.jpeg' olarak değiştirildi.
# 'dbbc4187-singleBirdinsky77.jpeg' dosyası '278.jpeg' olarak değiştirildi.
# 'dc2080a9-BirdsFlying_78.jpg' dosyası '279.jpg' olarak değiştirildi.
# 'dc57d665-singleBirdinsky12.jpeg' dosyası '280.jpeg' olarak değiştirildi.
# 'dcdefe6b-singleBirdinsky368.jpeg' dosyası '281.jpeg' olarak değiştirildi.
# 'dcdfe876-BirdsFlying_51.jpg' dosyası '282.jpg' olarak değiştirildi.
# 'dce9cc17-singleBirdinsky287.jpeg' dosyası '283.jpeg' olarak değiştirildi.
# 'dcf00cc6-singleBirdinsky361.jpeg' dosyası '284.jpeg' olarak değiştirildi.
# 'dd1a5565-singleBirdinsky357.jpeg' dosyası '285.jpeg' olarak değiştirildi.
# 'dd797f7d-BirdsFlying_69.jpg' dosyası '286.jpg' olarak değiştirildi.
# 'dd9c8e64-singleBirdinsky36.jpeg' dosyası '287.jpeg' olarak değiştirildi.
# 'ddb99ef6-singleBirdinsky266.jpeg' dosyası '288.jpeg' olarak değiştirildi.
# 'de8ae1bd-singleBirdinsky332.jpeg' dosyası '289.jpeg' olarak değiştirildi.
# 'de9c161c-BirdsFlying_25.jpg' dosyası '290.jpg' olarak değiştirildi.
# 'decf6a00-singleBirdinsky11.jpeg' dosyası '291.jpeg' olarak değiştirildi.
# 'df3e8dad-singleBirdinsky396.jpeg' dosyası '292.jpeg' olarak değiştirildi.
# 'df8f6236-BirdsFlying_52.jpg' dosyası '293.jpg' olarak değiştirildi.
# 'e09799af-BirdsFlying_27.jpg' dosyası '294.jpg' olarak değiştirildi.
# 'e1137d7a-BirdsFlying_59.jpg' dosyası '295.jpg' olarak değiştirildi.
# 'e121efa7-singleBirdinsky97.jpeg' dosyası '296.jpeg' olarak değiştirildi.
# 'e19ac38b-singleBirdinsky344.jpeg' dosyası '297.jpeg' olarak değiştirildi.
# 'e1da50b9-BirdsFlying_94.jpg' dosyası '298.jpg' olarak değiştirildi.
# 'e3039681-singleBirdinsky59.jpeg' dosyası '299.jpeg' olarak değiştirildi.
# 'e33b0129-singleBirdinsky265.jpeg' dosyası '300.jpeg' olarak değiştirildi.
# 'e486f84a-BirdsFlying_14.jpg' dosyası '301.jpg' olarak değiştirildi.
# 'e517ea5e-singleBirdinsky15.jpeg' dosyası '302.jpeg' olarak değiştirildi.
# 'e5656bae-singleBirdinsky372.jpeg' dosyası '303.jpeg' olarak değiştirildi.
# 'e61a80b4-singleBirdinsky309.jpeg' dosyası '304.jpeg' olarak değiştirildi.
# 'e8d40c43-singleBirdinsky307.jpeg' dosyası '305.jpeg' olarak değiştirildi.
# 'e99342cc-singleBirdinsky101.jpeg' dosyası '306.jpeg' olarak değiştirildi.
# 'eac7e99b-BirdsFlying_64.jpg' dosyası '307.jpg' olarak değiştirildi.
# 'eb5202ee-BirdsFlying_99.jpg' dosyası '308.jpg' olarak değiştirildi.
# 'eb5a11bd-singleBirdinsky298.jpeg' dosyası '309.jpeg' olarak değiştirildi.
# 'eb5b939f-singleBirdinsky285.jpeg' dosyası '310.jpeg' olarak değiştirildi.
# 'ebfec92e-singleBirdinsky322.jpeg' dosyası '311.jpeg' olarak değiştirildi.
# 'ec002da0-BirdsFlying_83.jpg' dosyası '312.jpg' olarak değiştirildi.
# 'ec969a39-singleBirdinsky86.jpeg' dosyası '313.jpeg' olarak değiştirildi.
# 'edc46316-singleBirdinsky277.jpeg' dosyası '314.jpeg' olarak değiştirildi.
# 'edd6883a-singleBirdinsky384.jpeg' dosyası '315.jpeg' olarak değiştirildi.
# 'ef04f342-singleBirdinsky71.jpeg' dosyası '316.jpeg' olarak değiştirildi.
# 'f009ec1f-BirdsFlying_4.jpg' dosyası '317.jpg' olarak değiştirildi.
# 'f0533c9d-BirdsFlying_97.jpg' dosyası '318.jpg' olarak değiştirildi.
# 'f059d232-BirdsFlying_8.jpg' dosyası '319.jpg' olarak değiştirildi.
# 'f11710a8-singleBirdinsky341.jpeg' dosyası '320.jpeg' olarak değiştirildi.
# 'f135cbc3-singleBirdinsky358.jpeg' dosyası '321.jpeg' olarak değiştirildi.
# 'f160b739-singleBirdinsky46.jpeg' dosyası '322.jpeg' olarak değiştirildi.
# 'f1fcd495-singleBirdinsky261.jpeg' dosyası '323.jpeg' olarak değiştirildi.
# 'f202ac08-singleBirdinsky73.jpeg' dosyası '324.jpeg' olarak değiştirildi.
# 'f281bbef-singleBirdinsky91.jpeg' dosyası '325.jpeg' olarak değiştirildi.
# 'f2eea839-singleBirdinsky302.jpeg' dosyası '326.jpeg' olarak değiştirildi.
# 'f3122b69-singleBirdinsky72.jpeg' dosyası '327.jpeg' olarak değiştirildi.
# 'f3554d84-singleBirdinsky304.jpeg' dosyası '328.jpeg' olarak değiştirildi.
# 'f38238d3-singleBirdinsky79.jpeg' dosyası '329.jpeg' olarak değiştirildi.
# 'f3aad9d7-BirdsFlying_96.jpg' dosyası '330.jpg' olarak değiştirildi.
# 'f3db90d1-singleBirdinsky316.jpeg' dosyası '331.jpeg' olarak değiştirildi.
# 'f4896dce-singleBirdinsky96.jpeg' dosyası '332.jpeg' olarak değiştirildi.
# 'f50820b9-BirdsFlying_79.jpg' dosyası '333.jpg' olarak değiştirildi.
# 'f64053c2-singleBirdinsky321.jpeg' dosyası '334.jpeg' olarak değiştirildi.
# 'f6a0173a-singleBirdinsky48.jpeg' dosyası '335.jpeg' olarak değiştirildi.
# 'f79db98f-BirdsFlying_80.jpg' dosyası '336.jpg' olarak değiştirildi.
# 'f7e896f1-singleBirdinsky320.jpeg' dosyası '337.jpeg' olarak değiştirildi.
# 'fa787f8e-singleBirdinsky9.jpeg' dosyası '338.jpeg' olarak değiştirildi.
# 'fa86d27f-BirdsFlying_30.jpg' dosyası '339.jpg' olarak değiştirildi.
# 'facd524b-1389024_27c2560c5b4dab0e756b013ce3321cfe_640x640.jpg' dosyası '340.jpg' olarak değiştirildi.
# 'fb3cb273-BirdsFlying_42.jpg' dosyası '341.jpg' olarak değiştirildi.
# 'fb4c4f03-BirdsFlying_21.jpg' dosyası '342.jpg' olarak değiştirildi.
# 'fbf068f5-BirdsFlying_89.jpg' dosyası '343.jpg' olarak değiştirildi.
# 'fc20d621-singleBirdinsky333.jpeg' dosyası '344.jpeg' olarak değiştirildi.
# 'fc3aaa7a-singleBirdinsky325.jpeg' dosyası '345.jpeg' olarak değiştirildi.
# 'fe033844-singleBirdinsky29.jpeg' dosyası '346.jpeg' olarak değiştirildi.
# 'ff6e9784-singleBirdinsky347.jpeg' dosyası '347.jpeg' olarak değiştirildi.
# Dosya isimlendirme işlemi tamamlandı.

# %%
import os

# Dosyaların bulunduğu klasörün yolu
folder_path = 'C:/Users/edana/Desktop/dataset_new/Bird/normalized_images'

# Dosya isimlerini değiştirmek için başlangıç numarası
start_number = 348
end_number = 800

# Klasördeki tüm dosyaları al
files = os.listdir(folder_path)

# Sadece dosya olanları al (klasörleri hariç tut)
files = [f for f in files if os.path.isfile(os.path.join(folder_path, f))]

# Dosyaları sıralı olarak yeniden isimlendirme işlemi
for i, file_name in enumerate(files):
    if i < end_number:
        # Dosyanın uzantısını al
        file_extension = os.path.splitext(file_name)[1]
        # Yeni dosya adını oluştur
        new_name = f"{start_number + i}{file_extension}"
        # Eski ve yeni dosya yollarını oluştur
        old_file_path = os.path.join(folder_path, file_name)
        new_file_path = os.path.join(folder_path, new_name)
        # Dosya ismini değiştir
        os.rename(old_file_path, new_file_path)
        print(f"'{file_name}' dosyası '{new_name}' olarak değiştirildi.")
    else:
        break

print("Dosya isimlendirme işlemi tamamlandı.")
# Out:
# '00c384a2-singleBirdinsky50.jpeg' dosyası '348.jpeg' olarak değiştirildi.
# '01706918-singleBirdinsky81.jpeg' dosyası '349.jpeg' olarak değiştirildi.
# '0319e725-singleBirdinsky24.jpeg' dosyası '350.jpeg' olarak değiştirildi.
# '0496a2af-BirdsFlying_2.jpg' dosyası '351.jpg' olarak değiştirildi.
# '04af7fdd-BirdsFlying_38.jpg' dosyası '352.jpg' olarak değiştirildi.
# '05a04b01-BirdsFlying_18.jpg' dosyası '353.jpg' olarak değiştirildi.
# '0652642b-BirdsFlying_91.jpg' dosyası '354.jpg' olarak değiştirildi.
# '06e09c85-BirdsFlying_98.jpg' dosyası '355.jpg' olarak değiştirildi.
# '083588e5-BirdsFlying_23.jpg' dosyası '356.jpg' olarak değiştirildi.
# '096c5b6a-singleBirdinsky253.jpeg' dosyası '357.jpeg' olarak değiştirildi.
# '096ca146-BirdsFlying_72.jpg' dosyası '358.jpg' olarak değiştirildi.
# '09f4a437-BirdsFlying_67.jpg' dosyası '359.jpg' olarak değiştirildi.
# '0a818092-singleBirdinsky306.jpeg' dosyası '360.jpeg' olarak değiştirildi.
# '0c154f58-singleBirdinsky3.jpeg' dosyası '361.jpeg' olarak değiştirildi.
# '0c7232be-singleBirdinsky336.jpeg' dosyası '362.jpeg' olarak değiştirildi.
# '0da11122-singleBirdinsky393.jpeg' dosyası '363.jpeg' olarak değiştirildi.
# '0e900c14-singleBirdinsky288.jpeg' dosyası '364.jpeg' olarak değiştirildi.
# '0ebc3a4f-singleBirdinsky41.jpeg' dosyası '365.jpeg' olarak değiştirildi.
# '10a41ba2-BirdsFlying_22.jpg' dosyası '366.jpg' olarak değiştirildi.
# '10e665f5-singleBirdinsky264.jpeg' dosyası '367.jpeg' olarak değiştirildi.
# '1103dfd4-singleBirdinsky383.jpeg' dosyası '368.jpeg' olarak değiştirildi.
# '11782edd-BirdsFlying_36.jpg' dosyası '369.jpg' olarak değiştirildi.
# '118daf0d-singleBirdinsky18.webp' dosyası '370.webp' olarak değiştirildi.
# '12fe3e3a-singleBirdinsky89.jpeg' dosyası '371.jpeg' olarak değiştirildi.
# '12fed2b4-singleBirdinsky102.jpeg' dosyası '372.jpeg' olarak değiştirildi.
# '151b71a7-singleBirdinsky66.jpeg' dosyası '373.jpeg' olarak değiştirildi.
# '15c3d099-singleBirdinsky284.jpeg' dosyası '374.jpeg' olarak değiştirildi.
# '15e1590b-singleBirdinsky5.jpeg' dosyası '375.jpeg' olarak değiştirildi.
# '1687157c-singleBirdinsky400.jpeg' dosyası '376.jpeg' olarak değiştirildi.
# '17772976-BirdsFlying_74.jpg' dosyası '377.jpg' olarak değiştirildi.
# '180fbf18-BirdsFlying_100.jpg' dosyası '378.jpg' olarak değiştirildi.
# '182e77e9-singleBirdinsky339.jpeg' dosyası '379.jpeg' olarak değiştirildi.
# '18eb8f35-BirdsFlying_5.jpg' dosyası '380.jpg' olarak değiştirildi.
# '1978edc0-singleBirdinsky328.jpeg' dosyası '381.jpeg' olarak değiştirildi.
# '1b748c32-singleBirdinsky273.jpeg' dosyası '382.jpeg' olarak değiştirildi.
# '1c2cddb7-singleBirdinsky398.jpeg' dosyası '383.jpeg' olarak değiştirildi.
# '1c8f463b-BirdsFlying_76.jpg' dosyası '384.jpg' olarak değiştirildi.
# '1d91fb02-singleBirdinsky67.jpeg' dosyası '385.jpeg' olarak değiştirildi.
# '1db47a06-BirdsFlying_1.jpg' dosyası '386.jpg' olarak değiştirildi.
# '1dffb844-BirdsFlying_39.jpg' dosyası '387.jpg' olarak değiştirildi.
# '1e5b48e9-singleBirdinsky80.jpeg' dosyası '388.jpeg' olarak değiştirildi.
# '1e6921bf-BirdsFlying_24.jpg' dosyası '389.jpg' olarak değiştirildi.
# '1f1e669a-BirdsFlying_11.jpg' dosyası '390.jpg' olarak değiştirildi.
# '1f8d389c-BirdsFlying_84.jpg' dosyası '391.jpg' olarak değiştirildi.
# '20e841c9-BirdsFlying_47.jpg' dosyası '392.jpg' olarak değiştirildi.
# '20f647c6-singleBirdinsky292.jpeg' dosyası '393.jpeg' olarak değiştirildi.
# '2185b228-singleBirdinsky331.jpeg' dosyası '394.jpeg' olarak değiştirildi.
# '240fa050-singleBirdinsky377.jpeg' dosyası '395.jpeg' olarak değiştirildi.
# '242dc811-singleBirdinsky311.jpeg' dosyası '396.jpeg' olarak değiştirildi.
# '243fa17c-BirdsFlying_90.jpg' dosyası '397.jpg' olarak değiştirildi.
# '2532d08c-singleBirdinsky1.jpeg' dosyası '398.jpeg' olarak değiştirildi.
# '26e07423-singleBirdinsky392.jpeg' dosyası '399.jpeg' olarak değiştirildi.
# '27934706-BirdsFlying_10.jpg' dosyası '400.jpg' olarak değiştirildi.
# '281dce8d-singleBirdinsky256.jpeg' dosyası '401.jpeg' olarak değiştirildi.
# '284b8596-singleBirdinsky19.webp' dosyası '402.webp' olarak değiştirildi.
# '2925913b-singleBirdinsky337.jpeg' dosyası '403.jpeg' olarak değiştirildi.
# '2954b105-singleBirdinsky348.jpeg' dosyası '404.jpeg' olarak değiştirildi.
# '2c41a790-singleBirdinsky318.jpeg' dosyası '405.jpeg' olarak değiştirildi.
# '2c7494c4-singleBirdinsky394.jpeg' dosyası '406.jpeg' olarak değiştirildi.
# '2e2d65d7-singleBirdinsky43.jpeg' dosyası '407.jpeg' olarak değiştirildi.
# '2e8bd394-BirdsFlying_46.jpg' dosyası '408.jpg' olarak değiştirildi.
# '3147891e-singleBirdinsky399.jpeg' dosyası '409.jpeg' olarak değiştirildi.
# '317da91e-singleBirdinsky314.jpeg' dosyası '410.jpeg' olarak değiştirildi.
# '320b39e4-singleBirdinsky369.jpeg' dosyası '411.jpeg' olarak değiştirildi.
# '33233d28-singleBirdinsky42.jpeg' dosyası '412.jpeg' olarak değiştirildi.
# '34caa1ff-singleBirdinsky338.jpeg' dosyası '413.jpeg' olarak değiştirildi.
# '37cf37fc-singleBirdinsky366.jpeg' dosyası '414.jpeg' olarak değiştirildi.
# '397d805a-singleBirdinsky57.jpeg' dosyası '415.jpeg' olarak değiştirildi.
# '3a905dcf-singleBirdinsky299.jpeg' dosyası '416.jpeg' olarak değiştirildi.
# '3a9135e9-singleBirdinsky75.jpeg' dosyası '417.jpeg' olarak değiştirildi.
# '3a9e9ee2-BirdsFlying_19.jpg' dosyası '418.jpg' olarak değiştirildi.
# '3aa3fe5f-singleBirdinsky258.jpeg' dosyası '419.jpeg' olarak değiştirildi.
# '3ba7e70c-singleBirdinsky382.jpeg' dosyası '420.jpeg' olarak değiştirildi.
# '3c62bfb4-singleBirdinsky32.jpeg' dosyası '421.jpeg' olarak değiştirildi.
# '3cd0c759-singleBirdinsky390.jpeg' dosyası '422.jpeg' olarak değiştirildi.
# '3d0d363d-singleBirdinsky334.jpeg' dosyası '423.jpeg' olarak değiştirildi.
# '3ea5c6d9-singleBirdinsky293.jpeg' dosyası '424.jpeg' olarak değiştirildi.
# '3efc5f53-singleBirdinsky92.jpeg' dosyası '425.jpeg' olarak değiştirildi.
# '3f58aaad-singleBirdinsky345.jpeg' dosyası '426.jpeg' olarak değiştirildi.
# '407710d3-singleBirdinsky294.jpeg' dosyası '427.jpeg' olarak değiştirildi.
# '41054a5b-singleBirdinsky25.jpeg' dosyası '428.jpeg' olarak değiştirildi.
# '44498f6e-BirdsFlying_87.jpg' dosyası '429.jpg' olarak değiştirildi.
# '44869a98-singleBirdinsky52.jpeg' dosyası '430.jpeg' olarak değiştirildi.
# '458dfb12-BirdsFlying_88.jpg' dosyası '431.jpg' olarak değiştirildi.
# '45a86580-singleBirdinsky78.jpeg' dosyası '432.jpeg' olarak değiştirildi.
# '46350bc4-singleBirdinsky267.jpeg' dosyası '433.jpeg' olarak değiştirildi.
# '46409030-singleBirdinsky0.jpeg' dosyası '434.jpeg' olarak değiştirildi.
# '46cfbe96-singleBirdinsky268.jpeg' dosyası '435.jpeg' olarak değiştirildi.
# '47245b8d-singleBirdinsky94.jpeg' dosyası '436.jpeg' olarak değiştirildi.
# '48d6e2d5-singleBirdinsky257.jpeg' dosyası '437.jpeg' olarak değiştirildi.
# '4938aa51-singleBirdinsky90.jpeg' dosyası '438.jpeg' olarak değiştirildi.
# '49511e80-singleBirdinsky85.jpeg' dosyası '439.jpeg' olarak değiştirildi.
# '49819b2b-singleBirdinsky275.jpeg' dosyası '440.jpeg' olarak değiştirildi.
# '49ea09fc-singleBirdinsky39.jpeg' dosyası '441.jpeg' olarak değiştirildi.
# '49fadd0d-singleBirdinsky378.jpeg' dosyası '442.jpeg' olarak değiştirildi.
# '4b49fd33-singleBirdinsky351.jpeg' dosyası '443.jpeg' olarak değiştirildi.
# '4c531435-BirdsFlying_48.jpg' dosyası '444.jpg' olarak değiştirildi.
# '4f771275-singleBirdinsky391.jpeg' dosyası '445.jpeg' olarak değiştirildi.
# '4fde41b8-singleBirdinsky286.jpeg' dosyası '446.jpeg' olarak değiştirildi.
# '50502e52-singleBirdinsky340.jpeg' dosyası '447.jpeg' olarak değiştirildi.
# '519f56ef-BirdsFlying_77.jpg' dosyası '448.jpg' olarak değiştirildi.
# '5227372a-BirdsFlying_85.jpg' dosyası '449.jpg' olarak değiştirildi.
# '52336bdd-BirdsFlying_41.jpg' dosyası '450.jpg' olarak değiştirildi.
# '5261e3b8-BirdsFlying_70.jpg' dosyası '451.jpg' olarak değiştirildi.
# '52e5791f-singleBirdinsky54.jpeg' dosyası '452.jpeg' olarak değiştirildi.
# '530b50a6-singleBirdinsky374.jpeg' dosyası '453.jpeg' olarak değiştirildi.
# '53ee8b29-singleBirdinsky263.jpeg' dosyası '454.jpeg' olarak değiştirildi.
# '573c8f9e-singleBirdinsky262.jpeg' dosyası '455.jpeg' olarak değiştirildi.
# '57a2fb68-singleBirdinsky343.jpeg' dosyası '456.jpeg' olarak değiştirildi.
# '57f6335b-singleBirdinsky310.jpeg' dosyası '457.jpeg' olarak değiştirildi.
# '588d79df-singleBirdinsky10.jpeg' dosyası '458.jpeg' olarak değiştirildi.
# '58f4b780-BirdsFlying_28.jpg' dosyası '459.jpg' olarak değiştirildi.
# '59aae686-singleBirdinsky64.jpeg' dosyası '460.jpeg' olarak değiştirildi.
# '59c3d30d-singleBirdinsky359.jpeg' dosyası '461.jpeg' olarak değiştirildi.
# '5a4f74f7-singleBirdinsky23.jpeg' dosyası '462.jpeg' olarak değiştirildi.
# '5ac8b469-BirdsFlying_53.jpg' dosyası '463.jpg' olarak değiştirildi.
# '5b0b6e27-singleBirdinsky271.jpeg' dosyası '464.jpeg' olarak değiştirildi.
# '5b6fee58-singleBirdinsky283.jpeg' dosyası '465.jpeg' olarak değiştirildi.
# '5ba67ffd-singleBirdinsky363.jpeg' dosyası '466.jpeg' olarak değiştirildi.
# '5c4c41fd-singleBirdinsky70.jpeg' dosyası '467.jpeg' olarak değiştirildi.
# '5c6afd5d-BirdsFlying_17.jpg' dosyası '468.jpg' olarak değiştirildi.
# '5cbdc193-singleBirdinsky62.jpeg' dosyası '469.jpeg' olarak değiştirildi.
# '5d035a49-singleBirdinsky58.jpeg' dosyası '470.jpeg' olarak değiştirildi.
# '5d74c23d-singleBirdinsky290.jpeg' dosyası '471.jpeg' olarak değiştirildi.
# '5db6e053-singleBirdinsky53.jpeg' dosyası '472.jpeg' olarak değiştirildi.
# '5db9d7a8-singleBirdinsky88.jpeg' dosyası '473.jpeg' olarak değiştirildi.
# '5f851c6f-singleBirdinsky297.jpeg' dosyası '474.jpeg' olarak değiştirildi.
# '6072ed54-singleBirdinsky389.jpeg' dosyası '475.jpeg' olarak değiştirildi.
# '60779026-singleBirdinsky301.jpeg' dosyası '476.jpeg' olarak değiştirildi.
# '6262f3d0-singleBirdinsky87.jpeg' dosyası '477.jpeg' olarak değiştirildi.
# '632c7e69-singleBirdinsky63.jpeg' dosyası '478.jpeg' olarak değiştirildi.
# '63bb9223-BirdsFlying_35.jpg' dosyası '479.jpg' olarak değiştirildi.
# '63bdbf5e-singleBirdinsky26.jpeg' dosyası '480.jpeg' olarak değiştirildi.
# '63d2068f-BirdsFlying_15.jpg' dosyası '481.jpg' olarak değiştirildi.
# '64233198-singleBirdinsky255.jpeg' dosyası '482.jpeg' olarak değiştirildi.
# '64b441d4-BirdsFlying_86.jpg' dosyası '483.jpg' olarak değiştirildi.
# '6531fc8a-BirdsFlying_45.jpg' dosyası '484.jpg' olarak değiştirildi.
# '664cc429-BirdsFlying_92.jpg' dosyası '485.jpg' olarak değiştirildi.
# '681b5c56-singleBirdinsky274.jpeg' dosyası '486.jpeg' olarak değiştirildi.
# '693018be-singleBirdinsky282.jpeg' dosyası '487.jpeg' olarak değiştirildi.
# '6a3e85c5-singleBirdinsky387.jpeg' dosyası '488.jpeg' olarak değiştirildi.
# '6b092561-singleBirdinsky55.jpeg' dosyası '489.jpeg' olarak değiştirildi.
# '6c6f03ed-singleBirdinsky51.jpeg' dosyası '490.jpeg' olarak değiştirildi.
# '6ccb67b0-singleBirdinsky312.jpeg' dosyası '491.jpeg' olarak değiştirildi.
# '6df7c599-BirdsFlying_13.jpg' dosyası '492.jpg' olarak değiştirildi.
# '6e15ba0d-singleBirdinsky397.jpeg' dosyası '493.jpeg' olarak değiştirildi.
# '6e50e3dd-singleBirdinsky22.jpeg' dosyası '494.jpeg' olarak değiştirildi.
# '6f21a479-BirdsFlying_26.jpg' dosyası '495.jpg' olarak değiştirildi.
# '6f96a256-BirdsFlying_66.jpg' dosyası '496.jpg' olarak değiştirildi.
# '70f0ec8e-singleBirdinsky99.jpeg' dosyası '497.jpeg' olarak değiştirildi.
# '71509d84-BirdsFlying_57.jpg' dosyası '498.jpg' olarak değiştirildi.
# '7193c155-singleBirdinsky21.jpeg' dosyası '499.jpeg' olarak değiştirildi.
# '71a74a62-BirdsFlying_49.jpg' dosyası '500.jpg' olarak değiştirildi.
# '7202a32a-singleBirdinsky289.jpeg' dosyası '501.jpeg' olarak değiştirildi.
# '74d3336e-singleBirdinsky68.jpeg' dosyası '502.jpeg' olarak değiştirildi.
# '76e96f39-singleBirdinsky295.jpeg' dosyası '503.jpeg' olarak değiştirildi.
# '7711fc38-singleBirdinsky279.jpeg' dosyası '504.jpeg' olarak değiştirildi.
# '771919f4-BirdsFlying_33.jpg' dosyası '505.jpg' olarak değiştirildi.
# '772a0264-BirdsFlying_82.jpg' dosyası '506.jpg' olarak değiştirildi.
# '78584bc3-singleBirdinsky380.jpeg' dosyası '507.jpeg' olarak değiştirildi.
# '78fec515-singleBirdinsky13.jpeg' dosyası '508.jpeg' olarak değiştirildi.
# '79194f64-singleBirdinsky4.jpeg' dosyası '509.jpeg' olarak değiştirildi.
# '7933e628-singleBirdinsky388.jpeg' dosyası '510.jpeg' olarak değiştirildi.
# '7a13198b-singleBirdinsky303.jpeg' dosyası '511.jpeg' olarak değiştirildi.
# '7a2cd2b4-singleBirdinsky371.jpeg' dosyası '512.jpeg' olarak değiştirildi.
# '7a7546fe-singleBirdinsky17.jpeg' dosyası '513.jpeg' olarak değiştirildi.
# '7ae22701-singleBirdinsky45.jpeg' dosyası '514.jpeg' olarak değiştirildi.
# '7c5fc42f-singleBirdinsky365.jpeg' dosyası '515.jpeg' olarak değiştirildi.
# '7cde6cde-singleBirdinsky44.jpeg' dosyası '516.jpeg' olarak değiştirildi.
# '8053ae54-BirdsFlying_12.jpg' dosyası '517.jpg' olarak değiştirildi.
# '80d92f41-singleBirdinsky280.jpeg' dosyası '518.jpeg' olarak değiştirildi.
# '8162cbbb-singleBirdinsky324.jpeg' dosyası '519.jpeg' olarak değiştirildi.
# '81b67b84-singleBirdinsky379.jpeg' dosyası '520.jpeg' olarak değiştirildi.
# '8275ef4b-singleBirdinsky83.jpeg' dosyası '521.jpeg' olarak değiştirildi.
# '82d36d13-BirdsFlying_61.jpg' dosyası '522.jpg' olarak değiştirildi.
# '82e7089d-singleBirdinsky350.jpeg' dosyası '523.jpeg' olarak değiştirildi.
# '830b0046-singleBirdinsky360.jpeg' dosyası '524.jpeg' olarak değiştirildi.
# '847a8c83-singleBirdinsky269.jpeg' dosyası '525.jpeg' olarak değiştirildi.
# '855af4b4-singleBirdinsky335.jpeg' dosyası '526.jpeg' olarak değiştirildi.
# '861f5e5a-BirdsFlying_58.jpg' dosyası '527.jpg' olarak değiştirildi.
# '885a647a-BirdsFlying_68.jpg' dosyası '528.jpg' olarak değiştirildi.
# '8907c212-singleBirdinsky20.jpeg' dosyası '529.jpeg' olarak değiştirildi.
# '8c2bb288-BirdsFlying_65.jpg' dosyası '530.jpg' olarak değiştirildi.
# '8c54c00d-singleBirdinsky56.jpeg' dosyası '531.jpeg' olarak değiştirildi.
# '8cc41cb5-singleBirdinsky276.jpeg' dosyası '532.jpeg' olarak değiştirildi.
# '8cfe1708-singleBirdinsky270.jpeg' dosyası '533.jpeg' olarak değiştirildi.
# '8f331e26-singleBirdinsky356.jpeg' dosyası '534.jpeg' olarak değiştirildi.
# '8f422e83-singleBirdinsky34.jpeg' dosyası '535.jpeg' olarak değiştirildi.
# '906a30c4-singleBirdinsky259.jpeg' dosyası '536.jpeg' olarak değiştirildi.
# '91434aab-singleBirdinsky346.jpeg' dosyası '537.jpeg' olarak değiştirildi.
# '9245f1f4-singleBirdinsky296.jpeg' dosyası '538.jpeg' olarak değiştirildi.
# '93f58bcc-singleBirdinsky278.jpeg' dosyası '539.jpeg' olarak değiştirildi.
# '94041976-singleBirdinsky93.jpeg' dosyası '540.jpeg' olarak değiştirildi.
# '948eaec8-singleBirdinsky395.jpeg' dosyası '541.jpeg' olarak değiştirildi.
# '95fa5d36-singleBirdinsky364.jpeg' dosyası '542.jpeg' olarak değiştirildi.
# '9691cc03-BirdsFlying_37.jpg' dosyası '543.jpg' olarak değiştirildi.
# '96e12139-BirdsFlying_6.jpg' dosyası '544.jpg' olarak değiştirildi.
# '96e6abef-singleBirdinsky2.jpeg' dosyası '545.jpeg' olarak değiştirildi.
# '96e926d8-BirdsFlying_16.jpg' dosyası '546.jpg' olarak değiştirildi.
# '96f47643-singleBirdinsky375.jpeg' dosyası '547.jpeg' olarak değiştirildi.
# '97da69e6-BirdsFlying_9.jpg' dosyası '548.jpg' olarak değiştirildi.
# '991c5f0d-BirdsFlying_43.jpg' dosyası '549.jpg' olarak değiştirildi.
# '9a224791-singleBirdinsky95.jpeg' dosyası '550.jpeg' olarak değiştirildi.
# '9b9a31cb-singleBirdinsky308.jpeg' dosyası '551.jpeg' olarak değiştirildi.
# '9bf4b3d6-BirdsFlying_93.jpg' dosyası '552.jpg' olarak değiştirildi.
# '9cf82070-BirdsFlying_32.jpg' dosyası '553.jpg' olarak değiştirildi.
# '9dfe2852-singleBirdinsky84.jpeg' dosyası '554.jpeg' olarak değiştirildi.
# '9e6644bb-singleBirdinsky317.jpeg' dosyası '555.jpeg' olarak değiştirildi.
# '9fdfc9b7-singleBirdinsky38.jpeg' dosyası '556.jpeg' olarak değiştirildi.
# 'a04f7d3c-singleBirdinsky353.jpeg' dosyası '557.jpeg' olarak değiştirildi.
# 'a0a22a09-singleBirdinsky7.jpeg' dosyası '558.jpeg' olarak değiştirildi.
# 'a1eabb9b-singleBirdinsky355.jpeg' dosyası '559.jpeg' olarak değiştirildi.
# 'a2531b9c-singleBirdinsky16.jpeg' dosyası '560.jpeg' olarak değiştirildi.
# 'a3667e49-singleBirdinsky362.jpeg' dosyası '561.jpeg' olarak değiştirildi.
# 'a36afc79-singleBirdinsky326.jpeg' dosyası '562.jpeg' olarak değiştirildi.
# 'a36e273a-BirdsFlying_81.jpg' dosyası '563.jpg' olarak değiştirildi.
# 'a4cff496-BirdsFlying_55.jpg' dosyası '564.jpg' olarak değiştirildi.
# 'a4e00d62-singleBirdinsky300.jpeg' dosyası '565.jpeg' olarak değiştirildi.
# 'a68afb5f-BirdsFlying_31.jpg' dosyası '566.jpg' olarak değiştirildi.
# 'a69bd298-singleBirdinsky49.jpeg' dosyası '567.jpeg' olarak değiştirildi.
# 'a69cdddf-singleBirdinsky98.jpeg' dosyası '568.jpeg' olarak değiştirildi.
# 'a793430d-BirdsFlying_75.jpg' dosyası '569.jpg' olarak değiştirildi.
# 'a8857efe-singleBirdinsky323.jpeg' dosyası '570.jpeg' olarak değiştirildi.
# 'ab497272-BirdsFlying_20.jpg' dosyası '571.jpg' olarak değiştirildi.
# 'ad2e65d8-singleBirdinsky386.jpeg' dosyası '572.jpeg' olarak değiştirildi.
# 'ad989ce9-BirdsFlying_56.jpg' dosyası '573.jpg' olarak değiştirildi.
# 'aec4235a-singleBirdinsky27.jpeg' dosyası '574.jpeg' olarak değiştirildi.
# 'afae4680-singleBirdinsky319.jpeg' dosyası '575.jpeg' olarak değiştirildi.
# 'afe2f869-BirdsFlying_73.jpg' dosyası '576.jpg' olarak değiştirildi.
# 'b15212e1-singleBirdinsky60.jpeg' dosyası '577.jpeg' olarak değiştirildi.
# 'b168e71f-BirdsFlying_71.jpg' dosyası '578.jpg' olarak değiştirildi.
# 'b20dd9f1-singleBirdinsky305.jpeg' dosyası '579.jpeg' olarak değiştirildi.
# 'b337d171-singleBirdinsky260.jpeg' dosyası '580.jpeg' olarak değiştirildi.
# 'b34934dc-singleBirdinsky6.jpeg' dosyası '581.jpeg' olarak değiştirildi.
# 'b37a6528-BirdsFlying_60.jpg' dosyası '582.jpg' olarak değiştirildi.
# 'b41625e8-singleBirdinsky28.jpeg' dosyası '583.jpeg' olarak değiştirildi.
# 'b4369565-singleBirdinsky76.jpeg' dosyası '584.jpeg' olarak değiştirildi.
# 'b492a3e7-BirdsFlying_95.jpg' dosyası '585.jpg' olarak değiştirildi.
# 'b56c2240-BirdsFlying_50.jpg' dosyası '586.jpg' olarak değiştirildi.
# 'b59337b7-BirdsFlying_54.jpg' dosyası '587.jpg' olarak değiştirildi.
# 'b5f73620-singleBirdinsky100.jpeg' dosyası '588.jpeg' olarak değiştirildi.
# 'b7a0aaef-BirdsFlying_34.jpg' dosyası '589.jpg' olarak değiştirildi.
# 'b8f93a93-singleBirdinsky291.jpeg' dosyası '590.jpeg' olarak değiştirildi.
# 'bab4f15b-singleBirdinsky47.jpeg' dosyası '591.jpeg' olarak değiştirildi.
# 'baf46f79-BirdsFlying_40.jpg' dosyası '592.jpg' olarak değiştirildi.
# 'bc1cfd29-BirdsFlying_3.jpg' dosyası '593.jpg' olarak değiştirildi.
# 'bc900bc9-singleBirdinsky82.jpeg' dosyası '594.jpeg' olarak değiştirildi.
# 'bdb2c939-singleBirdinsky327.jpeg' dosyası '595.jpeg' olarak değiştirildi.
# 'bdf43445-singleBirdinsky254.jpeg' dosyası '596.jpeg' olarak değiştirildi.
# 'bed2730b-BirdsFlying_7.jpg' dosyası '597.jpg' olarak değiştirildi.
# 'c0338078-BirdsFlying_62.jpg' dosyası '598.jpg' olarak değiştirildi.
# 'c0c0fa95-singleBirdinsky74.jpeg' dosyası '599.jpeg' olarak değiştirildi.
# 'c0e329a3-singleBirdinsky272.jpeg' dosyası '600.jpeg' olarak değiştirildi.
# 'c2888d94-singleBirdinsky40.jpeg' dosyası '601.jpeg' olarak değiştirildi.
# 'c2ac1144-singleBirdinsky31.jpeg' dosyası '602.jpeg' olarak değiştirildi.
# 'c2c9b4cb-singleBirdinsky30.jpeg' dosyası '603.jpeg' olarak değiştirildi.
# 'c3cb682a-singleBirdinsky37.jpeg' dosyası '604.jpeg' olarak değiştirildi.
# 'c3f66c65-singleBirdinsky329.jpeg' dosyası '605.jpeg' olarak değiştirildi.
# 'c44f8fc1-singleBirdinsky14.jpeg' dosyası '606.jpeg' olarak değiştirildi.
# 'c540d90a-singleBirdinsky33.jpeg' dosyası '607.jpeg' olarak değiştirildi.
# 'c6386cba-singleBirdinsky352.jpeg' dosyası '608.jpeg' olarak değiştirildi.
# 'c79fde15-singleBirdinsky376.jpeg' dosyası '609.jpeg' olarak değiştirildi.
# 'c7abc7ae-singleBirdinsky61.jpeg' dosyası '610.jpeg' olarak değiştirildi.
# 'c7b7afed-singleBirdinsky349.jpeg' dosyası '611.jpeg' olarak değiştirildi.
# 'c7dc6a8e-singleBirdinsky330.jpeg' dosyası '612.jpeg' olarak değiştirildi.
# 'c97ddb6b-singleBirdinsky281.jpeg' dosyası '613.jpeg' olarak değiştirildi.
# 'ca727928-singleBirdinsky385.jpeg' dosyası '614.jpeg' olarak değiştirildi.
# 'cfd3e618-singleBirdinsky373.jpeg' dosyası '615.jpeg' olarak değiştirildi.
# 'd0d4c5c2-BirdsFlying_44.jpg' dosyası '616.jpg' olarak değiştirildi.
# 'd420bb3b-singleBirdinsky315.jpeg' dosyası '617.jpeg' olarak değiştirildi.
# 'd45de038-BirdsFlying_63.jpg' dosyası '618.jpg' olarak değiştirildi.
# 'd5850b02-singleBirdinsky370.jpeg' dosyası '619.jpeg' olarak değiştirildi.
# 'd70ed0f3-singleBirdinsky69.jpeg' dosyası '620.jpeg' olarak değiştirildi.
# 'd976db0a-singleBirdinsky65.jpeg' dosyası '621.jpeg' olarak değiştirildi.
# 'd97b08fd-BirdsFlying_29.jpg' dosyası '622.jpg' olarak değiştirildi.
# 'da4c61de-singleBirdinsky313.jpeg' dosyası '623.jpeg' olarak değiştirildi.
# 'db9075ce-singleBirdinsky35.jpeg' dosyası '624.jpeg' olarak değiştirildi.
# 'dbbc4187-singleBirdinsky77.jpeg' dosyası '625.jpeg' olarak değiştirildi.
# 'dc2080a9-BirdsFlying_78.jpg' dosyası '626.jpg' olarak değiştirildi.
# 'dc57d665-singleBirdinsky12.jpeg' dosyası '627.jpeg' olarak değiştirildi.
# 'dcdefe6b-singleBirdinsky368.jpeg' dosyası '628.jpeg' olarak değiştirildi.
# 'dcdfe876-BirdsFlying_51.jpg' dosyası '629.jpg' olarak değiştirildi.
# 'dce9cc17-singleBirdinsky287.jpeg' dosyası '630.jpeg' olarak değiştirildi.
# 'dcf00cc6-singleBirdinsky361.jpeg' dosyası '631.jpeg' olarak değiştirildi.
# 'dd1a5565-singleBirdinsky357.jpeg' dosyası '632.jpeg' olarak değiştirildi.
# 'dd797f7d-BirdsFlying_69.jpg' dosyası '633.jpg' olarak değiştirildi.
# 'dd9c8e64-singleBirdinsky36.jpeg' dosyası '634.jpeg' olarak değiştirildi.
# 'ddb99ef6-singleBirdinsky266.jpeg' dosyası '635.jpeg' olarak değiştirildi.
# 'de8ae1bd-singleBirdinsky332.jpeg' dosyası '636.jpeg' olarak değiştirildi.
# 'de9c161c-BirdsFlying_25.jpg' dosyası '637.jpg' olarak değiştirildi.
# 'decf6a00-singleBirdinsky11.jpeg' dosyası '638.jpeg' olarak değiştirildi.
# 'df3e8dad-singleBirdinsky396.jpeg' dosyası '639.jpeg' olarak değiştirildi.
# 'df8f6236-BirdsFlying_52.jpg' dosyası '640.jpg' olarak değiştirildi.
# 'e09799af-BirdsFlying_27.jpg' dosyası '641.jpg' olarak değiştirildi.
# 'e1137d7a-BirdsFlying_59.jpg' dosyası '642.jpg' olarak değiştirildi.
# 'e121efa7-singleBirdinsky97.jpeg' dosyası '643.jpeg' olarak değiştirildi.
# 'e19ac38b-singleBirdinsky344.jpeg' dosyası '644.jpeg' olarak değiştirildi.
# 'e1da50b9-BirdsFlying_94.jpg' dosyası '645.jpg' olarak değiştirildi.
# 'e3039681-singleBirdinsky59.jpeg' dosyası '646.jpeg' olarak değiştirildi.
# 'e33b0129-singleBirdinsky265.jpeg' dosyası '647.jpeg' olarak değiştirildi.
# 'e486f84a-BirdsFlying_14.jpg' dosyası '648.jpg' olarak değiştirildi.
# 'e517ea5e-singleBirdinsky15.jpeg' dosyası '649.jpeg' olarak değiştirildi.
# 'e5656bae-singleBirdinsky372.jpeg' dosyası '650.jpeg' olarak değiştirildi.
# 'e61a80b4-singleBirdinsky309.jpeg' dosyası '651.jpeg' olarak değiştirildi.
# 'e8d40c43-singleBirdinsky307.jpeg' dosyası '652.jpeg' olarak değiştirildi.
# 'e99342cc-singleBirdinsky101.jpeg' dosyası '653.jpeg' olarak değiştirildi.
# 'eac7e99b-BirdsFlying_64.jpg' dosyası '654.jpg' olarak değiştirildi.
# 'eb5202ee-BirdsFlying_99.jpg' dosyası '655.jpg' olarak değiştirildi.
# 'eb5a11bd-singleBirdinsky298.jpeg' dosyası '656.jpeg' olarak değiştirildi.
# 'eb5b939f-singleBirdinsky285.jpeg' dosyası '657.jpeg' olarak değiştirildi.
# 'ebfec92e-singleBirdinsky322.jpeg' dosyası '658.jpeg' olarak değiştirildi.
# 'ec002da0-BirdsFlying_83.jpg' dosyası '659.jpg' olarak değiştirildi.
# 'ec969a39-singleBirdinsky86.jpeg' dosyası '660.jpeg' olarak değiştirildi.
# 'edc46316-singleBirdinsky277.jpeg' dosyası '661.jpeg' olarak değiştirildi.
# 'edd6883a-singleBirdinsky384.jpeg' dosyası '662.jpeg' olarak değiştirildi.
# 'ef04f342-singleBirdinsky71.jpeg' dosyası '663.jpeg' olarak değiştirildi.
# 'f009ec1f-BirdsFlying_4.jpg' dosyası '664.jpg' olarak değiştirildi.
# 'f0533c9d-BirdsFlying_97.jpg' dosyası '665.jpg' olarak değiştirildi.
# 'f059d232-BirdsFlying_8.jpg' dosyası '666.jpg' olarak değiştirildi.
# 'f11710a8-singleBirdinsky341.jpeg' dosyası '667.jpeg' olarak değiştirildi.
# 'f135cbc3-singleBirdinsky358.jpeg' dosyası '668.jpeg' olarak değiştirildi.
# 'f160b739-singleBirdinsky46.jpeg' dosyası '669.jpeg' olarak değiştirildi.
# 'f1fcd495-singleBirdinsky261.jpeg' dosyası '670.jpeg' olarak değiştirildi.
# 'f202ac08-singleBirdinsky73.jpeg' dosyası '671.jpeg' olarak değiştirildi.
# 'f281bbef-singleBirdinsky91.jpeg' dosyası '672.jpeg' olarak değiştirildi.
# 'f2eea839-singleBirdinsky302.jpeg' dosyası '673.jpeg' olarak değiştirildi.
# 'f3122b69-singleBirdinsky72.jpeg' dosyası '674.jpeg' olarak değiştirildi.
# 'f3554d84-singleBirdinsky304.jpeg' dosyası '675.jpeg' olarak değiştirildi.
# 'f38238d3-singleBirdinsky79.jpeg' dosyası '676.jpeg' olarak değiştirildi.
# 'f3aad9d7-BirdsFlying_96.jpg' dosyası '677.jpg' olarak değiştirildi.
# 'f3db90d1-singleBirdinsky316.jpeg' dosyası '678.jpeg' olarak değiştirildi.
# 'f4896dce-singleBirdinsky96.jpeg' dosyası '679.jpeg' olarak değiştirildi.
# 'f50820b9-BirdsFlying_79.jpg' dosyası '680.jpg' olarak değiştirildi.
# 'f64053c2-singleBirdinsky321.jpeg' dosyası '681.jpeg' olarak değiştirildi.
# 'f6a0173a-singleBirdinsky48.jpeg' dosyası '682.jpeg' olarak değiştirildi.
# 'f79db98f-BirdsFlying_80.jpg' dosyası '683.jpg' olarak değiştirildi.
# 'f7e896f1-singleBirdinsky320.jpeg' dosyası '684.jpeg' olarak değiştirildi.
# 'fa787f8e-singleBirdinsky9.jpeg' dosyası '685.jpeg' olarak değiştirildi.
# 'fa86d27f-BirdsFlying_30.jpg' dosyası '686.jpg' olarak değiştirildi.
# 'facd524b-1389024_27c2560c5b4dab0e756b013ce3321cfe_640x640.jpg' dosyası '687.jpg' olarak değiştirildi.
# 'fb3cb273-BirdsFlying_42.jpg' dosyası '688.jpg' olarak değiştirildi.
# 'fb4c4f03-BirdsFlying_21.jpg' dosyası '689.jpg' olarak değiştirildi.
# 'fbf068f5-BirdsFlying_89.jpg' dosyası '690.jpg' olarak değiştirildi.
# 'fc20d621-singleBirdinsky333.jpeg' dosyası '691.jpeg' olarak değiştirildi.
# 'fc3aaa7a-singleBirdinsky325.jpeg' dosyası '692.jpeg' olarak değiştirildi.
# 'fe033844-singleBirdinsky29.jpeg' dosyası '693.jpeg' olarak değiştirildi.
# 'ff6e9784-singleBirdinsky347.jpeg' dosyası '694.jpeg' olarak değiştirildi.
# Dosya isimlendirme işlemi tamamlandı.

# %%
import os

# Dosyaların bulunduğu klasörün yolu
folder_path = 'C:/Users/edana/Desktop/dataset_new/Bird/resized_images'

# Dosya isimlerini değiştirmek için başlangıç numarası
start_number = 695
end_number = 1100

# Klasördeki tüm dosyaları al
files = os.listdir(folder_path)

# Sadece dosya olanları al (klasörleri hariç tut)
files = [f for f in files if os.path.isfile(os.path.join(folder_path, f))]

# Dosyaları sıralı olarak yeniden isimlendirme işlemi
for i, file_name in enumerate(files):
    if i < end_number:
        # Dosyanın uzantısını al
        file_extension = os.path.splitext(file_name)[1]
        # Yeni dosya adını oluştur
        new_name = f"{start_number + i}{file_extension}"
        # Eski ve yeni dosya yollarını oluştur
        old_file_path = os.path.join(folder_path, file_name)
        new_file_path = os.path.join(folder_path, new_name)
        # Dosya ismini değiştir
        os.rename(old_file_path, new_file_path)
        print(f"'{file_name}' dosyası '{new_name}' olarak değiştirildi.")
    else:
        break

print("Dosya isimlendirme işlemi tamamlandı.")
# Out:
# '00c384a2-singleBirdinsky50.jpeg' dosyası '695.jpeg' olarak değiştirildi.
# '01706918-singleBirdinsky81.jpeg' dosyası '696.jpeg' olarak değiştirildi.
# '0319e725-singleBirdinsky24.jpeg' dosyası '697.jpeg' olarak değiştirildi.
# '0496a2af-BirdsFlying_2.jpg' dosyası '698.jpg' olarak değiştirildi.
# '04af7fdd-BirdsFlying_38.jpg' dosyası '699.jpg' olarak değiştirildi.
# '05a04b01-BirdsFlying_18.jpg' dosyası '700.jpg' olarak değiştirildi.
# '0652642b-BirdsFlying_91.jpg' dosyası '701.jpg' olarak değiştirildi.
# '06e09c85-BirdsFlying_98.jpg' dosyası '702.jpg' olarak değiştirildi.
# '083588e5-BirdsFlying_23.jpg' dosyası '703.jpg' olarak değiştirildi.
# '096c5b6a-singleBirdinsky253.jpeg' dosyası '704.jpeg' olarak değiştirildi.
# '096ca146-BirdsFlying_72.jpg' dosyası '705.jpg' olarak değiştirildi.
# '09f4a437-BirdsFlying_67.jpg' dosyası '706.jpg' olarak değiştirildi.
# '0a818092-singleBirdinsky306.jpeg' dosyası '707.jpeg' olarak değiştirildi.
# '0c154f58-singleBirdinsky3.jpeg' dosyası '708.jpeg' olarak değiştirildi.
# '0c7232be-singleBirdinsky336.jpeg' dosyası '709.jpeg' olarak değiştirildi.
# '0da11122-singleBirdinsky393.jpeg' dosyası '710.jpeg' olarak değiştirildi.
# '0e900c14-singleBirdinsky288.jpeg' dosyası '711.jpeg' olarak değiştirildi.
# '0ebc3a4f-singleBirdinsky41.jpeg' dosyası '712.jpeg' olarak değiştirildi.
# '10a41ba2-BirdsFlying_22.jpg' dosyası '713.jpg' olarak değiştirildi.
# '10e665f5-singleBirdinsky264.jpeg' dosyası '714.jpeg' olarak değiştirildi.
# '1103dfd4-singleBirdinsky383.jpeg' dosyası '715.jpeg' olarak değiştirildi.
# '11782edd-BirdsFlying_36.jpg' dosyası '716.jpg' olarak değiştirildi.
# '118daf0d-singleBirdinsky18.webp' dosyası '717.webp' olarak değiştirildi.
# '12fe3e3a-singleBirdinsky89.jpeg' dosyası '718.jpeg' olarak değiştirildi.
# '12fed2b4-singleBirdinsky102.jpeg' dosyası '719.jpeg' olarak değiştirildi.
# '151b71a7-singleBirdinsky66.jpeg' dosyası '720.jpeg' olarak değiştirildi.
# '15c3d099-singleBirdinsky284.jpeg' dosyası '721.jpeg' olarak değiştirildi.
# '15e1590b-singleBirdinsky5.jpeg' dosyası '722.jpeg' olarak değiştirildi.
# '1687157c-singleBirdinsky400.jpeg' dosyası '723.jpeg' olarak değiştirildi.
# '17772976-BirdsFlying_74.jpg' dosyası '724.jpg' olarak değiştirildi.
# '180fbf18-BirdsFlying_100.jpg' dosyası '725.jpg' olarak değiştirildi.
# '182e77e9-singleBirdinsky339.jpeg' dosyası '726.jpeg' olarak değiştirildi.
# '18eb8f35-BirdsFlying_5.jpg' dosyası '727.jpg' olarak değiştirildi.
# '1978edc0-singleBirdinsky328.jpeg' dosyası '728.jpeg' olarak değiştirildi.
# '1b748c32-singleBirdinsky273.jpeg' dosyası '729.jpeg' olarak değiştirildi.
# '1c2cddb7-singleBirdinsky398.jpeg' dosyası '730.jpeg' olarak değiştirildi.
# '1c8f463b-BirdsFlying_76.jpg' dosyası '731.jpg' olarak değiştirildi.
# '1d91fb02-singleBirdinsky67.jpeg' dosyası '732.jpeg' olarak değiştirildi.
# '1db47a06-BirdsFlying_1.jpg' dosyası '733.jpg' olarak değiştirildi.
# '1dffb844-BirdsFlying_39.jpg' dosyası '734.jpg' olarak değiştirildi.
# '1e5b48e9-singleBirdinsky80.jpeg' dosyası '735.jpeg' olarak değiştirildi.
# '1e6921bf-BirdsFlying_24.jpg' dosyası '736.jpg' olarak değiştirildi.
# '1f1e669a-BirdsFlying_11.jpg' dosyası '737.jpg' olarak değiştirildi.
# '1f8d389c-BirdsFlying_84.jpg' dosyası '738.jpg' olarak değiştirildi.
# '20e841c9-BirdsFlying_47.jpg' dosyası '739.jpg' olarak değiştirildi.
# '20f647c6-singleBirdinsky292.jpeg' dosyası '740.jpeg' olarak değiştirildi.
# '2185b228-singleBirdinsky331.jpeg' dosyası '741.jpeg' olarak değiştirildi.
# '240fa050-singleBirdinsky377.jpeg' dosyası '742.jpeg' olarak değiştirildi.
# '242dc811-singleBirdinsky311.jpeg' dosyası '743.jpeg' olarak değiştirildi.
# '243fa17c-BirdsFlying_90.jpg' dosyası '744.jpg' olarak değiştirildi.
# '2532d08c-singleBirdinsky1.jpeg' dosyası '745.jpeg' olarak değiştirildi.
# '26e07423-singleBirdinsky392.jpeg' dosyası '746.jpeg' olarak değiştirildi.
# '27934706-BirdsFlying_10.jpg' dosyası '747.jpg' olarak değiştirildi.
# '281dce8d-singleBirdinsky256.jpeg' dosyası '748.jpeg' olarak değiştirildi.
# '284b8596-singleBirdinsky19.webp' dosyası '749.webp' olarak değiştirildi.
# '2925913b-singleBirdinsky337.jpeg' dosyası '750.jpeg' olarak değiştirildi.
# '2954b105-singleBirdinsky348.jpeg' dosyası '751.jpeg' olarak değiştirildi.
# '2c41a790-singleBirdinsky318.jpeg' dosyası '752.jpeg' olarak değiştirildi.
# '2c7494c4-singleBirdinsky394.jpeg' dosyası '753.jpeg' olarak değiştirildi.
# '2e2d65d7-singleBirdinsky43.jpeg' dosyası '754.jpeg' olarak değiştirildi.
# '2e8bd394-BirdsFlying_46.jpg' dosyası '755.jpg' olarak değiştirildi.
# '3147891e-singleBirdinsky399.jpeg' dosyası '756.jpeg' olarak değiştirildi.
# '317da91e-singleBirdinsky314.jpeg' dosyası '757.jpeg' olarak değiştirildi.
# '320b39e4-singleBirdinsky369.jpeg' dosyası '758.jpeg' olarak değiştirildi.
# '33233d28-singleBirdinsky42.jpeg' dosyası '759.jpeg' olarak değiştirildi.
# '34caa1ff-singleBirdinsky338.jpeg' dosyası '760.jpeg' olarak değiştirildi.
# '37cf37fc-singleBirdinsky366.jpeg' dosyası '761.jpeg' olarak değiştirildi.
# '397d805a-singleBirdinsky57.jpeg' dosyası '762.jpeg' olarak değiştirildi.
# '3a905dcf-singleBirdinsky299.jpeg' dosyası '763.jpeg' olarak değiştirildi.
# '3a9135e9-singleBirdinsky75.jpeg' dosyası '764.jpeg' olarak değiştirildi.
# '3a9e9ee2-BirdsFlying_19.jpg' dosyası '765.jpg' olarak değiştirildi.
# '3aa3fe5f-singleBirdinsky258.jpeg' dosyası '766.jpeg' olarak değiştirildi.
# '3ba7e70c-singleBirdinsky382.jpeg' dosyası '767.jpeg' olarak değiştirildi.
# '3c62bfb4-singleBirdinsky32.jpeg' dosyası '768.jpeg' olarak değiştirildi.
# '3cd0c759-singleBirdinsky390.jpeg' dosyası '769.jpeg' olarak değiştirildi.
# '3d0d363d-singleBirdinsky334.jpeg' dosyası '770.jpeg' olarak değiştirildi.
# '3ea5c6d9-singleBirdinsky293.jpeg' dosyası '771.jpeg' olarak değiştirildi.
# '3efc5f53-singleBirdinsky92.jpeg' dosyası '772.jpeg' olarak değiştirildi.
# '3f58aaad-singleBirdinsky345.jpeg' dosyası '773.jpeg' olarak değiştirildi.
# '407710d3-singleBirdinsky294.jpeg' dosyası '774.jpeg' olarak değiştirildi.
# '41054a5b-singleBirdinsky25.jpeg' dosyası '775.jpeg' olarak değiştirildi.
# '44498f6e-BirdsFlying_87.jpg' dosyası '776.jpg' olarak değiştirildi.
# '44869a98-singleBirdinsky52.jpeg' dosyası '777.jpeg' olarak değiştirildi.
# '458dfb12-BirdsFlying_88.jpg' dosyası '778.jpg' olarak değiştirildi.
# '45a86580-singleBirdinsky78.jpeg' dosyası '779.jpeg' olarak değiştirildi.
# '46350bc4-singleBirdinsky267.jpeg' dosyası '780.jpeg' olarak değiştirildi.
# '46409030-singleBirdinsky0.jpeg' dosyası '781.jpeg' olarak değiştirildi.
# '46cfbe96-singleBirdinsky268.jpeg' dosyası '782.jpeg' olarak değiştirildi.
# '47245b8d-singleBirdinsky94.jpeg' dosyası '783.jpeg' olarak değiştirildi.
# '48d6e2d5-singleBirdinsky257.jpeg' dosyası '784.jpeg' olarak değiştirildi.
# '4938aa51-singleBirdinsky90.jpeg' dosyası '785.jpeg' olarak değiştirildi.
# '49511e80-singleBirdinsky85.jpeg' dosyası '786.jpeg' olarak değiştirildi.
# '49819b2b-singleBirdinsky275.jpeg' dosyası '787.jpeg' olarak değiştirildi.
# '49ea09fc-singleBirdinsky39.jpeg' dosyası '788.jpeg' olarak değiştirildi.
# '49fadd0d-singleBirdinsky378.jpeg' dosyası '789.jpeg' olarak değiştirildi.
# '4b49fd33-singleBirdinsky351.jpeg' dosyası '790.jpeg' olarak değiştirildi.
# '4c531435-BirdsFlying_48.jpg' dosyası '791.jpg' olarak değiştirildi.
# '4f771275-singleBirdinsky391.jpeg' dosyası '792.jpeg' olarak değiştirildi.
# '4fde41b8-singleBirdinsky286.jpeg' dosyası '793.jpeg' olarak değiştirildi.
# '50502e52-singleBirdinsky340.jpeg' dosyası '794.jpeg' olarak değiştirildi.
# '519f56ef-BirdsFlying_77.jpg' dosyası '795.jpg' olarak değiştirildi.
# '5227372a-BirdsFlying_85.jpg' dosyası '796.jpg' olarak değiştirildi.
# '52336bdd-BirdsFlying_41.jpg' dosyası '797.jpg' olarak değiştirildi.
# '5261e3b8-BirdsFlying_70.jpg' dosyası '798.jpg' olarak değiştirildi.
# '52e5791f-singleBirdinsky54.jpeg' dosyası '799.jpeg' olarak değiştirildi.
# '530b50a6-singleBirdinsky374.jpeg' dosyası '800.jpeg' olarak değiştirildi.
# '53ee8b29-singleBirdinsky263.jpeg' dosyası '801.jpeg' olarak değiştirildi.
# '573c8f9e-singleBirdinsky262.jpeg' dosyası '802.jpeg' olarak değiştirildi.
# '57a2fb68-singleBirdinsky343.jpeg' dosyası '803.jpeg' olarak değiştirildi.
# '57f6335b-singleBirdinsky310.jpeg' dosyası '804.jpeg' olarak değiştirildi.
# '588d79df-singleBirdinsky10.jpeg' dosyası '805.jpeg' olarak değiştirildi.
# '58f4b780-BirdsFlying_28.jpg' dosyası '806.jpg' olarak değiştirildi.
# '59aae686-singleBirdinsky64.jpeg' dosyası '807.jpeg' olarak değiştirildi.
# '59c3d30d-singleBirdinsky359.jpeg' dosyası '808.jpeg' olarak değiştirildi.
# '5a4f74f7-singleBirdinsky23.jpeg' dosyası '809.jpeg' olarak değiştirildi.
# '5ac8b469-BirdsFlying_53.jpg' dosyası '810.jpg' olarak değiştirildi.
# '5b0b6e27-singleBirdinsky271.jpeg' dosyası '811.jpeg' olarak değiştirildi.
# '5b6fee58-singleBirdinsky283.jpeg' dosyası '812.jpeg' olarak değiştirildi.
# '5ba67ffd-singleBirdinsky363.jpeg' dosyası '813.jpeg' olarak değiştirildi.
# '5c4c41fd-singleBirdinsky70.jpeg' dosyası '814.jpeg' olarak değiştirildi.
# '5c6afd5d-BirdsFlying_17.jpg' dosyası '815.jpg' olarak değiştirildi.
# '5cbdc193-singleBirdinsky62.jpeg' dosyası '816.jpeg' olarak değiştirildi.
# '5d035a49-singleBirdinsky58.jpeg' dosyası '817.jpeg' olarak değiştirildi.
# '5d74c23d-singleBirdinsky290.jpeg' dosyası '818.jpeg' olarak değiştirildi.
# '5db6e053-singleBirdinsky53.jpeg' dosyası '819.jpeg' olarak değiştirildi.
# '5db9d7a8-singleBirdinsky88.jpeg' dosyası '820.jpeg' olarak değiştirildi.
# '5f851c6f-singleBirdinsky297.jpeg' dosyası '821.jpeg' olarak değiştirildi.
# '6072ed54-singleBirdinsky389.jpeg' dosyası '822.jpeg' olarak değiştirildi.
# '60779026-singleBirdinsky301.jpeg' dosyası '823.jpeg' olarak değiştirildi.
# '6262f3d0-singleBirdinsky87.jpeg' dosyası '824.jpeg' olarak değiştirildi.
# '632c7e69-singleBirdinsky63.jpeg' dosyası '825.jpeg' olarak değiştirildi.
# '63bb9223-BirdsFlying_35.jpg' dosyası '826.jpg' olarak değiştirildi.
# '63bdbf5e-singleBirdinsky26.jpeg' dosyası '827.jpeg' olarak değiştirildi.
# '63d2068f-BirdsFlying_15.jpg' dosyası '828.jpg' olarak değiştirildi.
# '64233198-singleBirdinsky255.jpeg' dosyası '829.jpeg' olarak değiştirildi.
# '64b441d4-BirdsFlying_86.jpg' dosyası '830.jpg' olarak değiştirildi.
# '6531fc8a-BirdsFlying_45.jpg' dosyası '831.jpg' olarak değiştirildi.
# '664cc429-BirdsFlying_92.jpg' dosyası '832.jpg' olarak değiştirildi.
# '681b5c56-singleBirdinsky274.jpeg' dosyası '833.jpeg' olarak değiştirildi.
# '693018be-singleBirdinsky282.jpeg' dosyası '834.jpeg' olarak değiştirildi.
# '6a3e85c5-singleBirdinsky387.jpeg' dosyası '835.jpeg' olarak değiştirildi.
# '6b092561-singleBirdinsky55.jpeg' dosyası '836.jpeg' olarak değiştirildi.
# '6c6f03ed-singleBirdinsky51.jpeg' dosyası '837.jpeg' olarak değiştirildi.
# '6ccb67b0-singleBirdinsky312.jpeg' dosyası '838.jpeg' olarak değiştirildi.
# '6df7c599-BirdsFlying_13.jpg' dosyası '839.jpg' olarak değiştirildi.
# '6e15ba0d-singleBirdinsky397.jpeg' dosyası '840.jpeg' olarak değiştirildi.
# '6e50e3dd-singleBirdinsky22.jpeg' dosyası '841.jpeg' olarak değiştirildi.
# '6f21a479-BirdsFlying_26.jpg' dosyası '842.jpg' olarak değiştirildi.
# '6f96a256-BirdsFlying_66.jpg' dosyası '843.jpg' olarak değiştirildi.
# '70f0ec8e-singleBirdinsky99.jpeg' dosyası '844.jpeg' olarak değiştirildi.
# '71509d84-BirdsFlying_57.jpg' dosyası '845.jpg' olarak değiştirildi.
# '7193c155-singleBirdinsky21.jpeg' dosyası '846.jpeg' olarak değiştirildi.
# '71a74a62-BirdsFlying_49.jpg' dosyası '847.jpg' olarak değiştirildi.
# '7202a32a-singleBirdinsky289.jpeg' dosyası '848.jpeg' olarak değiştirildi.
# '74d3336e-singleBirdinsky68.jpeg' dosyası '849.jpeg' olarak değiştirildi.
# '76e96f39-singleBirdinsky295.jpeg' dosyası '850.jpeg' olarak değiştirildi.
# '7711fc38-singleBirdinsky279.jpeg' dosyası '851.jpeg' olarak değiştirildi.
# '771919f4-BirdsFlying_33.jpg' dosyası '852.jpg' olarak değiştirildi.
# '772a0264-BirdsFlying_82.jpg' dosyası '853.jpg' olarak değiştirildi.
# '78584bc3-singleBirdinsky380.jpeg' dosyası '854.jpeg' olarak değiştirildi.
# '78fec515-singleBirdinsky13.jpeg' dosyası '855.jpeg' olarak değiştirildi.
# '79194f64-singleBirdinsky4.jpeg' dosyası '856.jpeg' olarak değiştirildi.
# '7933e628-singleBirdinsky388.jpeg' dosyası '857.jpeg' olarak değiştirildi.
# '7a13198b-singleBirdinsky303.jpeg' dosyası '858.jpeg' olarak değiştirildi.
# '7a2cd2b4-singleBirdinsky371.jpeg' dosyası '859.jpeg' olarak değiştirildi.
# '7a7546fe-singleBirdinsky17.jpeg' dosyası '860.jpeg' olarak değiştirildi.
# '7ae22701-singleBirdinsky45.jpeg' dosyası '861.jpeg' olarak değiştirildi.
# '7c5fc42f-singleBirdinsky365.jpeg' dosyası '862.jpeg' olarak değiştirildi.
# '7cde6cde-singleBirdinsky44.jpeg' dosyası '863.jpeg' olarak değiştirildi.
# '8053ae54-BirdsFlying_12.jpg' dosyası '864.jpg' olarak değiştirildi.
# '80d92f41-singleBirdinsky280.jpeg' dosyası '865.jpeg' olarak değiştirildi.
# '8162cbbb-singleBirdinsky324.jpeg' dosyası '866.jpeg' olarak değiştirildi.
# '81b67b84-singleBirdinsky379.jpeg' dosyası '867.jpeg' olarak değiştirildi.
# '8275ef4b-singleBirdinsky83.jpeg' dosyası '868.jpeg' olarak değiştirildi.
# '82d36d13-BirdsFlying_61.jpg' dosyası '869.jpg' olarak değiştirildi.
# '82e7089d-singleBirdinsky350.jpeg' dosyası '870.jpeg' olarak değiştirildi.
# '830b0046-singleBirdinsky360.jpeg' dosyası '871.jpeg' olarak değiştirildi.
# '847a8c83-singleBirdinsky269.jpeg' dosyası '872.jpeg' olarak değiştirildi.
# '855af4b4-singleBirdinsky335.jpeg' dosyası '873.jpeg' olarak değiştirildi.
# '861f5e5a-BirdsFlying_58.jpg' dosyası '874.jpg' olarak değiştirildi.
# '885a647a-BirdsFlying_68.jpg' dosyası '875.jpg' olarak değiştirildi.
# '8907c212-singleBirdinsky20.jpeg' dosyası '876.jpeg' olarak değiştirildi.
# '8c2bb288-BirdsFlying_65.jpg' dosyası '877.jpg' olarak değiştirildi.
# '8c54c00d-singleBirdinsky56.jpeg' dosyası '878.jpeg' olarak değiştirildi.
# '8cc41cb5-singleBirdinsky276.jpeg' dosyası '879.jpeg' olarak değiştirildi.
# '8cfe1708-singleBirdinsky270.jpeg' dosyası '880.jpeg' olarak değiştirildi.
# '8f331e26-singleBirdinsky356.jpeg' dosyası '881.jpeg' olarak değiştirildi.
# '8f422e83-singleBirdinsky34.jpeg' dosyası '882.jpeg' olarak değiştirildi.
# '906a30c4-singleBirdinsky259.jpeg' dosyası '883.jpeg' olarak değiştirildi.
# '91434aab-singleBirdinsky346.jpeg' dosyası '884.jpeg' olarak değiştirildi.
# '9245f1f4-singleBirdinsky296.jpeg' dosyası '885.jpeg' olarak değiştirildi.
# '93f58bcc-singleBirdinsky278.jpeg' dosyası '886.jpeg' olarak değiştirildi.
# '94041976-singleBirdinsky93.jpeg' dosyası '887.jpeg' olarak değiştirildi.
# '948eaec8-singleBirdinsky395.jpeg' dosyası '888.jpeg' olarak değiştirildi.
# '95fa5d36-singleBirdinsky364.jpeg' dosyası '889.jpeg' olarak değiştirildi.
# '9691cc03-BirdsFlying_37.jpg' dosyası '890.jpg' olarak değiştirildi.
# '96e12139-BirdsFlying_6.jpg' dosyası '891.jpg' olarak değiştirildi.
# '96e6abef-singleBirdinsky2.jpeg' dosyası '892.jpeg' olarak değiştirildi.
# '96e926d8-BirdsFlying_16.jpg' dosyası '893.jpg' olarak değiştirildi.
# '96f47643-singleBirdinsky375.jpeg' dosyası '894.jpeg' olarak değiştirildi.
# '97da69e6-BirdsFlying_9.jpg' dosyası '895.jpg' olarak değiştirildi.
# '991c5f0d-BirdsFlying_43.jpg' dosyası '896.jpg' olarak değiştirildi.
# '9a224791-singleBirdinsky95.jpeg' dosyası '897.jpeg' olarak değiştirildi.
# '9b9a31cb-singleBirdinsky308.jpeg' dosyası '898.jpeg' olarak değiştirildi.
# '9bf4b3d6-BirdsFlying_93.jpg' dosyası '899.jpg' olarak değiştirildi.
# '9cf82070-BirdsFlying_32.jpg' dosyası '900.jpg' olarak değiştirildi.
# '9dfe2852-singleBirdinsky84.jpeg' dosyası '901.jpeg' olarak değiştirildi.
# '9e6644bb-singleBirdinsky317.jpeg' dosyası '902.jpeg' olarak değiştirildi.
# '9fdfc9b7-singleBirdinsky38.jpeg' dosyası '903.jpeg' olarak değiştirildi.
# 'a04f7d3c-singleBirdinsky353.jpeg' dosyası '904.jpeg' olarak değiştirildi.
# 'a0a22a09-singleBirdinsky7.jpeg' dosyası '905.jpeg' olarak değiştirildi.
# 'a1eabb9b-singleBirdinsky355.jpeg' dosyası '906.jpeg' olarak değiştirildi.
# 'a2531b9c-singleBirdinsky16.jpeg' dosyası '907.jpeg' olarak değiştirildi.
# 'a3667e49-singleBirdinsky362.jpeg' dosyası '908.jpeg' olarak değiştirildi.
# 'a36afc79-singleBirdinsky326.jpeg' dosyası '909.jpeg' olarak değiştirildi.
# 'a36e273a-BirdsFlying_81.jpg' dosyası '910.jpg' olarak değiştirildi.
# 'a4cff496-BirdsFlying_55.jpg' dosyası '911.jpg' olarak değiştirildi.
# 'a4e00d62-singleBirdinsky300.jpeg' dosyası '912.jpeg' olarak değiştirildi.
# 'a68afb5f-BirdsFlying_31.jpg' dosyası '913.jpg' olarak değiştirildi.
# 'a69bd298-singleBirdinsky49.jpeg' dosyası '914.jpeg' olarak değiştirildi.
# 'a69cdddf-singleBirdinsky98.jpeg' dosyası '915.jpeg' olarak değiştirildi.
# 'a793430d-BirdsFlying_75.jpg' dosyası '916.jpg' olarak değiştirildi.
# 'a8857efe-singleBirdinsky323.jpeg' dosyası '917.jpeg' olarak değiştirildi.
# 'ab497272-BirdsFlying_20.jpg' dosyası '918.jpg' olarak değiştirildi.
# 'ad2e65d8-singleBirdinsky386.jpeg' dosyası '919.jpeg' olarak değiştirildi.
# 'ad989ce9-BirdsFlying_56.jpg' dosyası '920.jpg' olarak değiştirildi.
# 'aec4235a-singleBirdinsky27.jpeg' dosyası '921.jpeg' olarak değiştirildi.
# 'afae4680-singleBirdinsky319.jpeg' dosyası '922.jpeg' olarak değiştirildi.
# 'afe2f869-BirdsFlying_73.jpg' dosyası '923.jpg' olarak değiştirildi.
# 'b15212e1-singleBirdinsky60.jpeg' dosyası '924.jpeg' olarak değiştirildi.
# 'b168e71f-BirdsFlying_71.jpg' dosyası '925.jpg' olarak değiştirildi.
# 'b20dd9f1-singleBirdinsky305.jpeg' dosyası '926.jpeg' olarak değiştirildi.
# 'b337d171-singleBirdinsky260.jpeg' dosyası '927.jpeg' olarak değiştirildi.
# 'b34934dc-singleBirdinsky6.jpeg' dosyası '928.jpeg' olarak değiştirildi.
# 'b37a6528-BirdsFlying_60.jpg' dosyası '929.jpg' olarak değiştirildi.
# 'b41625e8-singleBirdinsky28.jpeg' dosyası '930.jpeg' olarak değiştirildi.
# 'b4369565-singleBirdinsky76.jpeg' dosyası '931.jpeg' olarak değiştirildi.
# 'b492a3e7-BirdsFlying_95.jpg' dosyası '932.jpg' olarak değiştirildi.
# 'b56c2240-BirdsFlying_50.jpg' dosyası '933.jpg' olarak değiştirildi.
# 'b59337b7-BirdsFlying_54.jpg' dosyası '934.jpg' olarak değiştirildi.
# 'b5f73620-singleBirdinsky100.jpeg' dosyası '935.jpeg' olarak değiştirildi.
# 'b7a0aaef-BirdsFlying_34.jpg' dosyası '936.jpg' olarak değiştirildi.
# 'b8f93a93-singleBirdinsky291.jpeg' dosyası '937.jpeg' olarak değiştirildi.
# 'bab4f15b-singleBirdinsky47.jpeg' dosyası '938.jpeg' olarak değiştirildi.
# 'baf46f79-BirdsFlying_40.jpg' dosyası '939.jpg' olarak değiştirildi.
# 'bc1cfd29-BirdsFlying_3.jpg' dosyası '940.jpg' olarak değiştirildi.
# 'bc900bc9-singleBirdinsky82.jpeg' dosyası '941.jpeg' olarak değiştirildi.
# 'bdb2c939-singleBirdinsky327.jpeg' dosyası '942.jpeg' olarak değiştirildi.
# 'bdf43445-singleBirdinsky254.jpeg' dosyası '943.jpeg' olarak değiştirildi.
# 'bed2730b-BirdsFlying_7.jpg' dosyası '944.jpg' olarak değiştirildi.
# 'c0338078-BirdsFlying_62.jpg' dosyası '945.jpg' olarak değiştirildi.
# 'c0c0fa95-singleBirdinsky74.jpeg' dosyası '946.jpeg' olarak değiştirildi.
# 'c0e329a3-singleBirdinsky272.jpeg' dosyası '947.jpeg' olarak değiştirildi.
# 'c2888d94-singleBirdinsky40.jpeg' dosyası '948.jpeg' olarak değiştirildi.
# 'c2ac1144-singleBirdinsky31.jpeg' dosyası '949.jpeg' olarak değiştirildi.
# 'c2c9b4cb-singleBirdinsky30.jpeg' dosyası '950.jpeg' olarak değiştirildi.
# 'c3cb682a-singleBirdinsky37.jpeg' dosyası '951.jpeg' olarak değiştirildi.
# 'c3f66c65-singleBirdinsky329.jpeg' dosyası '952.jpeg' olarak değiştirildi.
# 'c44f8fc1-singleBirdinsky14.jpeg' dosyası '953.jpeg' olarak değiştirildi.
# 'c540d90a-singleBirdinsky33.jpeg' dosyası '954.jpeg' olarak değiştirildi.
# 'c6386cba-singleBirdinsky352.jpeg' dosyası '955.jpeg' olarak değiştirildi.
# 'c79fde15-singleBirdinsky376.jpeg' dosyası '956.jpeg' olarak değiştirildi.
# 'c7abc7ae-singleBirdinsky61.jpeg' dosyası '957.jpeg' olarak değiştirildi.
# 'c7b7afed-singleBirdinsky349.jpeg' dosyası '958.jpeg' olarak değiştirildi.
# 'c7dc6a8e-singleBirdinsky330.jpeg' dosyası '959.jpeg' olarak değiştirildi.
# 'c97ddb6b-singleBirdinsky281.jpeg' dosyası '960.jpeg' olarak değiştirildi.
# 'ca727928-singleBirdinsky385.jpeg' dosyası '961.jpeg' olarak değiştirildi.
# 'cfd3e618-singleBirdinsky373.jpeg' dosyası '962.jpeg' olarak değiştirildi.
# 'd0d4c5c2-BirdsFlying_44.jpg' dosyası '963.jpg' olarak değiştirildi.
# 'd420bb3b-singleBirdinsky315.jpeg' dosyası '964.jpeg' olarak değiştirildi.
# 'd45de038-BirdsFlying_63.jpg' dosyası '965.jpg' olarak değiştirildi.
# 'd5850b02-singleBirdinsky370.jpeg' dosyası '966.jpeg' olarak değiştirildi.
# 'd70ed0f3-singleBirdinsky69.jpeg' dosyası '967.jpeg' olarak değiştirildi.
# 'd976db0a-singleBirdinsky65.jpeg' dosyası '968.jpeg' olarak değiştirildi.
# 'd97b08fd-BirdsFlying_29.jpg' dosyası '969.jpg' olarak değiştirildi.
# 'da4c61de-singleBirdinsky313.jpeg' dosyası '970.jpeg' olarak değiştirildi.
# 'db9075ce-singleBirdinsky35.jpeg' dosyası '971.jpeg' olarak değiştirildi.
# 'dbbc4187-singleBirdinsky77.jpeg' dosyası '972.jpeg' olarak değiştirildi.
# 'dc2080a9-BirdsFlying_78.jpg' dosyası '973.jpg' olarak değiştirildi.
# 'dc57d665-singleBirdinsky12.jpeg' dosyası '974.jpeg' olarak değiştirildi.
# 'dcdefe6b-singleBirdinsky368.jpeg' dosyası '975.jpeg' olarak değiştirildi.
# 'dcdfe876-BirdsFlying_51.jpg' dosyası '976.jpg' olarak değiştirildi.
# 'dce9cc17-singleBirdinsky287.jpeg' dosyası '977.jpeg' olarak değiştirildi.
# 'dcf00cc6-singleBirdinsky361.jpeg' dosyası '978.jpeg' olarak değiştirildi.
# 'dd1a5565-singleBirdinsky357.jpeg' dosyası '979.jpeg' olarak değiştirildi.
# 'dd797f7d-BirdsFlying_69.jpg' dosyası '980.jpg' olarak değiştirildi.
# 'dd9c8e64-singleBirdinsky36.jpeg' dosyası '981.jpeg' olarak değiştirildi.
# 'ddb99ef6-singleBirdinsky266.jpeg' dosyası '982.jpeg' olarak değiştirildi.
# 'de8ae1bd-singleBirdinsky332.jpeg' dosyası '983.jpeg' olarak değiştirildi.
# 'de9c161c-BirdsFlying_25.jpg' dosyası '984.jpg' olarak değiştirildi.
# 'decf6a00-singleBirdinsky11.jpeg' dosyası '985.jpeg' olarak değiştirildi.
# 'df3e8dad-singleBirdinsky396.jpeg' dosyası '986.jpeg' olarak değiştirildi.
# 'df8f6236-BirdsFlying_52.jpg' dosyası '987.jpg' olarak değiştirildi.
# 'e09799af-BirdsFlying_27.jpg' dosyası '988.jpg' olarak değiştirildi.
# 'e1137d7a-BirdsFlying_59.jpg' dosyası '989.jpg' olarak değiştirildi.
# 'e121efa7-singleBirdinsky97.jpeg' dosyası '990.jpeg' olarak değiştirildi.
# 'e19ac38b-singleBirdinsky344.jpeg' dosyası '991.jpeg' olarak değiştirildi.
# 'e1da50b9-BirdsFlying_94.jpg' dosyası '992.jpg' olarak değiştirildi.
# 'e3039681-singleBirdinsky59.jpeg' dosyası '993.jpeg' olarak değiştirildi.
# 'e33b0129-singleBirdinsky265.jpeg' dosyası '994.jpeg' olarak değiştirildi.
# 'e486f84a-BirdsFlying_14.jpg' dosyası '995.jpg' olarak değiştirildi.
# 'e517ea5e-singleBirdinsky15.jpeg' dosyası '996.jpeg' olarak değiştirildi.
# 'e5656bae-singleBirdinsky372.jpeg' dosyası '997.jpeg' olarak değiştirildi.
# 'e61a80b4-singleBirdinsky309.jpeg' dosyası '998.jpeg' olarak değiştirildi.
# 'e8d40c43-singleBirdinsky307.jpeg' dosyası '999.jpeg' olarak değiştirildi.
# 'e99342cc-singleBirdinsky101.jpeg' dosyası '1000.jpeg' olarak değiştirildi.
# 'eac7e99b-BirdsFlying_64.jpg' dosyası '1001.jpg' olarak değiştirildi.
# 'eb5202ee-BirdsFlying_99.jpg' dosyası '1002.jpg' olarak değiştirildi.
# 'eb5a11bd-singleBirdinsky298.jpeg' dosyası '1003.jpeg' olarak değiştirildi.
# 'eb5b939f-singleBirdinsky285.jpeg' dosyası '1004.jpeg' olarak değiştirildi.
# 'ebfec92e-singleBirdinsky322.jpeg' dosyası '1005.jpeg' olarak değiştirildi.
# 'ec002da0-BirdsFlying_83.jpg' dosyası '1006.jpg' olarak değiştirildi.
# 'ec969a39-singleBirdinsky86.jpeg' dosyası '1007.jpeg' olarak değiştirildi.
# 'edc46316-singleBirdinsky277.jpeg' dosyası '1008.jpeg' olarak değiştirildi.
# 'edd6883a-singleBirdinsky384.jpeg' dosyası '1009.jpeg' olarak değiştirildi.
# 'ef04f342-singleBirdinsky71.jpeg' dosyası '1010.jpeg' olarak değiştirildi.
# 'f009ec1f-BirdsFlying_4.jpg' dosyası '1011.jpg' olarak değiştirildi.
# 'f0533c9d-BirdsFlying_97.jpg' dosyası '1012.jpg' olarak değiştirildi.
# 'f059d232-BirdsFlying_8.jpg' dosyası '1013.jpg' olarak değiştirildi.
# 'f11710a8-singleBirdinsky341.jpeg' dosyası '1014.jpeg' olarak değiştirildi.
# 'f135cbc3-singleBirdinsky358.jpeg' dosyası '1015.jpeg' olarak değiştirildi.
# 'f160b739-singleBirdinsky46.jpeg' dosyası '1016.jpeg' olarak değiştirildi.
# 'f1fcd495-singleBirdinsky261.jpeg' dosyası '1017.jpeg' olarak değiştirildi.
# 'f202ac08-singleBirdinsky73.jpeg' dosyası '1018.jpeg' olarak değiştirildi.
# 'f281bbef-singleBirdinsky91.jpeg' dosyası '1019.jpeg' olarak değiştirildi.
# 'f2eea839-singleBirdinsky302.jpeg' dosyası '1020.jpeg' olarak değiştirildi.
# 'f3122b69-singleBirdinsky72.jpeg' dosyası '1021.jpeg' olarak değiştirildi.
# 'f3554d84-singleBirdinsky304.jpeg' dosyası '1022.jpeg' olarak değiştirildi.
# 'f38238d3-singleBirdinsky79.jpeg' dosyası '1023.jpeg' olarak değiştirildi.
# 'f3aad9d7-BirdsFlying_96.jpg' dosyası '1024.jpg' olarak değiştirildi.
# 'f3db90d1-singleBirdinsky316.jpeg' dosyası '1025.jpeg' olarak değiştirildi.
# 'f4896dce-singleBirdinsky96.jpeg' dosyası '1026.jpeg' olarak değiştirildi.
# 'f50820b9-BirdsFlying_79.jpg' dosyası '1027.jpg' olarak değiştirildi.
# 'f64053c2-singleBirdinsky321.jpeg' dosyası '1028.jpeg' olarak değiştirildi.
# 'f6a0173a-singleBirdinsky48.jpeg' dosyası '1029.jpeg' olarak değiştirildi.
# 'f79db98f-BirdsFlying_80.jpg' dosyası '1030.jpg' olarak değiştirildi.
# 'f7e896f1-singleBirdinsky320.jpeg' dosyası '1031.jpeg' olarak değiştirildi.
# 'fa787f8e-singleBirdinsky9.jpeg' dosyası '1032.jpeg' olarak değiştirildi.
# 'fa86d27f-BirdsFlying_30.jpg' dosyası '1033.jpg' olarak değiştirildi.
# 'facd524b-1389024_27c2560c5b4dab0e756b013ce3321cfe_640x640.jpg' dosyası '1034.jpg' olarak değiştirildi.
# 'fb3cb273-BirdsFlying_42.jpg' dosyası '1035.jpg' olarak değiştirildi.
# 'fb4c4f03-BirdsFlying_21.jpg' dosyası '1036.jpg' olarak değiştirildi.
# 'fbf068f5-BirdsFlying_89.jpg' dosyası '1037.jpg' olarak değiştirildi.
# 'fc20d621-singleBirdinsky333.jpeg' dosyası '1038.jpeg' olarak değiştirildi.
# 'fc3aaa7a-singleBirdinsky325.jpeg' dosyası '1039.jpeg' olarak değiştirildi.
# 'fe033844-singleBirdinsky29.jpeg' dosyası '1040.jpeg' olarak değiştirildi.
# 'ff6e9784-singleBirdinsky347.jpeg' dosyası '1041.jpeg' olarak değiştirildi.
# Dosya isimlendirme işlemi tamamlandı.

# %%
#CHANGING NAMES OF AUGMENTED, RESIZED, NORMLIZED FILES TO ORDER WELL (UAV)

# %%
import os

# Dosyaların bulunduğu klasörün yolu
folder_path = 'C:/Users/edana/Desktop/dataset_new/UAV/augmented_images'

# Dosya isimlerini değiştirmek için başlangıç numarası
start_number = 1
end_number = 500

# Klasördeki tüm dosyaları al
files = os.listdir(folder_path)

# Sadece dosya olanları al (klasörleri hariç tut)
files = [f for f in files if os.path.isfile(os.path.join(folder_path, f))]

# Dosyaları sıralı olarak yeniden isimlendirme işlemi
for i, file_name in enumerate(files):
    if i < end_number:
        # Dosyanın uzantısını al
        file_extension = os.path.splitext(file_name)[1]
        # Yeni dosya adını oluştur
        new_name = f"{start_number + i}{file_extension}"
        # Eski ve yeni dosya yollarını oluştur
        old_file_path = os.path.join(folder_path, file_name)
        new_file_path = os.path.join(folder_path, new_name)
        # Dosya ismini değiştir
        os.rename(old_file_path, new_file_path)
        print(f"'{file_name}' dosyası '{new_name}' olarak değiştirildi.")
    else:
        break

print("Dosya isimlendirme işlemi tamamlandı.")
# Out:
# '01f09349-47.jpeg' dosyası '1.jpeg' olarak değiştirildi.
# '01f14498-1_37.jpg' dosyası '2.jpg' olarak değiştirildi.
# '03235c10-1_10.jpg' dosyası '3.jpg' olarak değiştirildi.
# '032b8fc0-0095.jpg' dosyası '4.jpg' olarak değiştirildi.
# '0439f4e3-0237.jpg' dosyası '5.jpg' olarak değiştirildi.
# '04e13cc4-1704_jpg.rf.75c3676a3b249fe28258cf7edc78685e.jpg' dosyası '6.jpg' olarak değiştirildi.
# '0573af8e-1652_PNG.rf.41631d03f2ed222667877a536b01ced9.jpg' dosyası '7.jpg' olarak değiştirildi.
# '059a0726-33.jpeg' dosyası '8.jpeg' olarak değiştirildi.
# '05ea4ee7-1_12.jpg' dosyası '9.jpg' olarak değiştirildi.
# '06709e94-1_5.jpg' dosyası '10.jpg' olarak değiştirildi.
# '06ee1fa3-56.jpeg' dosyası '11.jpeg' olarak değiştirildi.
# '0766dc07-91.jpeg' dosyası '12.jpeg' olarak değiştirildi.
# '078f7569-1738_PNG.rf.760ee524c0edd762b2252027a0e1f1cb.jpg' dosyası '13.jpg' olarak değiştirildi.
# '089c260f-0001.jpg' dosyası '14.jpg' olarak değiştirildi.
# '08d06b6e-1784_jpg.rf.3d8a198eabaf697d14df17098004f016.jpg' dosyası '15.jpg' olarak değiştirildi.
# '09e7187b-1626_jpg.rf.da41bff1520ebed0a36aa35c64acd9a0.jpg' dosyası '16.jpg' olarak değiştirildi.
# '0a95ec6e-1758_jpg.rf.edec6d2de3c4f28886ab7dfc9fa45d0b.jpg' dosyası '17.jpg' olarak değiştirildi.
# '0aa31dc9-1_6.jpg' dosyası '18.jpg' olarak değiştirildi.
# '0da650df-1_49.jpg' dosyası '19.jpg' olarak değiştirildi.
# '0e026ff8-0048.jpg' dosyası '20.jpg' olarak değiştirildi.
# '0f22034a-1745_jpg.rf.bdbb6df36d8da1d8223cd40b0a6d8eb0.jpg' dosyası '21.jpg' olarak değiştirildi.
# '0f5cf83b-0228.jpg' dosyası '22.jpg' olarak değiştirildi.
# '11719f3f-0097.jpg' dosyası '23.jpg' olarak değiştirildi.
# '117d2488-1640_jpg.rf.a262659a6df5f26c64b5c8a795640ac6.jpg' dosyası '24.jpg' olarak değiştirildi.
# '11daa65d-1763_jpg.rf.21566c2cc30e771fcccda139d075855b.jpg' dosyası '25.jpg' olarak değiştirildi.
# '11e9053b-1679_jpg.rf.431b9419b1099be607c6a84e4f622dde.jpg' dosyası '26.jpg' olarak değiştirildi.
# '121ae19f-1749_jpg.rf.ba8439d61d4699b0212205bf7c333822.jpg' dosyası '27.jpg' olarak değiştirildi.
# '136d9ef5-1625_PNG.rf.5a94fc4e6ff595ae9dcbc4c1d202631c.jpg' dosyası '28.jpg' olarak değiştirildi.
# '138e133d-48.jpeg' dosyası '29.jpeg' olarak değiştirildi.
# '141a1661-74.jpeg' dosyası '30.jpeg' olarak değiştirildi.
# '144403a8-1789_jpg.rf.b3176e95278090aba73805531c03b4c0.jpg' dosyası '31.jpg' olarak değiştirildi.
# '145bbe5f-1665_PNG.rf.605d3378a7afe49e55947086a4260a0a.jpg' dosyası '32.jpg' olarak değiştirildi.
# '149117c6-0223.jpg' dosyası '33.jpg' olarak değiştirildi.
# '14b4f270-0068.jpg' dosyası '34.jpg' olarak değiştirildi.
# '14cceeaf-1_9.jpg' dosyası '35.jpg' olarak değiştirildi.
# '1502730c-1768_jpg.rf.a8ee9182c0748cd7fa90986567524b3a.jpg' dosyası '36.jpg' olarak değiştirildi.
# '172f735b-1628_PNG.rf.eda1e3e31a2bf5e31a1a72b9257b55e0.jpg' dosyası '37.jpg' olarak değiştirildi.
# '175f8f8e-23.jpeg' dosyası '38.jpeg' olarak değiştirildi.
# '179d607f-1687_PNG.rf.0b3fdfd3efbf1187d39b933349326393.jpg' dosyası '39.jpg' olarak değiştirildi.
# '17a73a88-114.jpeg' dosyası '40.jpeg' olarak değiştirildi.
# '191ff427-1729_PNG.rf.882450f0e8cca8d9125b309e128e1f44.jpg' dosyası '41.jpg' olarak değiştirildi.
# '1b3b6c83-1_18.jpg' dosyası '42.jpg' olarak değiştirildi.
# '1b6cf79d-1698_jpg.rf.8cfef565573232ca15d37050fb536ef6.jpg' dosyası '43.jpg' olarak değiştirildi.
# '1c93eda3-1773_jpg.rf.33b0b82a7101d1c10e6ead694a18b9ff.jpg' dosyası '44.jpg' olarak değiştirildi.
# '1e15a4dd-0058.jpg' dosyası '45.jpg' olarak değiştirildi.
# '1e420c26-1769_jpg.rf.732e05e08d3754c673f9e86a140174d5.jpg' dosyası '46.jpg' olarak değiştirildi.
# '1e69dc4b-1638_PNG.rf.afcd87ee2974bb029d0105db7e2fdd69.jpg' dosyası '47.jpg' olarak değiştirildi.
# '1eb9e1ed-1616_PNG.rf.5a48524b1275508dfb7b452f67fe7132.jpg' dosyası '48.jpg' olarak değiştirildi.
# '1f863c4f-0030.jpg' dosyası '49.jpg' olarak değiştirildi.
# '20af207e-1678_jpg.rf.a3a5aaafe0ed424e30c7a5e580b4fc23.jpg' dosyası '50.jpg' olarak değiştirildi.
# '21b889cc-0056.jpg' dosyası '51.jpg' olarak değiştirildi.
# '21fb86ee-1783_jpg.rf.ba3ad9d74288768b73176400feeb42ba.jpg' dosyası '52.jpg' olarak değiştirildi.
# '2297e830-1692_jpg.rf.ee35dc8c4a5c2460e22cc8a61c8abc5d.jpg' dosyası '53.jpg' olarak değiştirildi.
# '2332444a-1747_jpg.rf.8a7f664bfbae7aa0f8b4a54eb3cdfac5.jpg' dosyası '54.jpg' olarak değiştirildi.
# '23d08d00-1695_PNG.rf.e827534c59bca1fff23b34ced296a5d6.jpg' dosyası '55.jpg' olarak değiştirildi.
# '242c4d00-40.jpeg' dosyası '56.jpeg' olarak değiştirildi.
# '252ca85e-1610_PNG.rf.779bb6d7894aaf49143cd161ce92482d.jpg' dosyası '57.jpg' olarak değiştirildi.
# '256498ca-1712_jpg.rf.5630366560cba451a391a2559bfb611c.jpg' dosyası '58.jpg' olarak değiştirildi.
# '26e704ac-1710_PNG.rf.b31e1ab05dec9c94ae0d02be58918c78.jpg' dosyası '59.jpg' olarak değiştirildi.
# '272a5f8b-0071.jpg' dosyası '60.jpg' olarak değiştirildi.
# '281bf2d9-1631_PNG.rf.3593414c6d9041a99bb90a98fd7a226d.jpg' dosyası '61.jpg' olarak değiştirildi.
# '29047177-1730_jpg.rf.de41605f63fb477f2d3132791c4f620a.jpg' dosyası '62.jpg' olarak değiştirildi.
# '290df7a9-1664_jpg.rf.efbe4de923eabd446bc1fb4009aa53b7.jpg' dosyası '63.jpg' olarak değiştirildi.
# '290f4225-1682_jpg.rf.8bbda5f3f2b76f2428c8209a4d4c1812.jpg' dosyası '64.jpg' olarak değiştirildi.
# '291e6e0f-1782_jpg.rf.73b92dfad04fd7fd0d6df003eeb95e3a.jpg' dosyası '65.jpg' olarak değiştirildi.
# '2b85dc59-1734_jpg.rf.14f01407f6485735401f88c2903906f9.jpg' dosyası '66.jpg' olarak değiştirildi.
# '2bc989a1-0215.jpg' dosyası '67.jpg' olarak değiştirildi.
# '2bcc1992-1760_jpg.rf.f01a0e02fe82f774d799b6c0cdf93751.jpg' dosyası '68.jpg' olarak değiştirildi.
# '2bda6acc-0025.jpg' dosyası '69.jpg' olarak değiştirildi.
# '2c790ddf-1_47.jpg' dosyası '70.jpg' olarak değiştirildi.
# '2c9f0310-88.jpeg' dosyası '71.jpeg' olarak değiştirildi.
# '2cf05c47-1_35.jpg' dosyası '72.jpg' olarak değiştirildi.
# '2d03980b-1724_PNG.rf.268edb49e3dc99988edb1285034a34f4.jpg' dosyası '73.jpg' olarak değiştirildi.
# '2d050469-0061.jpg' dosyası '74.jpg' olarak değiştirildi.
# '2de11f3d-1765_jpg.rf.84799cca6abb8049bb2f3d13bcbc5529.jpg' dosyası '75.jpg' olarak değiştirildi.
# '2e5ada57-1776_jpg.rf.abfe7c5d91dcc5c821a3e41ab884caea.jpg' dosyası '76.jpg' olarak değiştirildi.
# '2f47dc4d-1701_PNG.rf.db8e3d7c7ed938e6772e9272454cc895.jpg' dosyası '77.jpg' olarak değiştirildi.
# '2f498b32-1800_jpg.rf.4e8ff95ae1039719d9708a2b09fea3d3.jpg' dosyası '78.jpg' olarak değiştirildi.
# '2f774247-0232.jpg' dosyası '79.jpg' olarak değiştirildi.
# '2fb271e3-110.jpeg' dosyası '80.jpeg' olarak değiştirildi.
# '2fb9c374-10.jpeg' dosyası '81.jpeg' olarak değiştirildi.
# '30969694-1700_jpg.rf.97ad2f2f3f0f4a12c1744a81688e4b35.jpg' dosyası '82.jpg' olarak değiştirildi.
# '30d86b36-1_16.jpg' dosyası '83.jpg' olarak değiştirildi.
# '318223a8-59.jpeg' dosyası '84.jpeg' olarak değiştirildi.
# '32d8a231-1709_PNG.rf.b8c97dbf24b35eb9753beca1eb85bbbf.jpg' dosyası '85.jpg' olarak değiştirildi.
# '32fbd758-1693_PNG.rf.dc50a9c21776f1f640def875acc348d4.jpg' dosyası '86.jpg' olarak değiştirildi.
# '33953287-31.jpeg' dosyası '87.jpeg' olarak değiştirildi.
# '33d405de-89.jpeg' dosyası '88.jpeg' olarak değiştirildi.
# '341ffde7-1794_jpg.rf.733583058330201835117194be53c526.jpg' dosyası '89.jpg' olarak değiştirildi.
# '34a8e88f-49.jpeg' dosyası '90.jpeg' olarak değiştirildi.
# '35d1a03a-0032.jpg' dosyası '91.jpg' olarak değiştirildi.
# '366fedf9-1_8.jpg' dosyası '92.jpg' olarak değiştirildi.
# '37326e7c-0004.jpg' dosyası '93.jpg' olarak değiştirildi.
# '38edbc1f-1_17.jpg' dosyası '94.jpg' olarak değiştirildi.
# '3914bf0d-1_48.jpg' dosyası '95.jpg' olarak değiştirildi.
# '39a2ff1a-1689_jpg.rf.1870d81654b2898fc10cdd88fba1103b.jpg' dosyası '96.jpg' olarak değiştirildi.
# '39afc5bd-1699_PNG.rf.f00262370ada3df7813f8abf9dbaaea6.jpg' dosyası '97.jpg' olarak değiştirildi.
# '3a97176f-0007.jpg' dosyası '98.jpg' olarak değiştirildi.
# '3abde690-1705_PNG.rf.5daecef458f44b8f3f653315c06cef2d.jpg' dosyası '99.jpg' olarak değiştirildi.
# '3ac3f3cd-0074.jpg' dosyası '100.jpg' olarak değiştirildi.
# '3b0a78c0-0026.jpg' dosyası '101.jpg' olarak değiştirildi.
# '3b6de15d-1_4.jpg' dosyası '102.jpg' olarak değiştirildi.
# '3bd136b9-93.jpeg' dosyası '103.jpeg' olarak değiştirildi.
# '3c819c48-0094.jpg' dosyası '104.jpg' olarak değiştirildi.
# '3cbcfbfe-1_39.jpg' dosyası '105.jpg' olarak değiştirildi.
# '3d0b6bf7-1608_PNG.rf.8f8e8bc34dad875ac7510e2d08526799.jpg' dosyası '106.jpg' olarak değiştirildi.
# '3d4ba054-25.jpeg' dosyası '107.jpeg' olarak değiştirildi.
# '3e000fff-0216.jpg' dosyası '108.jpg' olarak değiştirildi.
# '3fe5cd20-1_28.jpg' dosyası '109.jpg' olarak değiştirildi.
# '4082834b-1797_jpg.rf.ba7cb0c088bbb76cde14f84d753a4198.jpg' dosyası '110.jpg' olarak değiştirildi.
# '40b06903-4.jpeg' dosyası '111.jpeg' olarak değiştirildi.
# '41758738-5.jpeg' dosyası '112.jpeg' olarak değiştirildi.
# '41ff7b0a-11.jpeg' dosyası '113.jpeg' olarak değiştirildi.
# '4270aeb2-1779_jpg.rf.ac0d8d4aea4ca7d703fa97feec895c1c.jpg' dosyası '114.jpg' olarak değiştirildi.
# '43f7d0d0-1748_jpg.rf.848c4824398270597a1996ea57155e8d.jpg' dosyası '115.jpg' olarak değiştirildi.
# '43fd8d51-103.jpeg' dosyası '116.jpeg' olarak değiştirildi.
# '446022df-1714_PNG.rf.e1a11f9a67e571c2b6e0221e0acbb29e.jpg' dosyası '117.jpg' olarak değiştirildi.
# '44a27934-1711_PNG.rf.994ceebb4d4de24b1c737b63782ac5f3.jpg' dosyası '118.jpg' olarak değiştirildi.
# '450fcc6d-1788_jpg.rf.aa4b353a44b48103a347de07db99006b.jpg' dosyası '119.jpg' olarak değiştirildi.
# '4741334d-1740_PNG.rf.f8c4d16b445e2de5edaddbcfaf739860.jpg' dosyası '120.jpg' olarak değiştirildi.
# '48c11af5-50.jpeg' dosyası '121.jpeg' olarak değiştirildi.
# '4942c5da-9.jpeg' dosyası '122.jpeg' olarak değiştirildi.
# '4a3158dc-1731_jpg.rf.bd7aab9f4ddd8d04294b70c6c5c61894.jpg' dosyası '123.jpg' olarak değiştirildi.
# '4b698730-1766_jpg.rf.213a245a2d9d0a4dcc100571ef1528a7.jpg' dosyası '124.jpg' olarak değiştirildi.
# '4bf61371-1684_jpg.rf.5ff2f366337e04e8be46a047332a5307.jpg' dosyası '125.jpg' olarak değiştirildi.
# '4c1e9eb6-1650_jpg.rf.6e138f8c66d2d62d2f84f50e8e0958a9.jpg' dosyası '126.jpg' olarak değiştirildi.
# '4c2a2626-108.jpeg' dosyası '127.jpeg' olarak değiştirildi.
# '4d7dbbd0-0214.jpg' dosyası '128.jpg' olarak değiştirildi.
# '4e9a4cc3-0065.jpg' dosyası '129.jpg' olarak değiştirildi.
# '4f126336-116.jpeg' dosyası '130.jpeg' olarak değiştirildi.
# '4fc9dc9e-1685_PNG.rf.6fe6627ad4eb31b35b45b3ed6416e58d.jpg' dosyası '131.jpg' olarak değiştirildi.
# '4fded54d-71.jpeg' dosyası '132.jpeg' olarak değiştirildi.
# '4ffc68a2-28.jpeg' dosyası '133.jpeg' olarak değiştirildi.
# '50fcea93-0039.jpg' dosyası '134.jpg' olarak değiştirildi.
# '519374a5-1796_jpg.rf.29e87505fe19d9ca298c07f128b9020d.jpg' dosyası '135.jpg' olarak değiştirildi.
# '5296708c-1674_jpg.rf.201552149988fc445579febd17b93f4a.jpg' dosyası '136.jpg' olarak değiştirildi.
# '5398dd4f-1621_PNG.rf.7e367626dfb3ea2ee8661ecb2e31be00.jpg' dosyası '137.jpg' olarak değiştirildi.
# '53bc80a6-1663_PNG.rf.806493996f980213411ca39950299d01.jpg' dosyası '138.jpg' olarak değiştirildi.
# '54e18b8b-0049.jpg' dosyası '139.jpg' olarak değiştirildi.
# '5535c582-0035.jpg' dosyası '140.jpg' olarak değiştirildi.
# '55c2f987-1750_jpg.rf.10aa88c6b5fb8e3c4c05be923da87537.jpg' dosyası '141.jpg' olarak değiştirildi.
# '55e0495e-1671_jpg.rf.2b05de921321bea3f3982158042fda79.jpg' dosyası '142.jpg' olarak değiştirildi.
# '56538f0e-1672_PNG.rf.4619877de1c7477fdacc0d85b2015627.jpg' dosyası '143.jpg' olarak değiştirildi.
# '5726a329-1_40.jpg' dosyası '144.jpg' olarak değiştirildi.
# '57c9d404-1795_jpg.rf.e149398595abe4ab13782c4caa4e9102.jpg' dosyası '145.jpg' olarak değiştirildi.
# '582b15c9-1771_jpg.rf.1118fce5351a6cdc903bbd0e1c171d85.jpg' dosyası '146.jpg' olarak değiştirildi.
# '5835b201-0229.jpg' dosyası '147.jpg' olarak değiştirildi.
# '58d92291-1_19.jpg' dosyası '148.jpg' olarak değiştirildi.
# '59603489-1632_PNG.rf.d73ba021479cfecd5560ee3d259f4fb4.jpg' dosyası '149.jpg' olarak değiştirildi.
# '596367e7-106.jpeg' dosyası '150.jpeg' olarak değiştirildi.
# '59d39757-1735_PNG.rf.82b871de5a1d781af5f3baab3cf03687.jpg' dosyası '151.jpg' olarak değiştirildi.
# '5b5d768c-73.jpeg' dosyası '152.jpeg' olarak değiştirildi.
# '5baa4e15-1778_jpg.rf.d1ad8c0f211636c63f4e19f52941fb98.jpg' dosyası '153.jpg' olarak değiştirildi.
# '5cad6e06-1725_PNG.rf.74473d308ec6f51028fe7a4c298e17fe.jpg' dosyası '154.jpg' olarak değiştirildi.
# '5cbb5ad5-39.jpeg' dosyası '155.jpeg' olarak değiştirildi.
# '5ce8ce0c-0075.jpg' dosyası '156.jpg' olarak değiştirildi.
# '5cf1b861-1_45.jpg' dosyası '157.jpg' olarak değiştirildi.
# '5dc36d3e-0219.jpg' dosyası '158.jpg' olarak değiştirildi.
# '5df5fb68-1697_PNG.rf.6e3a51c33982dbc6964dfb5ec86de664.jpg' dosyası '159.jpg' olarak değiştirildi.
# '5e404778-0003.jpg' dosyası '160.jpg' olarak değiştirildi.
# '5e74edcd-1668_PNG.rf.605b736cdf039421ecc684c38f72b733.jpg' dosyası '161.jpg' olarak değiştirildi.
# '5ed05a2f-1613_PNG.rf.396debae38885eca5b00f091832ab18f.jpg' dosyası '162.jpg' olarak değiştirildi.
# '5f7aff2c-1786_jpg.rf.60f1132a002824b313c723ed0f972056.jpg' dosyası '163.jpg' olarak değiştirildi.
# '61311d29-70.jpeg' dosyası '164.jpeg' olarak değiştirildi.
# '62b4fde4-1_36.jpg' dosyası '165.jpg' olarak değiştirildi.
# '6462d88b-118.jpeg' dosyası '166.jpeg' olarak değiştirildi.
# '648cd228-1753_jpg.rf.357a4563f930d6611d0f49b5b6656fc7.jpg' dosyası '167.jpg' olarak değiştirildi.
# '65a69694-1655_PNG.rf.e0cb12b407fe78eedbc8def68153c63e.jpg' dosyası '168.jpg' olarak değiştirildi.
# '65b2df56-1691_PNG.rf.ae1bc6b9b25ea4b79738e6a45ddf5995.jpg' dosyası '169.jpg' olarak değiştirildi.
# '67ac51bb-1602_jpg.rf.8c7a4219cf6dc6b9c7fefde52868491e.jpg' dosyası '170.jpg' olarak değiştirildi.
# '67d1e2c3-1.jpeg' dosyası '171.jpeg' olarak değiştirildi.
# '67f13abe-1726_PNG.rf.2777c20eef13bd411988ff6ffe9d5ef6.jpg' dosyası '172.jpg' olarak değiştirildi.
# '67fdeb95-1755_jpg.rf.193fb2d532426dc3f9441f3f37f7af44.jpg' dosyası '173.jpg' olarak değiştirildi.
# '68818419-43.jpeg' dosyası '174.jpeg' olarak değiştirildi.
# '68ed085e-117.jpeg' dosyası '175.jpeg' olarak değiştirildi.
# '69e08229-1643_PNG.rf.a1b53487e08dbd0722dbefaf04304423.jpg' dosyası '176.jpg' olarak değiştirildi.
# '6a220461-30.jpeg' dosyası '177.jpeg' olarak değiştirildi.
# '6abbf616-45.jpeg' dosyası '178.jpeg' olarak değiştirildi.
# '6ad8d69e-0101.jpg' dosyası '179.jpg' olarak değiştirildi.
# '6bfc0156-1732_PNG.rf.db83b2e6b7b80a6799b7d72c3d0edbb4.jpg' dosyası '180.jpg' olarak değiştirildi.
# '6c4426b2-92.jpeg' dosyası '181.jpeg' olarak değiştirildi.
# '6c5dae14-0096.jpg' dosyası '182.jpg' olarak değiştirildi.
# '6cf3dde7-119.jpeg' dosyası '183.jpeg' olarak değiştirildi.
# '6d0ebdf6-1688_PNG.rf.8eb4b86d39af14463008a809a436baa1.jpg' dosyası '184.jpg' olarak değiştirildi.
# '6dbb4573-1791_jpg.rf.09891e74bae412ac782c8a1e6c2ca4c0.jpg' dosyası '185.jpg' olarak değiştirildi.
# '6e025529-1_42.jpg' dosyası '186.jpg' olarak değiştirildi.
# '6eebf6df-1723_jpg.rf.f40fde3a704297994cf38903f8c8d865.jpg' dosyası '187.jpg' olarak değiştirildi.
# '6f133aa9-27.jpeg' dosyası '188.jpeg' olarak değiştirildi.
# '700714e1-1_31.jpg' dosyası '189.jpg' olarak değiştirildi.
# '70255337-0225.jpg' dosyası '190.jpg' olarak değiştirildi.
# '71279fb1-0089.jpg' dosyası '191.jpg' olarak değiştirildi.
# '719429c2-109.jpeg' dosyası '192.jpeg' olarak değiştirildi.
# '71f16ae8-1756_jpg.rf.54428ce468bcc7229771ae36ba8c69be.jpg' dosyası '193.jpg' olarak değiştirildi.
# '732e1f65-86.jpeg' dosyası '194.jpeg' olarak değiştirildi.
# '737a47c0-0064.jpg' dosyası '195.jpg' olarak değiştirildi.
# '74af603e-115.jpeg' dosyası '196.jpeg' olarak değiştirildi.
# '76995547-76.jpeg' dosyası '197.jpeg' olarak değiştirildi.
# '77503bf2-0236.jpg' dosyası '198.jpg' olarak değiştirildi.
# '777d68f1-0091.jpg' dosyası '199.jpg' olarak değiştirildi.
# '7802ab2a-1_46.jpg' dosyası '200.jpg' olarak değiştirildi.
# '782651d3-1615_jpg.rf.cff344e4990cfd17ad88510aebcf854c.jpg' dosyası '201.jpg' olarak değiştirildi.
# '7839c15e-0221.jpg' dosyası '202.jpg' olarak değiştirildi.
# '7890b6b7-0234.jpg' dosyası '203.jpg' olarak değiştirildi.
# '78f02b89-1677_jpg.rf.9e4eb3a6fe967ede7e97f250ba3f5bbc.jpg' dosyası '204.jpg' olarak değiştirildi.
# '791375df-1_14.jpg' dosyası '205.jpg' olarak değiştirildi.
# '79278cbe-79.jpeg' dosyası '206.jpeg' olarak değiştirildi.
# '794d7d9f-0085.jpg' dosyası '207.jpg' olarak değiştirildi.
# '7a0ab92b-77.jpeg' dosyası '208.jpeg' olarak değiştirildi.
# '7b81089b-104.jpeg' dosyası '209.jpeg' olarak değiştirildi.
# '7c10c980-1744_jpg.rf.647bdba2f100a85975c9f786348240a3.jpg' dosyası '210.jpg' olarak değiştirildi.
# '7c833491-97.jpeg' dosyası '211.jpeg' olarak değiştirildi.
# '7c93e453-1618_PNG.rf.10f7986858962a2856c8aa7a94a71931.jpg' dosyası '212.jpg' olarak değiştirildi.
# '7ca80f8f-0008.jpg' dosyası '213.jpg' olarak değiştirildi.
# '7ce843a8-95.jpeg' dosyası '214.jpeg' olarak değiştirildi.
# '7d011c4a-1603_PNG.rf.6d166768eb36c4b1316c825de79f41df.jpg' dosyası '215.jpg' olarak değiştirildi.
# '7ecc6207-1_11.jpg' dosyası '216.jpg' olarak değiştirildi.
# '7ee727b2-0044.jpg' dosyası '217.jpg' olarak değiştirildi.
# '80389cd3-1696_PNG.rf.b472fc8695d2ab88dd094063d9b24a56.jpg' dosyası '218.jpg' olarak değiştirildi.
# '803d03ae-1775_jpg.rf.43cdd8244e8caf22e38e5749c9a9d75e.jpg' dosyası '219.jpg' olarak değiştirildi.
# '805e7b0e-29.jpeg' dosyası '220.jpeg' olarak değiştirildi.
# '81928856-1781_jpg.rf.7566fa8793b388dfde462ec3bf2d17d8.jpg' dosyası '221.jpg' olarak değiştirildi.
# '81b2dc95-1713_PNG.rf.8090c7f14ff4b2a08c690f41f6997393.jpg' dosyası '222.jpg' olarak değiştirildi.
# '81e98155-0224.jpg' dosyası '223.jpg' olarak değiştirildi.
# '81ee5b03-1607_PNG.rf.d4019e916a08cac70af3e5764e98c8c4.jpg' dosyası '224.jpg' olarak değiştirildi.
# '8221dab8-1647_jpg.rf.82a8738ed5830f38a07a4280dc2c0243.jpg' dosyası '225.jpg' olarak değiştirildi.
# '8307a192-1792_jpg.rf.3f9ea897ca3b73a0f7f9533606cb3a2c.jpg' dosyası '226.jpg' olarak değiştirildi.
# '838742be-0090.jpg' dosyası '227.jpg' olarak değiştirildi.
# '83aa7d4c-63.jpeg' dosyası '228.jpeg' olarak değiştirildi.
# '84e4e25b-1764_jpg.rf.114f23651be64b7022449a110efad6e3.jpg' dosyası '229.jpg' olarak değiştirildi.
# '855608cf-0069.jpg' dosyası '230.jpg' olarak değiştirildi.
# '86198463-1661_PNG.rf.23a3dd11ce45b233cedc3ac5997e6353.jpg' dosyası '231.jpg' olarak değiştirildi.
# '8644a21b-0220.jpg' dosyası '232.jpg' olarak değiştirildi.
# '8680c82c-0226.jpg' dosyası '233.jpg' olarak değiştirildi.
# '87421135-0081.jpg' dosyası '234.jpg' olarak değiştirildi.
# '87abf076-1646_jpg.rf.82731b21b4771fdb3592e736be73b1cb.jpg' dosyası '235.jpg' olarak değiştirildi.
# '88d06ba0-0040.jpg' dosyası '236.jpg' olarak değiştirildi.
# '89408786-1670_PNG.rf.030aa3a65e8d64e3d96ac5df7497be40.jpg' dosyası '237.jpg' olarak değiştirildi.
# '89fd03ac-1746_PNG.rf.3489407de06c2a8fbcf9632c42b257ab.jpg' dosyası '238.jpg' olarak değiştirildi.
# '8a3d7f5d-0230.jpg' dosyası '239.jpg' olarak değiştirildi.
# '8a7097fe-1_23.jpg' dosyası '240.jpg' olarak değiştirildi.
# '8ac03289-36.jpeg' dosyası '241.jpeg' olarak değiştirildi.
# '8b050446-1702_PNG.rf.54f3d5e39a79b1a581827373d8b450a5.jpg' dosyası '242.jpg' olarak değiştirildi.
# '8ebeebe5-44.jpeg' dosyası '243.jpeg' olarak değiştirildi.
# '8ef74800-1669_PNG.rf.7e91984f73a9611d0d448e594d8d1d6b.jpg' dosyası '244.jpg' olarak değiştirildi.
# '8f8faa40-0088.jpg' dosyası '245.jpg' olarak değiştirildi.
# '90150186-111.jpeg' dosyası '246.jpeg' olarak değiştirildi.
# '903859c2-1686_PNG.rf.84d6f3a92daff2a89006077572b20254.jpg' dosyası '247.jpg' olarak değiştirildi.
# '9082763f-1_27.jpg' dosyası '248.jpg' olarak değiştirildi.
# '909495be-1761_jpg.rf.a11ab1efa0fbecfa5f4fee36de37200e.jpg' dosyası '249.jpg' olarak değiştirildi.
# '920e0485-1627_jpg.rf.12f3ea3462dcc7bcc2c9508c74efcff2.jpg' dosyası '250.jpg' olarak değiştirildi.
# '92673a9d-1799_jpg.rf.cecdfc4d5afe05133a94e055a88e88e3.jpg' dosyası '251.jpg' olarak değiştirildi.
# '93b34211-26.jpeg' dosyası '252.jpeg' olarak değiştirildi.
# '943070ce-0238.jpg' dosyası '253.jpg' olarak değiştirildi.
# '94589274-7.jpeg' dosyası '254.jpeg' olarak değiştirildi.
# '949f393a-1_7.jpg' dosyası '255.jpg' olarak değiştirildi.
# '94df85f7-1623_jpg.rf.bca18d31cb1b9bca228b0e1ca45c05f3.jpg' dosyası '256.jpg' olarak değiştirildi.
# '94f02707-1_29.jpg' dosyası '257.jpg' olarak değiştirildi.
# '9539b4a5-1690_PNG.rf.fc24b50b8be4ba35ef1bbf55a8ab33a0.jpg' dosyası '258.jpg' olarak değiştirildi.
# '95b6b888-1736_PNG.rf.e9111aef2b6e261ede550407bbcf7137.jpg' dosyası '259.jpg' olarak değiştirildi.
# '96407bd1-42.jpeg' dosyası '260.jpeg' olarak değiştirildi.
# '9710649e-1683_PNG.rf.2d59d3265d22c1d97e338e79862b7c47.jpg' dosyası '261.jpg' olarak değiştirildi.
# '9748d1ae-0083.jpg' dosyası '262.jpg' olarak değiştirildi.
# '97cd29b2-0072.jpg' dosyası '263.jpg' olarak değiştirildi.
# '97d8c3f2-51.jpeg' dosyası '264.jpeg' olarak değiştirildi.
# '97f3a32e-68.jpeg' dosyası '265.jpeg' olarak değiştirildi.
# '98167d6f-32.jpeg' dosyası '266.jpeg' olarak değiştirildi.
# '99053d60-1_2.jpg' dosyası '267.jpg' olarak değiştirildi.
# '99963d7f-0093.jpg' dosyası '268.jpg' olarak değiştirildi.
# '9a1dab73-67.jpeg' dosyası '269.jpeg' olarak değiştirildi.
# '9a43428b-100.jpeg' dosyası '270.jpeg' olarak değiştirildi.
# '9aaf32ea-1703_PNG.rf.18d30225b234fd56acdee9eb74cf1316.jpg' dosyası '271.jpg' olarak değiştirildi.
# '9ae67235-84.jpeg' dosyası '272.jpeg' olarak değiştirildi.
# '9bf9f126-1658_PNG.rf.04a4b616055e74857ea642a1e79dd1f7.jpg' dosyası '273.jpg' olarak değiştirildi.
# '9c13e582-1743_PNG.rf.824d8986d5a288b871ef2d9794fa243d.jpg' dosyası '274.jpg' olarak değiştirildi.
# '9c9ded32-1_25.jpg' dosyası '275.jpg' olarak değiştirildi.
# '9db7f854-1737_jpg.rf.c97afea9839adf066d66879dba1ba4b5.jpg' dosyası '276.jpg' olarak değiştirildi.
# '9f03aaf1-0217.jpg' dosyası '277.jpg' olarak değiştirildi.
# 'a01412df-1787_jpg.rf.cf706b3fccb03407de68d104809844d4.jpg' dosyası '278.jpg' olarak değiştirildi.
# 'a0f4772c-0084.jpg' dosyası '279.jpg' olarak değiştirildi.
# 'a12ddbe3-98.jpeg' dosyası '280.jpeg' olarak değiştirildi.
# 'a142abaf-75.jpeg' dosyası '281.jpeg' olarak değiştirildi.
# 'a29f462b-1654_jpg.rf.4113dd7d7a4f4140d5e878a586079707.jpg' dosyası '282.jpg' olarak değiştirildi.
# 'a2ba7fbd-83.jpeg' dosyası '283.jpeg' olarak değiştirildi.
# 'a356d54d-0050.jpg' dosyası '284.jpg' olarak değiştirildi.
# 'a3b6985c-0218.jpg' dosyası '285.jpg' olarak değiştirildi.
# 'a4437b94-0059.jpg' dosyası '286.jpg' olarak değiştirildi.
# 'a4a21ae0-72.jpeg' dosyası '287.jpeg' olarak değiştirildi.
# 'a5edd06c-1719_PNG.rf.a35dd12a163a3b22202401546bbabe64.jpg' dosyası '288.jpg' olarak değiştirildi.
# 'a60bdaf4-0054.jpg' dosyası '289.jpg' olarak değiştirildi.
# 'a70c2a64-1612_jpg.rf.db9803ce956db0c3a202d30ac15d868c.jpg' dosyası '290.jpg' olarak değiştirildi.
# 'a74c3e78-0231.jpg' dosyası '291.jpg' olarak değiştirildi.
# 'a7b60e87-1_20.jpg' dosyası '292.jpg' olarak değiştirildi.
# 'a96b80b9-1_41.jpg' dosyası '293.jpg' olarak değiştirildi.
# 'a9ac4738-1770_jpg.rf.74e197c75231d33c2eed4329f56aa591.jpg' dosyası '294.jpg' olarak değiştirildi.
# 'a9bbf681-1_13.jpg' dosyası '295.jpg' olarak değiştirildi.
# 'aa3bdf98-1_24.jpg' dosyası '296.jpg' olarak değiştirildi.
# 'aa76fbad-1_3.jpg' dosyası '297.jpg' olarak değiştirildi.
# 'aa96a935-1_15.jpg' dosyası '298.jpg' olarak değiştirildi.
# 'aab5d11c-1653_jpg.rf.8c8b1ea54bcaf07ad23a6fc49bf378a2.jpg' dosyası '299.jpg' olarak değiştirildi.
# 'aadccee2-85.jpeg' dosyası '300.jpeg' olarak değiştirildi.
# 'ab5f0a45-38.jpeg' dosyası '301.jpeg' olarak değiştirildi.
# 'abc004de-21.jpeg' dosyası '302.jpeg' olarak değiştirildi.
# 'abea5a1b-0024.jpg' dosyası '303.jpg' olarak değiştirildi.
# 'abf05682-66.jpeg' dosyası '304.jpeg' olarak değiştirildi.
# 'ac10d7c3-1767_jpg.rf.2c7f2ac953882c3d16d2bafeae8a8717.jpg' dosyası '305.jpg' olarak değiştirildi.
# 'ad43c3fb-1657_PNG.rf.81fa0c68dd47d716d2c00ff48054bfd2.jpg' dosyası '306.jpg' olarak değiştirildi.
# 'af266214-1673_jpg.rf.8a9fd1dfea1062b300f42077e25d4493.jpg' dosyası '307.jpg' olarak değiştirildi.
# 'af716351-1_33.jpg' dosyası '308.jpg' olarak değiştirildi.
# 'af892c4f-82.jpeg' dosyası '309.jpeg' olarak değiştirildi.
# 'afb84d8e-1733_PNG.rf.7514d7665fb47369cdb484e4e2f9e23a.jpg' dosyası '310.jpg' olarak değiştirildi.
# 'b145c1fc-0213.jpg' dosyası '311.jpg' olarak değiştirildi.
# 'b256906a-1_21.jpg' dosyası '312.jpg' olarak değiştirildi.
# 'b28c1191-1759_jpg.rf.c11a51a5e1717867e12bd7fe354d5171.jpg' dosyası '313.jpg' olarak değiştirildi.
# 'b2f0bbb8-1708_PNG.rf.c0a6aaa77116520cb3fbc45d03d2c1c3.jpg' dosyası '314.jpg' olarak değiştirildi.
# 'b32ad4bf-101.jpeg' dosyası '315.jpeg' olarak değiştirildi.
# 'b3b57887-1_34.jpg' dosyası '316.jpg' olarak değiştirildi.
# 'b45b35b5-0034.jpg' dosyası '317.jpg' olarak değiştirildi.
# 'b49121ca-1681_PNG.rf.3f20b7d1c96c7cbe0fb51dae645325f1.jpg' dosyası '318.jpg' olarak değiştirildi.
# 'b4f5849c-1662_PNG.rf.67682d2b339b7fee82dd3c28818886f8.jpg' dosyası '319.jpg' olarak değiştirildi.
# 'b533df79-0028.jpg' dosyası '320.jpg' olarak değiştirildi.
# 'b62fbffa-1_22.jpg' dosyası '321.jpg' olarak değiştirildi.
# 'b720d066-34.jpeg' dosyası '322.jpeg' olarak değiştirildi.
# 'b78e7299-1629_jpg.rf.466d8c46b45580f5b41679e285aa631e.jpg' dosyası '323.jpg' olarak değiştirildi.
# 'b7f9e362-1741_PNG.rf.fb85a79ffa9ad2116cc54de893655140.jpg' dosyası '324.jpg' olarak değiştirildi.
# 'b839b376-55.jpeg' dosyası '325.jpeg' olarak değiştirildi.
# 'b8d4140b-1620_PNG.rf.c8135c08d7fc7556635622edb312111d.jpg' dosyası '326.jpg' olarak değiştirildi.
# 'b8ef4543-0042.jpg' dosyası '327.jpg' olarak değiştirildi.
# 'b93f4047-54.jpeg' dosyası '328.jpeg' olarak değiştirildi.
# 'b96d0dc4-107.jpeg' dosyası '329.jpeg' olarak değiştirildi.
# 'b9d22e87-35.jpeg' dosyası '330.jpeg' olarak değiştirildi.
# 'ba595c96-81.jpeg' dosyası '331.jpeg' olarak değiştirildi.
# 'bab4441f-1644_PNG.rf.b37c19a29ff3839987ba9b07635ee7de.jpg' dosyası '332.jpg' olarak değiştirildi.
# 'bb21eb31-1728_PNG.rf.995f7204141083d315a40d46c90cb88a.jpg' dosyası '333.jpg' olarak değiştirildi.
# 'bb32bcaf-0063.jpg' dosyası '334.jpg' olarak değiştirildi.
# 'bda32f55-1676_jpg.rf.1c4ef760e03984b95fceccafb558149a.jpg' dosyası '335.jpg' olarak değiştirildi.
# 'bfeb10b0-2.jpeg' dosyası '336.jpeg' olarak değiştirildi.
# 'c1521c77-0073.jpg' dosyası '337.jpg' olarak değiştirildi.
# 'c221f5a4-1721_PNG.rf.c0d9ba50a0fa4b4184435e63515ac7d0.jpg' dosyası '338.jpg' olarak değiştirildi.
# 'c265d051-0029.jpg' dosyası '339.jpg' olarak değiştirildi.
# 'c3c6def7-1718_jpg.rf.61431c72a4e9ad50e29a7239a20eb35d.jpg' dosyası '340.jpg' olarak değiştirildi.
# 'c462f393-1762_jpg.rf.f27eaa7e6fceed5da298124913a70a7e.jpg' dosyası '341.jpg' olarak değiştirildi.
# 'c47f8da8-0079.jpg' dosyası '342.jpg' olarak değiştirildi.
# 'c546bafc-1706_PNG.rf.36831c2b410c906b8d47594dddd6f5af.jpg' dosyası '343.jpg' olarak değiştirildi.
# 'c5fe9820-1_44.jpg' dosyası '344.jpg' olarak değiştirildi.
# 'c6aaa8a2-1694_jpg.rf.ed6dc5e01fd7c98aa999a58916748a09.jpg' dosyası '345.jpg' olarak değiştirildi.
# 'c721a9ed-3.jpeg' dosyası '346.jpeg' olarak değiştirildi.
# 'c7a74425-87.jpeg' dosyası '347.jpeg' olarak değiştirildi.
# 'c7f8628a-1720_jpg.rf.16d408948cf6119d5a4756c8bccd41b7.jpg' dosyası '348.jpg' olarak değiştirildi.
# 'c8211eb9-41.jpeg' dosyası '349.jpeg' olarak değiştirildi.
# 'c9188ba4-20.jpeg' dosyası '350.jpeg' olarak değiştirildi.
# 'c9540f1b-0222.jpg' dosyası '351.jpg' olarak değiştirildi.
# 'cafc08b6-1793_jpg.rf.d3f40cdf81e882b2d5f728a2d8a1116e.jpg' dosyası '352.jpg' olarak değiştirildi.
# 'cc20ecce-105.jpeg' dosyası '353.jpeg' olarak değiştirildi.
# 'cd44812a-57.jpeg' dosyası '354.jpeg' olarak değiştirildi.
# 'cd4a4aeb-1675_jpg.rf.e01028657d3096eec2b2de21149b3d66.jpg' dosyası '355.jpg' olarak değiştirildi.
# 'cf444842-1754_jpg.rf.e81151bda74098dbd185717b9895327c.jpg' dosyası '356.jpg' olarak değiştirildi.
# 'cfb91fb1-0033.jpg' dosyası '357.jpg' olarak değiştirildi.
# 'd03bd268-60.jpeg' dosyası '358.jpeg' olarak değiştirildi.
# 'd05f3296-1659_jpg.rf.8d7bb2e6cfdcc0e159f0b474d736cd23.jpg' dosyası '359.jpg' olarak değiştirildi.
# 'd0742092-1622_PNG.rf.e36fec1f97a252f70d588f68afe30348.jpg' dosyası '360.jpg' olarak değiştirildi.
# 'd0995fae-80.jpeg' dosyası '361.jpeg' olarak değiştirildi.
# 'd21e6439-1_50.jpg' dosyası '362.jpg' olarak değiştirildi.
# 'd2ee9016-1772_jpg.rf.4bd8bed20b8bd1ad01c92fb1a4754188.jpg' dosyası '363.jpg' olarak değiştirildi.
# 'd2fc6a50-1785_jpg.rf.2d90f49b241b0b35743780d3005757f3.jpg' dosyası '364.jpg' olarak değiştirildi.
# 'd3ef9536-90.jpeg' dosyası '365.jpeg' olarak değiştirildi.
# 'd3f28551-0006.jpg' dosyası '366.jpg' olarak değiştirildi.
# 'd8f834e7-0046.jpg' dosyası '367.jpg' olarak değiştirildi.
# 'd9567c05-1777_jpg.rf.c66c9ebc785b4da31e26ea4c4e4a62a1.jpg' dosyası '368.jpg' olarak değiştirildi.
# 'dab1a68a-58.jpeg' dosyası '369.jpeg' olarak değiştirildi.
# 'dc678330-1716_PNG.rf.cfbf2315987a71caf669148f9a7c49c8.jpg' dosyası '370.jpg' olarak değiştirildi.
# 'dc95075d-0227.jpg' dosyası '371.jpg' olarak değiştirildi.
# 'ddc29556-14.jpeg' dosyası '372.jpeg' olarak değiştirildi.
# 'dddb4611-1619_PNG.rf.68121fa178da57a3fd9cda380e621e7f.jpg' dosyası '373.jpg' olarak değiştirildi.
# 'de87817d-102.jpeg' dosyası '374.jpeg' olarak değiştirildi.
# 'df0754a1-1_38.jpg' dosyası '375.jpg' olarak değiştirildi.
# 'df375901-1798_jpg.rf.9a493318f212c6c98f4a3f05a13eea76.jpg' dosyası '376.jpg' olarak değiştirildi.
# 'e081c843-1680_PNG.rf.595af6bbc3bb467115095dad4bfbd882.jpg' dosyası '377.jpg' olarak değiştirildi.
# 'e0f36324-0092.jpg' dosyası '378.jpg' olarak değiştirildi.
# 'e17759a4-1707_PNG.rf.5b7aedaf6c782601d5c84f9f9c424f0c.jpg' dosyası '379.jpg' olarak değiştirildi.
# 'e1d24eab-1_30.jpg' dosyası '380.jpg' olarak değiştirildi.
# 'e38e7016-46.jpeg' dosyası '381.jpeg' olarak değiştirildi.
# 'e4a2b888-8.jpeg' dosyası '382.jpeg' olarak değiştirildi.
# 'e5b0c2ed-62.jpeg' dosyası '383.jpeg' olarak değiştirildi.
# 'e6982b76-1666_jpg.rf.e68005fe22293d8ed65be81b5b55284d.jpg' dosyası '384.jpg' olarak değiştirildi.
# 'e70d1094-0087.jpg' dosyası '385.jpg' olarak değiştirildi.
# 'e7127bc8-1_32.jpg' dosyası '386.jpg' olarak değiştirildi.
# 'e73e7e75-1639_jpg.rf.b4eac3ce5250218c0d71ec912d61d963.jpg' dosyası '387.jpg' olarak değiştirildi.
# 'e92b2b29-24.jpeg' dosyası '388.jpeg' olarak değiştirildi.
# 'e94cb7b6-1617_jpg.rf.ffd5a7b7438d823a2343a12dada12089.jpg' dosyası '389.jpg' olarak değiştirildi.
# 'e9d316ee-1_26.jpg' dosyası '390.jpg' olarak değiştirildi.
# 'e9e29f7a-1757_jpg.rf.0350296277c5e74975cb293635e7b5dc.jpg' dosyası '391.jpg' olarak değiştirildi.
# 'eb00d7b8-1727_jpg.rf.ad46560655772135795a2e4222114f09.jpg' dosyası '392.jpg' olarak değiştirildi.
# 'ebcbf784-96.jpeg' dosyası '393.jpeg' olarak değiştirildi.
# 'ec797a9c-6.jpeg' dosyası '394.jpeg' olarak değiştirildi.
# 'eca6a23e-0070.jpg' dosyası '395.jpg' olarak değiştirildi.
# 'ed90f69c-0080.jpg' dosyası '396.jpg' olarak değiştirildi.
# 'edfda87b-0009.jpg' dosyası '397.jpg' olarak değiştirildi.
# 'eec1b9d0-1752_jpg.rf.da77149bb6e9ba4f77b32966f7ebcad9.jpg' dosyası '398.jpg' olarak değiştirildi.
# 'ef74cb90-1722_PNG.rf.ec0f20690e2589ea7c280eb51e5f1d26.jpg' dosyası '399.jpg' olarak değiştirildi.
# 'f351df95-69.jpeg' dosyası '400.jpeg' olarak değiştirildi.
# 'f4911c6a-1751_jpg.rf.d9e04a1de46a4a8b41783115c3cc9287.jpg' dosyası '401.jpg' olarak değiştirildi.
# 'f4cae116-1667_PNG.rf.ecd602065f602d50f1ec516562c2965b.jpg' dosyası '402.jpg' olarak değiştirildi.
# 'f4ec2535-1614_PNG.rf.75684e57f15200631b982e4b8c2c3c0a.jpg' dosyası '403.jpg' olarak değiştirildi.
# 'f5640b71-1609_jpg.rf.0948d1a01e1a2f3b2bee3b24df4eb1c4.jpg' dosyası '404.jpg' olarak değiştirildi.
# 'f5be5af7-0082.jpg' dosyası '405.jpg' olarak değiştirildi.
# 'f6727d0c-1739_jpg.rf.bcde1e5fe8247bf993bb8884a93255ae.jpg' dosyası '406.jpg' olarak değiştirildi.
# 'f6f65f7a-1_43.jpg' dosyası '407.jpg' olarak değiştirildi.
# 'f70d040e-1611_PNG.rf.60c1f6ab00a0c01c086bb26321984b09.jpg' dosyası '408.jpg' olarak değiştirildi.
# 'f72a7067-1715_jpg.rf.e4bac7da8a02b72bc21c762435c65426.jpg' dosyası '409.jpg' olarak değiştirildi.
# 'f793f894-0005.jpg' dosyası '410.jpg' olarak değiştirildi.
# 'f9207dd2-0037.jpg' dosyası '411.jpg' olarak değiştirildi.
# 'f95acc38-0052.jpg' dosyası '412.jpg' olarak değiştirildi.
# 'fa654e5c-0086.jpg' dosyası '413.jpg' olarak değiştirildi.
# 'fab5c405-112.jpeg' dosyası '414.jpeg' olarak değiştirildi.
# 'fafdd005-1656_PNG.rf.121cc7aacdda6227ead175776ac86d8b.jpg' dosyası '415.jpg' olarak değiştirildi.
# 'fd1ad646-1_1.jpg' dosyası '416.jpg' olarak değiştirildi.
# 'fd948ebb-19.jpeg' dosyası '417.jpeg' olarak değiştirildi.
# Dosya isimlendirme işlemi tamamlandı.

# %%
import os

# Dosyaların bulunduğu klasörün yolu
folder_path = 'C:/Users/edana/Desktop/dataset_new/UAV/normalized_images'

# Dosya isimlerini değiştirmek için başlangıç numarası
start_number = 418
end_number = 1100

# Klasördeki tüm dosyaları al
files = os.listdir(folder_path)

# Sadece dosya olanları al (klasörleri hariç tut)
files = [f for f in files if os.path.isfile(os.path.join(folder_path, f))]

# Dosyaları sıralı olarak yeniden isimlendirme işlemi
for i, file_name in enumerate(files):
    if i < end_number:
        # Dosyanın uzantısını al
        file_extension = os.path.splitext(file_name)[1]
        # Yeni dosya adını oluştur
        new_name = f"{start_number + i}{file_extension}"
        # Eski ve yeni dosya yollarını oluştur
        old_file_path = os.path.join(folder_path, file_name)
        new_file_path = os.path.join(folder_path, new_name)
        # Dosya ismini değiştir
        os.rename(old_file_path, new_file_path)
        print(f"'{file_name}' dosyası '{new_name}' olarak değiştirildi.")
    else:
        break

print("Dosya isimlendirme işlemi tamamlandı.")
# Out:
# '01f09349-47.jpeg' dosyası '418.jpeg' olarak değiştirildi.
# '01f14498-1_37.jpg' dosyası '419.jpg' olarak değiştirildi.
# '03235c10-1_10.jpg' dosyası '420.jpg' olarak değiştirildi.
# '032b8fc0-0095.jpg' dosyası '421.jpg' olarak değiştirildi.
# '0439f4e3-0237.jpg' dosyası '422.jpg' olarak değiştirildi.
# '04e13cc4-1704_jpg.rf.75c3676a3b249fe28258cf7edc78685e.jpg' dosyası '423.jpg' olarak değiştirildi.
# '0573af8e-1652_PNG.rf.41631d03f2ed222667877a536b01ced9.jpg' dosyası '424.jpg' olarak değiştirildi.
# '059a0726-33.jpeg' dosyası '425.jpeg' olarak değiştirildi.
# '05ea4ee7-1_12.jpg' dosyası '426.jpg' olarak değiştirildi.
# '06709e94-1_5.jpg' dosyası '427.jpg' olarak değiştirildi.
# '06ee1fa3-56.jpeg' dosyası '428.jpeg' olarak değiştirildi.
# '0766dc07-91.jpeg' dosyası '429.jpeg' olarak değiştirildi.
# '078f7569-1738_PNG.rf.760ee524c0edd762b2252027a0e1f1cb.jpg' dosyası '430.jpg' olarak değiştirildi.
# '089c260f-0001.jpg' dosyası '431.jpg' olarak değiştirildi.
# '08d06b6e-1784_jpg.rf.3d8a198eabaf697d14df17098004f016.jpg' dosyası '432.jpg' olarak değiştirildi.
# '09e7187b-1626_jpg.rf.da41bff1520ebed0a36aa35c64acd9a0.jpg' dosyası '433.jpg' olarak değiştirildi.
# '0a95ec6e-1758_jpg.rf.edec6d2de3c4f28886ab7dfc9fa45d0b.jpg' dosyası '434.jpg' olarak değiştirildi.
# '0aa31dc9-1_6.jpg' dosyası '435.jpg' olarak değiştirildi.
# '0da650df-1_49.jpg' dosyası '436.jpg' olarak değiştirildi.
# '0e026ff8-0048.jpg' dosyası '437.jpg' olarak değiştirildi.
# '0f22034a-1745_jpg.rf.bdbb6df36d8da1d8223cd40b0a6d8eb0.jpg' dosyası '438.jpg' olarak değiştirildi.
# '0f5cf83b-0228.jpg' dosyası '439.jpg' olarak değiştirildi.
# '11719f3f-0097.jpg' dosyası '440.jpg' olarak değiştirildi.
# '117d2488-1640_jpg.rf.a262659a6df5f26c64b5c8a795640ac6.jpg' dosyası '441.jpg' olarak değiştirildi.
# '11daa65d-1763_jpg.rf.21566c2cc30e771fcccda139d075855b.jpg' dosyası '442.jpg' olarak değiştirildi.
# '11e9053b-1679_jpg.rf.431b9419b1099be607c6a84e4f622dde.jpg' dosyası '443.jpg' olarak değiştirildi.
# '121ae19f-1749_jpg.rf.ba8439d61d4699b0212205bf7c333822.jpg' dosyası '444.jpg' olarak değiştirildi.
# '136d9ef5-1625_PNG.rf.5a94fc4e6ff595ae9dcbc4c1d202631c.jpg' dosyası '445.jpg' olarak değiştirildi.
# '138e133d-48.jpeg' dosyası '446.jpeg' olarak değiştirildi.
# '141a1661-74.jpeg' dosyası '447.jpeg' olarak değiştirildi.
# '144403a8-1789_jpg.rf.b3176e95278090aba73805531c03b4c0.jpg' dosyası '448.jpg' olarak değiştirildi.
# '145bbe5f-1665_PNG.rf.605d3378a7afe49e55947086a4260a0a.jpg' dosyası '449.jpg' olarak değiştirildi.
# '149117c6-0223.jpg' dosyası '450.jpg' olarak değiştirildi.
# '14b4f270-0068.jpg' dosyası '451.jpg' olarak değiştirildi.
# '14cceeaf-1_9.jpg' dosyası '452.jpg' olarak değiştirildi.
# '1502730c-1768_jpg.rf.a8ee9182c0748cd7fa90986567524b3a.jpg' dosyası '453.jpg' olarak değiştirildi.
# '172f735b-1628_PNG.rf.eda1e3e31a2bf5e31a1a72b9257b55e0.jpg' dosyası '454.jpg' olarak değiştirildi.
# '175f8f8e-23.jpeg' dosyası '455.jpeg' olarak değiştirildi.
# '179d607f-1687_PNG.rf.0b3fdfd3efbf1187d39b933349326393.jpg' dosyası '456.jpg' olarak değiştirildi.
# '17a73a88-114.jpeg' dosyası '457.jpeg' olarak değiştirildi.
# '191ff427-1729_PNG.rf.882450f0e8cca8d9125b309e128e1f44.jpg' dosyası '458.jpg' olarak değiştirildi.
# '1b3b6c83-1_18.jpg' dosyası '459.jpg' olarak değiştirildi.
# '1b6cf79d-1698_jpg.rf.8cfef565573232ca15d37050fb536ef6.jpg' dosyası '460.jpg' olarak değiştirildi.
# '1c93eda3-1773_jpg.rf.33b0b82a7101d1c10e6ead694a18b9ff.jpg' dosyası '461.jpg' olarak değiştirildi.
# '1e15a4dd-0058.jpg' dosyası '462.jpg' olarak değiştirildi.
# '1e420c26-1769_jpg.rf.732e05e08d3754c673f9e86a140174d5.jpg' dosyası '463.jpg' olarak değiştirildi.
# '1e69dc4b-1638_PNG.rf.afcd87ee2974bb029d0105db7e2fdd69.jpg' dosyası '464.jpg' olarak değiştirildi.
# '1eb9e1ed-1616_PNG.rf.5a48524b1275508dfb7b452f67fe7132.jpg' dosyası '465.jpg' olarak değiştirildi.
# '1f863c4f-0030.jpg' dosyası '466.jpg' olarak değiştirildi.
# '20af207e-1678_jpg.rf.a3a5aaafe0ed424e30c7a5e580b4fc23.jpg' dosyası '467.jpg' olarak değiştirildi.
# '21b889cc-0056.jpg' dosyası '468.jpg' olarak değiştirildi.
# '21fb86ee-1783_jpg.rf.ba3ad9d74288768b73176400feeb42ba.jpg' dosyası '469.jpg' olarak değiştirildi.
# '2297e830-1692_jpg.rf.ee35dc8c4a5c2460e22cc8a61c8abc5d.jpg' dosyası '470.jpg' olarak değiştirildi.
# '2332444a-1747_jpg.rf.8a7f664bfbae7aa0f8b4a54eb3cdfac5.jpg' dosyası '471.jpg' olarak değiştirildi.
# '23d08d00-1695_PNG.rf.e827534c59bca1fff23b34ced296a5d6.jpg' dosyası '472.jpg' olarak değiştirildi.
# '242c4d00-40.jpeg' dosyası '473.jpeg' olarak değiştirildi.
# '252ca85e-1610_PNG.rf.779bb6d7894aaf49143cd161ce92482d.jpg' dosyası '474.jpg' olarak değiştirildi.
# '256498ca-1712_jpg.rf.5630366560cba451a391a2559bfb611c.jpg' dosyası '475.jpg' olarak değiştirildi.
# '26e704ac-1710_PNG.rf.b31e1ab05dec9c94ae0d02be58918c78.jpg' dosyası '476.jpg' olarak değiştirildi.
# '272a5f8b-0071.jpg' dosyası '477.jpg' olarak değiştirildi.
# '281bf2d9-1631_PNG.rf.3593414c6d9041a99bb90a98fd7a226d.jpg' dosyası '478.jpg' olarak değiştirildi.
# '29047177-1730_jpg.rf.de41605f63fb477f2d3132791c4f620a.jpg' dosyası '479.jpg' olarak değiştirildi.
# '290df7a9-1664_jpg.rf.efbe4de923eabd446bc1fb4009aa53b7.jpg' dosyası '480.jpg' olarak değiştirildi.
# '290f4225-1682_jpg.rf.8bbda5f3f2b76f2428c8209a4d4c1812.jpg' dosyası '481.jpg' olarak değiştirildi.
# '291e6e0f-1782_jpg.rf.73b92dfad04fd7fd0d6df003eeb95e3a.jpg' dosyası '482.jpg' olarak değiştirildi.
# '2b85dc59-1734_jpg.rf.14f01407f6485735401f88c2903906f9.jpg' dosyası '483.jpg' olarak değiştirildi.
# '2bc989a1-0215.jpg' dosyası '484.jpg' olarak değiştirildi.
# '2bcc1992-1760_jpg.rf.f01a0e02fe82f774d799b6c0cdf93751.jpg' dosyası '485.jpg' olarak değiştirildi.
# '2bda6acc-0025.jpg' dosyası '486.jpg' olarak değiştirildi.
# '2c790ddf-1_47.jpg' dosyası '487.jpg' olarak değiştirildi.
# '2c9f0310-88.jpeg' dosyası '488.jpeg' olarak değiştirildi.
# '2cf05c47-1_35.jpg' dosyası '489.jpg' olarak değiştirildi.
# '2d03980b-1724_PNG.rf.268edb49e3dc99988edb1285034a34f4.jpg' dosyası '490.jpg' olarak değiştirildi.
# '2d050469-0061.jpg' dosyası '491.jpg' olarak değiştirildi.
# '2de11f3d-1765_jpg.rf.84799cca6abb8049bb2f3d13bcbc5529.jpg' dosyası '492.jpg' olarak değiştirildi.
# '2e5ada57-1776_jpg.rf.abfe7c5d91dcc5c821a3e41ab884caea.jpg' dosyası '493.jpg' olarak değiştirildi.
# '2f47dc4d-1701_PNG.rf.db8e3d7c7ed938e6772e9272454cc895.jpg' dosyası '494.jpg' olarak değiştirildi.
# '2f498b32-1800_jpg.rf.4e8ff95ae1039719d9708a2b09fea3d3.jpg' dosyası '495.jpg' olarak değiştirildi.
# '2f774247-0232.jpg' dosyası '496.jpg' olarak değiştirildi.
# '2fb271e3-110.jpeg' dosyası '497.jpeg' olarak değiştirildi.
# '2fb9c374-10.jpeg' dosyası '498.jpeg' olarak değiştirildi.
# '30969694-1700_jpg.rf.97ad2f2f3f0f4a12c1744a81688e4b35.jpg' dosyası '499.jpg' olarak değiştirildi.
# '30d86b36-1_16.jpg' dosyası '500.jpg' olarak değiştirildi.
# '318223a8-59.jpeg' dosyası '501.jpeg' olarak değiştirildi.
# '32d8a231-1709_PNG.rf.b8c97dbf24b35eb9753beca1eb85bbbf.jpg' dosyası '502.jpg' olarak değiştirildi.
# '32fbd758-1693_PNG.rf.dc50a9c21776f1f640def875acc348d4.jpg' dosyası '503.jpg' olarak değiştirildi.
# '33953287-31.jpeg' dosyası '504.jpeg' olarak değiştirildi.
# '33d405de-89.jpeg' dosyası '505.jpeg' olarak değiştirildi.
# '341ffde7-1794_jpg.rf.733583058330201835117194be53c526.jpg' dosyası '506.jpg' olarak değiştirildi.
# '34a8e88f-49.jpeg' dosyası '507.jpeg' olarak değiştirildi.
# '35d1a03a-0032.jpg' dosyası '508.jpg' olarak değiştirildi.
# '366fedf9-1_8.jpg' dosyası '509.jpg' olarak değiştirildi.
# '37326e7c-0004.jpg' dosyası '510.jpg' olarak değiştirildi.
# '38edbc1f-1_17.jpg' dosyası '511.jpg' olarak değiştirildi.
# '3914bf0d-1_48.jpg' dosyası '512.jpg' olarak değiştirildi.
# '39a2ff1a-1689_jpg.rf.1870d81654b2898fc10cdd88fba1103b.jpg' dosyası '513.jpg' olarak değiştirildi.
# '39afc5bd-1699_PNG.rf.f00262370ada3df7813f8abf9dbaaea6.jpg' dosyası '514.jpg' olarak değiştirildi.
# '3a97176f-0007.jpg' dosyası '515.jpg' olarak değiştirildi.
# '3abde690-1705_PNG.rf.5daecef458f44b8f3f653315c06cef2d.jpg' dosyası '516.jpg' olarak değiştirildi.
# '3ac3f3cd-0074.jpg' dosyası '517.jpg' olarak değiştirildi.
# '3b0a78c0-0026.jpg' dosyası '518.jpg' olarak değiştirildi.
# '3b6de15d-1_4.jpg' dosyası '519.jpg' olarak değiştirildi.
# '3bd136b9-93.jpeg' dosyası '520.jpeg' olarak değiştirildi.
# '3c819c48-0094.jpg' dosyası '521.jpg' olarak değiştirildi.
# '3cbcfbfe-1_39.jpg' dosyası '522.jpg' olarak değiştirildi.
# '3d0b6bf7-1608_PNG.rf.8f8e8bc34dad875ac7510e2d08526799.jpg' dosyası '523.jpg' olarak değiştirildi.
# '3d4ba054-25.jpeg' dosyası '524.jpeg' olarak değiştirildi.
# '3e000fff-0216.jpg' dosyası '525.jpg' olarak değiştirildi.
# '3fe5cd20-1_28.jpg' dosyası '526.jpg' olarak değiştirildi.
# '4082834b-1797_jpg.rf.ba7cb0c088bbb76cde14f84d753a4198.jpg' dosyası '527.jpg' olarak değiştirildi.
# '40b06903-4.jpeg' dosyası '528.jpeg' olarak değiştirildi.
# '41758738-5.jpeg' dosyası '529.jpeg' olarak değiştirildi.
# '41ff7b0a-11.jpeg' dosyası '530.jpeg' olarak değiştirildi.
# '4270aeb2-1779_jpg.rf.ac0d8d4aea4ca7d703fa97feec895c1c.jpg' dosyası '531.jpg' olarak değiştirildi.
# '43f7d0d0-1748_jpg.rf.848c4824398270597a1996ea57155e8d.jpg' dosyası '532.jpg' olarak değiştirildi.
# '43fd8d51-103.jpeg' dosyası '533.jpeg' olarak değiştirildi.
# '446022df-1714_PNG.rf.e1a11f9a67e571c2b6e0221e0acbb29e.jpg' dosyası '534.jpg' olarak değiştirildi.
# '44a27934-1711_PNG.rf.994ceebb4d4de24b1c737b63782ac5f3.jpg' dosyası '535.jpg' olarak değiştirildi.
# '450fcc6d-1788_jpg.rf.aa4b353a44b48103a347de07db99006b.jpg' dosyası '536.jpg' olarak değiştirildi.
# '4741334d-1740_PNG.rf.f8c4d16b445e2de5edaddbcfaf739860.jpg' dosyası '537.jpg' olarak değiştirildi.
# '48c11af5-50.jpeg' dosyası '538.jpeg' olarak değiştirildi.
# '4942c5da-9.jpeg' dosyası '539.jpeg' olarak değiştirildi.
# '4a3158dc-1731_jpg.rf.bd7aab9f4ddd8d04294b70c6c5c61894.jpg' dosyası '540.jpg' olarak değiştirildi.
# '4b698730-1766_jpg.rf.213a245a2d9d0a4dcc100571ef1528a7.jpg' dosyası '541.jpg' olarak değiştirildi.
# '4bf61371-1684_jpg.rf.5ff2f366337e04e8be46a047332a5307.jpg' dosyası '542.jpg' olarak değiştirildi.
# '4c1e9eb6-1650_jpg.rf.6e138f8c66d2d62d2f84f50e8e0958a9.jpg' dosyası '543.jpg' olarak değiştirildi.
# '4c2a2626-108.jpeg' dosyası '544.jpeg' olarak değiştirildi.
# '4d7dbbd0-0214.jpg' dosyası '545.jpg' olarak değiştirildi.
# '4e9a4cc3-0065.jpg' dosyası '546.jpg' olarak değiştirildi.
# '4f126336-116.jpeg' dosyası '547.jpeg' olarak değiştirildi.
# '4fc9dc9e-1685_PNG.rf.6fe6627ad4eb31b35b45b3ed6416e58d.jpg' dosyası '548.jpg' olarak değiştirildi.
# '4fded54d-71.jpeg' dosyası '549.jpeg' olarak değiştirildi.
# '4ffc68a2-28.jpeg' dosyası '550.jpeg' olarak değiştirildi.
# '50fcea93-0039.jpg' dosyası '551.jpg' olarak değiştirildi.
# '519374a5-1796_jpg.rf.29e87505fe19d9ca298c07f128b9020d.jpg' dosyası '552.jpg' olarak değiştirildi.
# '5296708c-1674_jpg.rf.201552149988fc445579febd17b93f4a.jpg' dosyası '553.jpg' olarak değiştirildi.
# '5398dd4f-1621_PNG.rf.7e367626dfb3ea2ee8661ecb2e31be00.jpg' dosyası '554.jpg' olarak değiştirildi.
# '53bc80a6-1663_PNG.rf.806493996f980213411ca39950299d01.jpg' dosyası '555.jpg' olarak değiştirildi.
# '54e18b8b-0049.jpg' dosyası '556.jpg' olarak değiştirildi.
# '5535c582-0035.jpg' dosyası '557.jpg' olarak değiştirildi.
# '55c2f987-1750_jpg.rf.10aa88c6b5fb8e3c4c05be923da87537.jpg' dosyası '558.jpg' olarak değiştirildi.
# '55e0495e-1671_jpg.rf.2b05de921321bea3f3982158042fda79.jpg' dosyası '559.jpg' olarak değiştirildi.
# '56538f0e-1672_PNG.rf.4619877de1c7477fdacc0d85b2015627.jpg' dosyası '560.jpg' olarak değiştirildi.
# '5726a329-1_40.jpg' dosyası '561.jpg' olarak değiştirildi.
# '57c9d404-1795_jpg.rf.e149398595abe4ab13782c4caa4e9102.jpg' dosyası '562.jpg' olarak değiştirildi.
# '582b15c9-1771_jpg.rf.1118fce5351a6cdc903bbd0e1c171d85.jpg' dosyası '563.jpg' olarak değiştirildi.
# '5835b201-0229.jpg' dosyası '564.jpg' olarak değiştirildi.
# '58d92291-1_19.jpg' dosyası '565.jpg' olarak değiştirildi.
# '59603489-1632_PNG.rf.d73ba021479cfecd5560ee3d259f4fb4.jpg' dosyası '566.jpg' olarak değiştirildi.
# '596367e7-106.jpeg' dosyası '567.jpeg' olarak değiştirildi.
# '59d39757-1735_PNG.rf.82b871de5a1d781af5f3baab3cf03687.jpg' dosyası '568.jpg' olarak değiştirildi.
# '5b5d768c-73.jpeg' dosyası '569.jpeg' olarak değiştirildi.
# '5baa4e15-1778_jpg.rf.d1ad8c0f211636c63f4e19f52941fb98.jpg' dosyası '570.jpg' olarak değiştirildi.
# '5cad6e06-1725_PNG.rf.74473d308ec6f51028fe7a4c298e17fe.jpg' dosyası '571.jpg' olarak değiştirildi.
# '5cbb5ad5-39.jpeg' dosyası '572.jpeg' olarak değiştirildi.
# '5ce8ce0c-0075.jpg' dosyası '573.jpg' olarak değiştirildi.
# '5cf1b861-1_45.jpg' dosyası '574.jpg' olarak değiştirildi.
# '5dc36d3e-0219.jpg' dosyası '575.jpg' olarak değiştirildi.
# '5df5fb68-1697_PNG.rf.6e3a51c33982dbc6964dfb5ec86de664.jpg' dosyası '576.jpg' olarak değiştirildi.
# '5e404778-0003.jpg' dosyası '577.jpg' olarak değiştirildi.
# '5e74edcd-1668_PNG.rf.605b736cdf039421ecc684c38f72b733.jpg' dosyası '578.jpg' olarak değiştirildi.
# '5ed05a2f-1613_PNG.rf.396debae38885eca5b00f091832ab18f.jpg' dosyası '579.jpg' olarak değiştirildi.
# '5f7aff2c-1786_jpg.rf.60f1132a002824b313c723ed0f972056.jpg' dosyası '580.jpg' olarak değiştirildi.
# '61311d29-70.jpeg' dosyası '581.jpeg' olarak değiştirildi.
# '62b4fde4-1_36.jpg' dosyası '582.jpg' olarak değiştirildi.
# '6462d88b-118.jpeg' dosyası '583.jpeg' olarak değiştirildi.
# '648cd228-1753_jpg.rf.357a4563f930d6611d0f49b5b6656fc7.jpg' dosyası '584.jpg' olarak değiştirildi.
# '65a69694-1655_PNG.rf.e0cb12b407fe78eedbc8def68153c63e.jpg' dosyası '585.jpg' olarak değiştirildi.
# '65b2df56-1691_PNG.rf.ae1bc6b9b25ea4b79738e6a45ddf5995.jpg' dosyası '586.jpg' olarak değiştirildi.
# '67ac51bb-1602_jpg.rf.8c7a4219cf6dc6b9c7fefde52868491e.jpg' dosyası '587.jpg' olarak değiştirildi.
# '67d1e2c3-1.jpeg' dosyası '588.jpeg' olarak değiştirildi.
# '67f13abe-1726_PNG.rf.2777c20eef13bd411988ff6ffe9d5ef6.jpg' dosyası '589.jpg' olarak değiştirildi.
# '67fdeb95-1755_jpg.rf.193fb2d532426dc3f9441f3f37f7af44.jpg' dosyası '590.jpg' olarak değiştirildi.
# '68818419-43.jpeg' dosyası '591.jpeg' olarak değiştirildi.
# '68ed085e-117.jpeg' dosyası '592.jpeg' olarak değiştirildi.
# '69e08229-1643_PNG.rf.a1b53487e08dbd0722dbefaf04304423.jpg' dosyası '593.jpg' olarak değiştirildi.
# '6a220461-30.jpeg' dosyası '594.jpeg' olarak değiştirildi.
# '6abbf616-45.jpeg' dosyası '595.jpeg' olarak değiştirildi.
# '6ad8d69e-0101.jpg' dosyası '596.jpg' olarak değiştirildi.
# '6bfc0156-1732_PNG.rf.db83b2e6b7b80a6799b7d72c3d0edbb4.jpg' dosyası '597.jpg' olarak değiştirildi.
# '6c4426b2-92.jpeg' dosyası '598.jpeg' olarak değiştirildi.
# '6c5dae14-0096.jpg' dosyası '599.jpg' olarak değiştirildi.
# '6cf3dde7-119.jpeg' dosyası '600.jpeg' olarak değiştirildi.
# '6d0ebdf6-1688_PNG.rf.8eb4b86d39af14463008a809a436baa1.jpg' dosyası '601.jpg' olarak değiştirildi.
# '6dbb4573-1791_jpg.rf.09891e74bae412ac782c8a1e6c2ca4c0.jpg' dosyası '602.jpg' olarak değiştirildi.
# '6e025529-1_42.jpg' dosyası '603.jpg' olarak değiştirildi.
# '6eebf6df-1723_jpg.rf.f40fde3a704297994cf38903f8c8d865.jpg' dosyası '604.jpg' olarak değiştirildi.
# '6f133aa9-27.jpeg' dosyası '605.jpeg' olarak değiştirildi.
# '700714e1-1_31.jpg' dosyası '606.jpg' olarak değiştirildi.
# '70255337-0225.jpg' dosyası '607.jpg' olarak değiştirildi.
# '71279fb1-0089.jpg' dosyası '608.jpg' olarak değiştirildi.
# '719429c2-109.jpeg' dosyası '609.jpeg' olarak değiştirildi.
# '71f16ae8-1756_jpg.rf.54428ce468bcc7229771ae36ba8c69be.jpg' dosyası '610.jpg' olarak değiştirildi.
# '732e1f65-86.jpeg' dosyası '611.jpeg' olarak değiştirildi.
# '737a47c0-0064.jpg' dosyası '612.jpg' olarak değiştirildi.
# '74af603e-115.jpeg' dosyası '613.jpeg' olarak değiştirildi.
# '76995547-76.jpeg' dosyası '614.jpeg' olarak değiştirildi.
# '77503bf2-0236.jpg' dosyası '615.jpg' olarak değiştirildi.
# '777d68f1-0091.jpg' dosyası '616.jpg' olarak değiştirildi.
# '7802ab2a-1_46.jpg' dosyası '617.jpg' olarak değiştirildi.
# '782651d3-1615_jpg.rf.cff344e4990cfd17ad88510aebcf854c.jpg' dosyası '618.jpg' olarak değiştirildi.
# '7839c15e-0221.jpg' dosyası '619.jpg' olarak değiştirildi.
# '7890b6b7-0234.jpg' dosyası '620.jpg' olarak değiştirildi.
# '78f02b89-1677_jpg.rf.9e4eb3a6fe967ede7e97f250ba3f5bbc.jpg' dosyası '621.jpg' olarak değiştirildi.
# '791375df-1_14.jpg' dosyası '622.jpg' olarak değiştirildi.
# '79278cbe-79.jpeg' dosyası '623.jpeg' olarak değiştirildi.
# '794d7d9f-0085.jpg' dosyası '624.jpg' olarak değiştirildi.
# '7a0ab92b-77.jpeg' dosyası '625.jpeg' olarak değiştirildi.
# '7b81089b-104.jpeg' dosyası '626.jpeg' olarak değiştirildi.
# '7c10c980-1744_jpg.rf.647bdba2f100a85975c9f786348240a3.jpg' dosyası '627.jpg' olarak değiştirildi.
# '7c833491-97.jpeg' dosyası '628.jpeg' olarak değiştirildi.
# '7c93e453-1618_PNG.rf.10f7986858962a2856c8aa7a94a71931.jpg' dosyası '629.jpg' olarak değiştirildi.
# '7ca80f8f-0008.jpg' dosyası '630.jpg' olarak değiştirildi.
# '7ce843a8-95.jpeg' dosyası '631.jpeg' olarak değiştirildi.
# '7d011c4a-1603_PNG.rf.6d166768eb36c4b1316c825de79f41df.jpg' dosyası '632.jpg' olarak değiştirildi.
# '7ecc6207-1_11.jpg' dosyası '633.jpg' olarak değiştirildi.
# '7ee727b2-0044.jpg' dosyası '634.jpg' olarak değiştirildi.
# '80389cd3-1696_PNG.rf.b472fc8695d2ab88dd094063d9b24a56.jpg' dosyası '635.jpg' olarak değiştirildi.
# '803d03ae-1775_jpg.rf.43cdd8244e8caf22e38e5749c9a9d75e.jpg' dosyası '636.jpg' olarak değiştirildi.
# '805e7b0e-29.jpeg' dosyası '637.jpeg' olarak değiştirildi.
# '81928856-1781_jpg.rf.7566fa8793b388dfde462ec3bf2d17d8.jpg' dosyası '638.jpg' olarak değiştirildi.
# '81b2dc95-1713_PNG.rf.8090c7f14ff4b2a08c690f41f6997393.jpg' dosyası '639.jpg' olarak değiştirildi.
# '81e98155-0224.jpg' dosyası '640.jpg' olarak değiştirildi.
# '81ee5b03-1607_PNG.rf.d4019e916a08cac70af3e5764e98c8c4.jpg' dosyası '641.jpg' olarak değiştirildi.
# '8221dab8-1647_jpg.rf.82a8738ed5830f38a07a4280dc2c0243.jpg' dosyası '642.jpg' olarak değiştirildi.
# '8307a192-1792_jpg.rf.3f9ea897ca3b73a0f7f9533606cb3a2c.jpg' dosyası '643.jpg' olarak değiştirildi.
# '838742be-0090.jpg' dosyası '644.jpg' olarak değiştirildi.
# '83aa7d4c-63.jpeg' dosyası '645.jpeg' olarak değiştirildi.
# '84e4e25b-1764_jpg.rf.114f23651be64b7022449a110efad6e3.jpg' dosyası '646.jpg' olarak değiştirildi.
# '855608cf-0069.jpg' dosyası '647.jpg' olarak değiştirildi.
# '86198463-1661_PNG.rf.23a3dd11ce45b233cedc3ac5997e6353.jpg' dosyası '648.jpg' olarak değiştirildi.
# '8644a21b-0220.jpg' dosyası '649.jpg' olarak değiştirildi.
# '8680c82c-0226.jpg' dosyası '650.jpg' olarak değiştirildi.
# '87421135-0081.jpg' dosyası '651.jpg' olarak değiştirildi.
# '87abf076-1646_jpg.rf.82731b21b4771fdb3592e736be73b1cb.jpg' dosyası '652.jpg' olarak değiştirildi.
# '88d06ba0-0040.jpg' dosyası '653.jpg' olarak değiştirildi.
# '89408786-1670_PNG.rf.030aa3a65e8d64e3d96ac5df7497be40.jpg' dosyası '654.jpg' olarak değiştirildi.
# '89fd03ac-1746_PNG.rf.3489407de06c2a8fbcf9632c42b257ab.jpg' dosyası '655.jpg' olarak değiştirildi.
# '8a3d7f5d-0230.jpg' dosyası '656.jpg' olarak değiştirildi.
# '8a7097fe-1_23.jpg' dosyası '657.jpg' olarak değiştirildi.
# '8ac03289-36.jpeg' dosyası '658.jpeg' olarak değiştirildi.
# '8b050446-1702_PNG.rf.54f3d5e39a79b1a581827373d8b450a5.jpg' dosyası '659.jpg' olarak değiştirildi.
# '8ebeebe5-44.jpeg' dosyası '660.jpeg' olarak değiştirildi.
# '8ef74800-1669_PNG.rf.7e91984f73a9611d0d448e594d8d1d6b.jpg' dosyası '661.jpg' olarak değiştirildi.
# '8f8faa40-0088.jpg' dosyası '662.jpg' olarak değiştirildi.
# '90150186-111.jpeg' dosyası '663.jpeg' olarak değiştirildi.
# '903859c2-1686_PNG.rf.84d6f3a92daff2a89006077572b20254.jpg' dosyası '664.jpg' olarak değiştirildi.
# '9082763f-1_27.jpg' dosyası '665.jpg' olarak değiştirildi.
# '909495be-1761_jpg.rf.a11ab1efa0fbecfa5f4fee36de37200e.jpg' dosyası '666.jpg' olarak değiştirildi.
# '920e0485-1627_jpg.rf.12f3ea3462dcc7bcc2c9508c74efcff2.jpg' dosyası '667.jpg' olarak değiştirildi.
# '92673a9d-1799_jpg.rf.cecdfc4d5afe05133a94e055a88e88e3.jpg' dosyası '668.jpg' olarak değiştirildi.
# '93b34211-26.jpeg' dosyası '669.jpeg' olarak değiştirildi.
# '943070ce-0238.jpg' dosyası '670.jpg' olarak değiştirildi.
# '94589274-7.jpeg' dosyası '671.jpeg' olarak değiştirildi.
# '949f393a-1_7.jpg' dosyası '672.jpg' olarak değiştirildi.
# '94df85f7-1623_jpg.rf.bca18d31cb1b9bca228b0e1ca45c05f3.jpg' dosyası '673.jpg' olarak değiştirildi.
# '94f02707-1_29.jpg' dosyası '674.jpg' olarak değiştirildi.
# '9539b4a5-1690_PNG.rf.fc24b50b8be4ba35ef1bbf55a8ab33a0.jpg' dosyası '675.jpg' olarak değiştirildi.
# '95b6b888-1736_PNG.rf.e9111aef2b6e261ede550407bbcf7137.jpg' dosyası '676.jpg' olarak değiştirildi.
# '96407bd1-42.jpeg' dosyası '677.jpeg' olarak değiştirildi.
# '9710649e-1683_PNG.rf.2d59d3265d22c1d97e338e79862b7c47.jpg' dosyası '678.jpg' olarak değiştirildi.
# '9748d1ae-0083.jpg' dosyası '679.jpg' olarak değiştirildi.
# '97cd29b2-0072.jpg' dosyası '680.jpg' olarak değiştirildi.
# '97d8c3f2-51.jpeg' dosyası '681.jpeg' olarak değiştirildi.
# '97f3a32e-68.jpeg' dosyası '682.jpeg' olarak değiştirildi.
# '98167d6f-32.jpeg' dosyası '683.jpeg' olarak değiştirildi.
# '99053d60-1_2.jpg' dosyası '684.jpg' olarak değiştirildi.
# '99963d7f-0093.jpg' dosyası '685.jpg' olarak değiştirildi.
# '9a1dab73-67.jpeg' dosyası '686.jpeg' olarak değiştirildi.
# '9a43428b-100.jpeg' dosyası '687.jpeg' olarak değiştirildi.
# '9aaf32ea-1703_PNG.rf.18d30225b234fd56acdee9eb74cf1316.jpg' dosyası '688.jpg' olarak değiştirildi.
# '9ae67235-84.jpeg' dosyası '689.jpeg' olarak değiştirildi.
# '9bf9f126-1658_PNG.rf.04a4b616055e74857ea642a1e79dd1f7.jpg' dosyası '690.jpg' olarak değiştirildi.
# '9c13e582-1743_PNG.rf.824d8986d5a288b871ef2d9794fa243d.jpg' dosyası '691.jpg' olarak değiştirildi.
# '9c9ded32-1_25.jpg' dosyası '692.jpg' olarak değiştirildi.
# '9db7f854-1737_jpg.rf.c97afea9839adf066d66879dba1ba4b5.jpg' dosyası '693.jpg' olarak değiştirildi.
# '9f03aaf1-0217.jpg' dosyası '694.jpg' olarak değiştirildi.
# 'a01412df-1787_jpg.rf.cf706b3fccb03407de68d104809844d4.jpg' dosyası '695.jpg' olarak değiştirildi.
# 'a0f4772c-0084.jpg' dosyası '696.jpg' olarak değiştirildi.
# 'a12ddbe3-98.jpeg' dosyası '697.jpeg' olarak değiştirildi.
# 'a142abaf-75.jpeg' dosyası '698.jpeg' olarak değiştirildi.
# 'a29f462b-1654_jpg.rf.4113dd7d7a4f4140d5e878a586079707.jpg' dosyası '699.jpg' olarak değiştirildi.
# 'a2ba7fbd-83.jpeg' dosyası '700.jpeg' olarak değiştirildi.
# 'a356d54d-0050.jpg' dosyası '701.jpg' olarak değiştirildi.
# 'a3b6985c-0218.jpg' dosyası '702.jpg' olarak değiştirildi.
# 'a4437b94-0059.jpg' dosyası '703.jpg' olarak değiştirildi.
# 'a4a21ae0-72.jpeg' dosyası '704.jpeg' olarak değiştirildi.
# 'a5edd06c-1719_PNG.rf.a35dd12a163a3b22202401546bbabe64.jpg' dosyası '705.jpg' olarak değiştirildi.
# 'a60bdaf4-0054.jpg' dosyası '706.jpg' olarak değiştirildi.
# 'a70c2a64-1612_jpg.rf.db9803ce956db0c3a202d30ac15d868c.jpg' dosyası '707.jpg' olarak değiştirildi.
# 'a74c3e78-0231.jpg' dosyası '708.jpg' olarak değiştirildi.
# 'a7b60e87-1_20.jpg' dosyası '709.jpg' olarak değiştirildi.
# 'a96b80b9-1_41.jpg' dosyası '710.jpg' olarak değiştirildi.
# 'a9ac4738-1770_jpg.rf.74e197c75231d33c2eed4329f56aa591.jpg' dosyası '711.jpg' olarak değiştirildi.
# 'a9bbf681-1_13.jpg' dosyası '712.jpg' olarak değiştirildi.
# 'aa3bdf98-1_24.jpg' dosyası '713.jpg' olarak değiştirildi.
# 'aa76fbad-1_3.jpg' dosyası '714.jpg' olarak değiştirildi.
# 'aa96a935-1_15.jpg' dosyası '715.jpg' olarak değiştirildi.
# 'aab5d11c-1653_jpg.rf.8c8b1ea54bcaf07ad23a6fc49bf378a2.jpg' dosyası '716.jpg' olarak değiştirildi.
# 'aadccee2-85.jpeg' dosyası '717.jpeg' olarak değiştirildi.
# 'ab5f0a45-38.jpeg' dosyası '718.jpeg' olarak değiştirildi.
# 'abc004de-21.jpeg' dosyası '719.jpeg' olarak değiştirildi.
# 'abea5a1b-0024.jpg' dosyası '720.jpg' olarak değiştirildi.
# 'abf05682-66.jpeg' dosyası '721.jpeg' olarak değiştirildi.
# 'ac10d7c3-1767_jpg.rf.2c7f2ac953882c3d16d2bafeae8a8717.jpg' dosyası '722.jpg' olarak değiştirildi.
# 'ad43c3fb-1657_PNG.rf.81fa0c68dd47d716d2c00ff48054bfd2.jpg' dosyası '723.jpg' olarak değiştirildi.
# 'af266214-1673_jpg.rf.8a9fd1dfea1062b300f42077e25d4493.jpg' dosyası '724.jpg' olarak değiştirildi.
# 'af716351-1_33.jpg' dosyası '725.jpg' olarak değiştirildi.
# 'af892c4f-82.jpeg' dosyası '726.jpeg' olarak değiştirildi.
# 'afb84d8e-1733_PNG.rf.7514d7665fb47369cdb484e4e2f9e23a.jpg' dosyası '727.jpg' olarak değiştirildi.
# 'b145c1fc-0213.jpg' dosyası '728.jpg' olarak değiştirildi.
# 'b256906a-1_21.jpg' dosyası '729.jpg' olarak değiştirildi.
# 'b28c1191-1759_jpg.rf.c11a51a5e1717867e12bd7fe354d5171.jpg' dosyası '730.jpg' olarak değiştirildi.
# 'b2f0bbb8-1708_PNG.rf.c0a6aaa77116520cb3fbc45d03d2c1c3.jpg' dosyası '731.jpg' olarak değiştirildi.
# 'b32ad4bf-101.jpeg' dosyası '732.jpeg' olarak değiştirildi.
# 'b3b57887-1_34.jpg' dosyası '733.jpg' olarak değiştirildi.
# 'b45b35b5-0034.jpg' dosyası '734.jpg' olarak değiştirildi.
# 'b49121ca-1681_PNG.rf.3f20b7d1c96c7cbe0fb51dae645325f1.jpg' dosyası '735.jpg' olarak değiştirildi.
# 'b4f5849c-1662_PNG.rf.67682d2b339b7fee82dd3c28818886f8.jpg' dosyası '736.jpg' olarak değiştirildi.
# 'b533df79-0028.jpg' dosyası '737.jpg' olarak değiştirildi.
# 'b62fbffa-1_22.jpg' dosyası '738.jpg' olarak değiştirildi.
# 'b720d066-34.jpeg' dosyası '739.jpeg' olarak değiştirildi.
# 'b78e7299-1629_jpg.rf.466d8c46b45580f5b41679e285aa631e.jpg' dosyası '740.jpg' olarak değiştirildi.
# 'b7f9e362-1741_PNG.rf.fb85a79ffa9ad2116cc54de893655140.jpg' dosyası '741.jpg' olarak değiştirildi.
# 'b839b376-55.jpeg' dosyası '742.jpeg' olarak değiştirildi.
# 'b8d4140b-1620_PNG.rf.c8135c08d7fc7556635622edb312111d.jpg' dosyası '743.jpg' olarak değiştirildi.
# 'b8ef4543-0042.jpg' dosyası '744.jpg' olarak değiştirildi.
# 'b93f4047-54.jpeg' dosyası '745.jpeg' olarak değiştirildi.
# 'b96d0dc4-107.jpeg' dosyası '746.jpeg' olarak değiştirildi.
# 'b9d22e87-35.jpeg' dosyası '747.jpeg' olarak değiştirildi.
# 'ba595c96-81.jpeg' dosyası '748.jpeg' olarak değiştirildi.
# 'bab4441f-1644_PNG.rf.b37c19a29ff3839987ba9b07635ee7de.jpg' dosyası '749.jpg' olarak değiştirildi.
# 'bb21eb31-1728_PNG.rf.995f7204141083d315a40d46c90cb88a.jpg' dosyası '750.jpg' olarak değiştirildi.
# 'bb32bcaf-0063.jpg' dosyası '751.jpg' olarak değiştirildi.
# 'bda32f55-1676_jpg.rf.1c4ef760e03984b95fceccafb558149a.jpg' dosyası '752.jpg' olarak değiştirildi.
# 'bfeb10b0-2.jpeg' dosyası '753.jpeg' olarak değiştirildi.
# 'c1521c77-0073.jpg' dosyası '754.jpg' olarak değiştirildi.
# 'c221f5a4-1721_PNG.rf.c0d9ba50a0fa4b4184435e63515ac7d0.jpg' dosyası '755.jpg' olarak değiştirildi.
# 'c265d051-0029.jpg' dosyası '756.jpg' olarak değiştirildi.
# 'c3c6def7-1718_jpg.rf.61431c72a4e9ad50e29a7239a20eb35d.jpg' dosyası '757.jpg' olarak değiştirildi.
# 'c462f393-1762_jpg.rf.f27eaa7e6fceed5da298124913a70a7e.jpg' dosyası '758.jpg' olarak değiştirildi.
# 'c47f8da8-0079.jpg' dosyası '759.jpg' olarak değiştirildi.
# 'c546bafc-1706_PNG.rf.36831c2b410c906b8d47594dddd6f5af.jpg' dosyası '760.jpg' olarak değiştirildi.
# 'c5fe9820-1_44.jpg' dosyası '761.jpg' olarak değiştirildi.
# 'c6aaa8a2-1694_jpg.rf.ed6dc5e01fd7c98aa999a58916748a09.jpg' dosyası '762.jpg' olarak değiştirildi.
# 'c721a9ed-3.jpeg' dosyası '763.jpeg' olarak değiştirildi.
# 'c7a74425-87.jpeg' dosyası '764.jpeg' olarak değiştirildi.
# 'c7f8628a-1720_jpg.rf.16d408948cf6119d5a4756c8bccd41b7.jpg' dosyası '765.jpg' olarak değiştirildi.
# 'c8211eb9-41.jpeg' dosyası '766.jpeg' olarak değiştirildi.
# 'c9188ba4-20.jpeg' dosyası '767.jpeg' olarak değiştirildi.
# 'c9540f1b-0222.jpg' dosyası '768.jpg' olarak değiştirildi.
# 'cafc08b6-1793_jpg.rf.d3f40cdf81e882b2d5f728a2d8a1116e.jpg' dosyası '769.jpg' olarak değiştirildi.
# 'cc20ecce-105.jpeg' dosyası '770.jpeg' olarak değiştirildi.
# 'cd44812a-57.jpeg' dosyası '771.jpeg' olarak değiştirildi.
# 'cd4a4aeb-1675_jpg.rf.e01028657d3096eec2b2de21149b3d66.jpg' dosyası '772.jpg' olarak değiştirildi.
# 'cf444842-1754_jpg.rf.e81151bda74098dbd185717b9895327c.jpg' dosyası '773.jpg' olarak değiştirildi.
# 'cfb91fb1-0033.jpg' dosyası '774.jpg' olarak değiştirildi.
# 'd03bd268-60.jpeg' dosyası '775.jpeg' olarak değiştirildi.
# 'd05f3296-1659_jpg.rf.8d7bb2e6cfdcc0e159f0b474d736cd23.jpg' dosyası '776.jpg' olarak değiştirildi.
# 'd0742092-1622_PNG.rf.e36fec1f97a252f70d588f68afe30348.jpg' dosyası '777.jpg' olarak değiştirildi.
# 'd0995fae-80.jpeg' dosyası '778.jpeg' olarak değiştirildi.
# 'd21e6439-1_50.jpg' dosyası '779.jpg' olarak değiştirildi.
# 'd2ee9016-1772_jpg.rf.4bd8bed20b8bd1ad01c92fb1a4754188.jpg' dosyası '780.jpg' olarak değiştirildi.
# 'd2fc6a50-1785_jpg.rf.2d90f49b241b0b35743780d3005757f3.jpg' dosyası '781.jpg' olarak değiştirildi.
# 'd3ef9536-90.jpeg' dosyası '782.jpeg' olarak değiştirildi.
# 'd3f28551-0006.jpg' dosyası '783.jpg' olarak değiştirildi.
# 'd8f834e7-0046.jpg' dosyası '784.jpg' olarak değiştirildi.
# 'd9567c05-1777_jpg.rf.c66c9ebc785b4da31e26ea4c4e4a62a1.jpg' dosyası '785.jpg' olarak değiştirildi.
# 'dab1a68a-58.jpeg' dosyası '786.jpeg' olarak değiştirildi.
# 'dc678330-1716_PNG.rf.cfbf2315987a71caf669148f9a7c49c8.jpg' dosyası '787.jpg' olarak değiştirildi.
# 'dc95075d-0227.jpg' dosyası '788.jpg' olarak değiştirildi.
# 'ddc29556-14.jpeg' dosyası '789.jpeg' olarak değiştirildi.
# 'dddb4611-1619_PNG.rf.68121fa178da57a3fd9cda380e621e7f.jpg' dosyası '790.jpg' olarak değiştirildi.
# 'de87817d-102.jpeg' dosyası '791.jpeg' olarak değiştirildi.
# 'df0754a1-1_38.jpg' dosyası '792.jpg' olarak değiştirildi.
# 'df375901-1798_jpg.rf.9a493318f212c6c98f4a3f05a13eea76.jpg' dosyası '793.jpg' olarak değiştirildi.
# 'e081c843-1680_PNG.rf.595af6bbc3bb467115095dad4bfbd882.jpg' dosyası '794.jpg' olarak değiştirildi.
# 'e0f36324-0092.jpg' dosyası '795.jpg' olarak değiştirildi.
# 'e17759a4-1707_PNG.rf.5b7aedaf6c782601d5c84f9f9c424f0c.jpg' dosyası '796.jpg' olarak değiştirildi.
# 'e1d24eab-1_30.jpg' dosyası '797.jpg' olarak değiştirildi.
# 'e38e7016-46.jpeg' dosyası '798.jpeg' olarak değiştirildi.
# 'e4a2b888-8.jpeg' dosyası '799.jpeg' olarak değiştirildi.
# 'e5b0c2ed-62.jpeg' dosyası '800.jpeg' olarak değiştirildi.
# 'e6982b76-1666_jpg.rf.e68005fe22293d8ed65be81b5b55284d.jpg' dosyası '801.jpg' olarak değiştirildi.
# 'e70d1094-0087.jpg' dosyası '802.jpg' olarak değiştirildi.
# 'e7127bc8-1_32.jpg' dosyası '803.jpg' olarak değiştirildi.
# 'e73e7e75-1639_jpg.rf.b4eac3ce5250218c0d71ec912d61d963.jpg' dosyası '804.jpg' olarak değiştirildi.
# 'e92b2b29-24.jpeg' dosyası '805.jpeg' olarak değiştirildi.
# 'e94cb7b6-1617_jpg.rf.ffd5a7b7438d823a2343a12dada12089.jpg' dosyası '806.jpg' olarak değiştirildi.
# 'e9d316ee-1_26.jpg' dosyası '807.jpg' olarak değiştirildi.
# 'e9e29f7a-1757_jpg.rf.0350296277c5e74975cb293635e7b5dc.jpg' dosyası '808.jpg' olarak değiştirildi.
# 'eb00d7b8-1727_jpg.rf.ad46560655772135795a2e4222114f09.jpg' dosyası '809.jpg' olarak değiştirildi.
# 'ebcbf784-96.jpeg' dosyası '810.jpeg' olarak değiştirildi.
# 'ec797a9c-6.jpeg' dosyası '811.jpeg' olarak değiştirildi.
# 'eca6a23e-0070.jpg' dosyası '812.jpg' olarak değiştirildi.
# 'ed90f69c-0080.jpg' dosyası '813.jpg' olarak değiştirildi.
# 'edfda87b-0009.jpg' dosyası '814.jpg' olarak değiştirildi.
# 'eec1b9d0-1752_jpg.rf.da77149bb6e9ba4f77b32966f7ebcad9.jpg' dosyası '815.jpg' olarak değiştirildi.
# 'ef74cb90-1722_PNG.rf.ec0f20690e2589ea7c280eb51e5f1d26.jpg' dosyası '816.jpg' olarak değiştirildi.
# 'f351df95-69.jpeg' dosyası '817.jpeg' olarak değiştirildi.
# 'f4911c6a-1751_jpg.rf.d9e04a1de46a4a8b41783115c3cc9287.jpg' dosyası '818.jpg' olarak değiştirildi.
# 'f4cae116-1667_PNG.rf.ecd602065f602d50f1ec516562c2965b.jpg' dosyası '819.jpg' olarak değiştirildi.
# 'f4ec2535-1614_PNG.rf.75684e57f15200631b982e4b8c2c3c0a.jpg' dosyası '820.jpg' olarak değiştirildi.
# 'f5640b71-1609_jpg.rf.0948d1a01e1a2f3b2bee3b24df4eb1c4.jpg' dosyası '821.jpg' olarak değiştirildi.
# 'f5be5af7-0082.jpg' dosyası '822.jpg' olarak değiştirildi.
# 'f6727d0c-1739_jpg.rf.bcde1e5fe8247bf993bb8884a93255ae.jpg' dosyası '823.jpg' olarak değiştirildi.
# 'f6f65f7a-1_43.jpg' dosyası '824.jpg' olarak değiştirildi.
# 'f70d040e-1611_PNG.rf.60c1f6ab00a0c01c086bb26321984b09.jpg' dosyası '825.jpg' olarak değiştirildi.
# 'f72a7067-1715_jpg.rf.e4bac7da8a02b72bc21c762435c65426.jpg' dosyası '826.jpg' olarak değiştirildi.
# 'f793f894-0005.jpg' dosyası '827.jpg' olarak değiştirildi.
# 'f9207dd2-0037.jpg' dosyası '828.jpg' olarak değiştirildi.
# 'f95acc38-0052.jpg' dosyası '829.jpg' olarak değiştirildi.
# 'fa654e5c-0086.jpg' dosyası '830.jpg' olarak değiştirildi.
# 'fab5c405-112.jpeg' dosyası '831.jpeg' olarak değiştirildi.
# 'fafdd005-1656_PNG.rf.121cc7aacdda6227ead175776ac86d8b.jpg' dosyası '832.jpg' olarak değiştirildi.
# 'fd1ad646-1_1.jpg' dosyası '833.jpg' olarak değiştirildi.
# 'fd948ebb-19.jpeg' dosyası '834.jpeg' olarak değiştirildi.
# Dosya isimlendirme işlemi tamamlandı.

# %%
import os

# Dosyaların bulunduğu klasörün yolu
folder_path = 'C:/Users/edana/Desktop/dataset_new/UAV/resized_images'

# Dosya isimlerini değiştirmek için başlangıç numarası
start_number = 835
end_number = 1600

# Klasördeki tüm dosyaları al
files = os.listdir(folder_path)

# Sadece dosya olanları al (klasörleri hariç tut)
files = [f for f in files if os.path.isfile(os.path.join(folder_path, f))]

# Dosyaları sıralı olarak yeniden isimlendirme işlemi
for i, file_name in enumerate(files):
    if i < end_number:
        # Dosyanın uzantısını al
        file_extension = os.path.splitext(file_name)[1]
        # Yeni dosya adını oluştur
        new_name = f"{start_number + i}{file_extension}"
        # Eski ve yeni dosya yollarını oluştur
        old_file_path = os.path.join(folder_path, file_name)
        new_file_path = os.path.join(folder_path, new_name)
        # Dosya ismini değiştir
        os.rename(old_file_path, new_file_path)
        print(f"'{file_name}' dosyası '{new_name}' olarak değiştirildi.")
    else:
        break

print("Dosya isimlendirme işlemi tamamlandı.")
# Out:
# '01f09349-47.jpeg' dosyası '835.jpeg' olarak değiştirildi.
# '01f14498-1_37.jpg' dosyası '836.jpg' olarak değiştirildi.
# '03235c10-1_10.jpg' dosyası '837.jpg' olarak değiştirildi.
# '032b8fc0-0095.jpg' dosyası '838.jpg' olarak değiştirildi.
# '0439f4e3-0237.jpg' dosyası '839.jpg' olarak değiştirildi.
# '04e13cc4-1704_jpg.rf.75c3676a3b249fe28258cf7edc78685e.jpg' dosyası '840.jpg' olarak değiştirildi.
# '0573af8e-1652_PNG.rf.41631d03f2ed222667877a536b01ced9.jpg' dosyası '841.jpg' olarak değiştirildi.
# '059a0726-33.jpeg' dosyası '842.jpeg' olarak değiştirildi.
# '05ea4ee7-1_12.jpg' dosyası '843.jpg' olarak değiştirildi.
# '06709e94-1_5.jpg' dosyası '844.jpg' olarak değiştirildi.
# '06ee1fa3-56.jpeg' dosyası '845.jpeg' olarak değiştirildi.
# '0766dc07-91.jpeg' dosyası '846.jpeg' olarak değiştirildi.
# '078f7569-1738_PNG.rf.760ee524c0edd762b2252027a0e1f1cb.jpg' dosyası '847.jpg' olarak değiştirildi.
# '089c260f-0001.jpg' dosyası '848.jpg' olarak değiştirildi.
# '08d06b6e-1784_jpg.rf.3d8a198eabaf697d14df17098004f016.jpg' dosyası '849.jpg' olarak değiştirildi.
# '09e7187b-1626_jpg.rf.da41bff1520ebed0a36aa35c64acd9a0.jpg' dosyası '850.jpg' olarak değiştirildi.
# '0a95ec6e-1758_jpg.rf.edec6d2de3c4f28886ab7dfc9fa45d0b.jpg' dosyası '851.jpg' olarak değiştirildi.
# '0aa31dc9-1_6.jpg' dosyası '852.jpg' olarak değiştirildi.
# '0da650df-1_49.jpg' dosyası '853.jpg' olarak değiştirildi.
# '0e026ff8-0048.jpg' dosyası '854.jpg' olarak değiştirildi.
# '0f22034a-1745_jpg.rf.bdbb6df36d8da1d8223cd40b0a6d8eb0.jpg' dosyası '855.jpg' olarak değiştirildi.
# '0f5cf83b-0228.jpg' dosyası '856.jpg' olarak değiştirildi.
# '11719f3f-0097.jpg' dosyası '857.jpg' olarak değiştirildi.
# '117d2488-1640_jpg.rf.a262659a6df5f26c64b5c8a795640ac6.jpg' dosyası '858.jpg' olarak değiştirildi.
# '11daa65d-1763_jpg.rf.21566c2cc30e771fcccda139d075855b.jpg' dosyası '859.jpg' olarak değiştirildi.
# '11e9053b-1679_jpg.rf.431b9419b1099be607c6a84e4f622dde.jpg' dosyası '860.jpg' olarak değiştirildi.
# '121ae19f-1749_jpg.rf.ba8439d61d4699b0212205bf7c333822.jpg' dosyası '861.jpg' olarak değiştirildi.
# '136d9ef5-1625_PNG.rf.5a94fc4e6ff595ae9dcbc4c1d202631c.jpg' dosyası '862.jpg' olarak değiştirildi.
# '138e133d-48.jpeg' dosyası '863.jpeg' olarak değiştirildi.
# '141a1661-74.jpeg' dosyası '864.jpeg' olarak değiştirildi.
# '144403a8-1789_jpg.rf.b3176e95278090aba73805531c03b4c0.jpg' dosyası '865.jpg' olarak değiştirildi.
# '145bbe5f-1665_PNG.rf.605d3378a7afe49e55947086a4260a0a.jpg' dosyası '866.jpg' olarak değiştirildi.
# '149117c6-0223.jpg' dosyası '867.jpg' olarak değiştirildi.
# '14b4f270-0068.jpg' dosyası '868.jpg' olarak değiştirildi.
# '14cceeaf-1_9.jpg' dosyası '869.jpg' olarak değiştirildi.
# '1502730c-1768_jpg.rf.a8ee9182c0748cd7fa90986567524b3a.jpg' dosyası '870.jpg' olarak değiştirildi.
# '172f735b-1628_PNG.rf.eda1e3e31a2bf5e31a1a72b9257b55e0.jpg' dosyası '871.jpg' olarak değiştirildi.
# '175f8f8e-23.jpeg' dosyası '872.jpeg' olarak değiştirildi.
# '179d607f-1687_PNG.rf.0b3fdfd3efbf1187d39b933349326393.jpg' dosyası '873.jpg' olarak değiştirildi.
# '17a73a88-114.jpeg' dosyası '874.jpeg' olarak değiştirildi.
# '191ff427-1729_PNG.rf.882450f0e8cca8d9125b309e128e1f44.jpg' dosyası '875.jpg' olarak değiştirildi.
# '1b3b6c83-1_18.jpg' dosyası '876.jpg' olarak değiştirildi.
# '1b6cf79d-1698_jpg.rf.8cfef565573232ca15d37050fb536ef6.jpg' dosyası '877.jpg' olarak değiştirildi.
# '1c93eda3-1773_jpg.rf.33b0b82a7101d1c10e6ead694a18b9ff.jpg' dosyası '878.jpg' olarak değiştirildi.
# '1e15a4dd-0058.jpg' dosyası '879.jpg' olarak değiştirildi.
# '1e420c26-1769_jpg.rf.732e05e08d3754c673f9e86a140174d5.jpg' dosyası '880.jpg' olarak değiştirildi.
# '1e69dc4b-1638_PNG.rf.afcd87ee2974bb029d0105db7e2fdd69.jpg' dosyası '881.jpg' olarak değiştirildi.
# '1eb9e1ed-1616_PNG.rf.5a48524b1275508dfb7b452f67fe7132.jpg' dosyası '882.jpg' olarak değiştirildi.
# '1f863c4f-0030.jpg' dosyası '883.jpg' olarak değiştirildi.
# '20af207e-1678_jpg.rf.a3a5aaafe0ed424e30c7a5e580b4fc23.jpg' dosyası '884.jpg' olarak değiştirildi.
# '21b889cc-0056.jpg' dosyası '885.jpg' olarak değiştirildi.
# '21fb86ee-1783_jpg.rf.ba3ad9d74288768b73176400feeb42ba.jpg' dosyası '886.jpg' olarak değiştirildi.
# '2297e830-1692_jpg.rf.ee35dc8c4a5c2460e22cc8a61c8abc5d.jpg' dosyası '887.jpg' olarak değiştirildi.
# '2332444a-1747_jpg.rf.8a7f664bfbae7aa0f8b4a54eb3cdfac5.jpg' dosyası '888.jpg' olarak değiştirildi.
# '23d08d00-1695_PNG.rf.e827534c59bca1fff23b34ced296a5d6.jpg' dosyası '889.jpg' olarak değiştirildi.
# '242c4d00-40.jpeg' dosyası '890.jpeg' olarak değiştirildi.
# '252ca85e-1610_PNG.rf.779bb6d7894aaf49143cd161ce92482d.jpg' dosyası '891.jpg' olarak değiştirildi.
# '256498ca-1712_jpg.rf.5630366560cba451a391a2559bfb611c.jpg' dosyası '892.jpg' olarak değiştirildi.
# '26e704ac-1710_PNG.rf.b31e1ab05dec9c94ae0d02be58918c78.jpg' dosyası '893.jpg' olarak değiştirildi.
# '272a5f8b-0071.jpg' dosyası '894.jpg' olarak değiştirildi.
# '281bf2d9-1631_PNG.rf.3593414c6d9041a99bb90a98fd7a226d.jpg' dosyası '895.jpg' olarak değiştirildi.
# '29047177-1730_jpg.rf.de41605f63fb477f2d3132791c4f620a.jpg' dosyası '896.jpg' olarak değiştirildi.
# '290df7a9-1664_jpg.rf.efbe4de923eabd446bc1fb4009aa53b7.jpg' dosyası '897.jpg' olarak değiştirildi.
# '290f4225-1682_jpg.rf.8bbda5f3f2b76f2428c8209a4d4c1812.jpg' dosyası '898.jpg' olarak değiştirildi.
# '291e6e0f-1782_jpg.rf.73b92dfad04fd7fd0d6df003eeb95e3a.jpg' dosyası '899.jpg' olarak değiştirildi.
# '2b85dc59-1734_jpg.rf.14f01407f6485735401f88c2903906f9.jpg' dosyası '900.jpg' olarak değiştirildi.
# '2bc989a1-0215.jpg' dosyası '901.jpg' olarak değiştirildi.
# '2bcc1992-1760_jpg.rf.f01a0e02fe82f774d799b6c0cdf93751.jpg' dosyası '902.jpg' olarak değiştirildi.
# '2bda6acc-0025.jpg' dosyası '903.jpg' olarak değiştirildi.
# '2c790ddf-1_47.jpg' dosyası '904.jpg' olarak değiştirildi.
# '2c9f0310-88.jpeg' dosyası '905.jpeg' olarak değiştirildi.
# '2cf05c47-1_35.jpg' dosyası '906.jpg' olarak değiştirildi.
# '2d03980b-1724_PNG.rf.268edb49e3dc99988edb1285034a34f4.jpg' dosyası '907.jpg' olarak değiştirildi.
# '2d050469-0061.jpg' dosyası '908.jpg' olarak değiştirildi.
# '2de11f3d-1765_jpg.rf.84799cca6abb8049bb2f3d13bcbc5529.jpg' dosyası '909.jpg' olarak değiştirildi.
# '2e5ada57-1776_jpg.rf.abfe7c5d91dcc5c821a3e41ab884caea.jpg' dosyası '910.jpg' olarak değiştirildi.
# '2f47dc4d-1701_PNG.rf.db8e3d7c7ed938e6772e9272454cc895.jpg' dosyası '911.jpg' olarak değiştirildi.
# '2f498b32-1800_jpg.rf.4e8ff95ae1039719d9708a2b09fea3d3.jpg' dosyası '912.jpg' olarak değiştirildi.
# '2f774247-0232.jpg' dosyası '913.jpg' olarak değiştirildi.
# '2fb271e3-110.jpeg' dosyası '914.jpeg' olarak değiştirildi.
# '2fb9c374-10.jpeg' dosyası '915.jpeg' olarak değiştirildi.
# '30969694-1700_jpg.rf.97ad2f2f3f0f4a12c1744a81688e4b35.jpg' dosyası '916.jpg' olarak değiştirildi.
# '30d86b36-1_16.jpg' dosyası '917.jpg' olarak değiştirildi.
# '318223a8-59.jpeg' dosyası '918.jpeg' olarak değiştirildi.
# '32d8a231-1709_PNG.rf.b8c97dbf24b35eb9753beca1eb85bbbf.jpg' dosyası '919.jpg' olarak değiştirildi.
# '32fbd758-1693_PNG.rf.dc50a9c21776f1f640def875acc348d4.jpg' dosyası '920.jpg' olarak değiştirildi.
# '33953287-31.jpeg' dosyası '921.jpeg' olarak değiştirildi.
# '33d405de-89.jpeg' dosyası '922.jpeg' olarak değiştirildi.
# '341ffde7-1794_jpg.rf.733583058330201835117194be53c526.jpg' dosyası '923.jpg' olarak değiştirildi.
# '34a8e88f-49.jpeg' dosyası '924.jpeg' olarak değiştirildi.
# '35d1a03a-0032.jpg' dosyası '925.jpg' olarak değiştirildi.
# '366fedf9-1_8.jpg' dosyası '926.jpg' olarak değiştirildi.
# '37326e7c-0004.jpg' dosyası '927.jpg' olarak değiştirildi.
# '38edbc1f-1_17.jpg' dosyası '928.jpg' olarak değiştirildi.
# '3914bf0d-1_48.jpg' dosyası '929.jpg' olarak değiştirildi.
# '39a2ff1a-1689_jpg.rf.1870d81654b2898fc10cdd88fba1103b.jpg' dosyası '930.jpg' olarak değiştirildi.
# '39afc5bd-1699_PNG.rf.f00262370ada3df7813f8abf9dbaaea6.jpg' dosyası '931.jpg' olarak değiştirildi.
# '3a97176f-0007.jpg' dosyası '932.jpg' olarak değiştirildi.
# '3abde690-1705_PNG.rf.5daecef458f44b8f3f653315c06cef2d.jpg' dosyası '933.jpg' olarak değiştirildi.
# '3ac3f3cd-0074.jpg' dosyası '934.jpg' olarak değiştirildi.
# '3b0a78c0-0026.jpg' dosyası '935.jpg' olarak değiştirildi.
# '3b6de15d-1_4.jpg' dosyası '936.jpg' olarak değiştirildi.
# '3bd136b9-93.jpeg' dosyası '937.jpeg' olarak değiştirildi.
# '3c819c48-0094.jpg' dosyası '938.jpg' olarak değiştirildi.
# '3cbcfbfe-1_39.jpg' dosyası '939.jpg' olarak değiştirildi.
# '3d0b6bf7-1608_PNG.rf.8f8e8bc34dad875ac7510e2d08526799.jpg' dosyası '940.jpg' olarak değiştirildi.
# '3d4ba054-25.jpeg' dosyası '941.jpeg' olarak değiştirildi.
# '3e000fff-0216.jpg' dosyası '942.jpg' olarak değiştirildi.
# '3fe5cd20-1_28.jpg' dosyası '943.jpg' olarak değiştirildi.
# '4082834b-1797_jpg.rf.ba7cb0c088bbb76cde14f84d753a4198.jpg' dosyası '944.jpg' olarak değiştirildi.
# '40b06903-4.jpeg' dosyası '945.jpeg' olarak değiştirildi.
# '41758738-5.jpeg' dosyası '946.jpeg' olarak değiştirildi.
# '41ff7b0a-11.jpeg' dosyası '947.jpeg' olarak değiştirildi.
# '4270aeb2-1779_jpg.rf.ac0d8d4aea4ca7d703fa97feec895c1c.jpg' dosyası '948.jpg' olarak değiştirildi.
# '43f7d0d0-1748_jpg.rf.848c4824398270597a1996ea57155e8d.jpg' dosyası '949.jpg' olarak değiştirildi.
# '43fd8d51-103.jpeg' dosyası '950.jpeg' olarak değiştirildi.
# '446022df-1714_PNG.rf.e1a11f9a67e571c2b6e0221e0acbb29e.jpg' dosyası '951.jpg' olarak değiştirildi.
# '44a27934-1711_PNG.rf.994ceebb4d4de24b1c737b63782ac5f3.jpg' dosyası '952.jpg' olarak değiştirildi.
# '450fcc6d-1788_jpg.rf.aa4b353a44b48103a347de07db99006b.jpg' dosyası '953.jpg' olarak değiştirildi.
# '4741334d-1740_PNG.rf.f8c4d16b445e2de5edaddbcfaf739860.jpg' dosyası '954.jpg' olarak değiştirildi.
# '48c11af5-50.jpeg' dosyası '955.jpeg' olarak değiştirildi.
# '4942c5da-9.jpeg' dosyası '956.jpeg' olarak değiştirildi.
# '4a3158dc-1731_jpg.rf.bd7aab9f4ddd8d04294b70c6c5c61894.jpg' dosyası '957.jpg' olarak değiştirildi.
# '4b698730-1766_jpg.rf.213a245a2d9d0a4dcc100571ef1528a7.jpg' dosyası '958.jpg' olarak değiştirildi.
# '4bf61371-1684_jpg.rf.5ff2f366337e04e8be46a047332a5307.jpg' dosyası '959.jpg' olarak değiştirildi.
# '4c1e9eb6-1650_jpg.rf.6e138f8c66d2d62d2f84f50e8e0958a9.jpg' dosyası '960.jpg' olarak değiştirildi.
# '4c2a2626-108.jpeg' dosyası '961.jpeg' olarak değiştirildi.
# '4d7dbbd0-0214.jpg' dosyası '962.jpg' olarak değiştirildi.
# '4e9a4cc3-0065.jpg' dosyası '963.jpg' olarak değiştirildi.
# '4f126336-116.jpeg' dosyası '964.jpeg' olarak değiştirildi.
# '4fc9dc9e-1685_PNG.rf.6fe6627ad4eb31b35b45b3ed6416e58d.jpg' dosyası '965.jpg' olarak değiştirildi.
# '4fded54d-71.jpeg' dosyası '966.jpeg' olarak değiştirildi.
# '4ffc68a2-28.jpeg' dosyası '967.jpeg' olarak değiştirildi.
# '50fcea93-0039.jpg' dosyası '968.jpg' olarak değiştirildi.
# '519374a5-1796_jpg.rf.29e87505fe19d9ca298c07f128b9020d.jpg' dosyası '969.jpg' olarak değiştirildi.
# '5296708c-1674_jpg.rf.201552149988fc445579febd17b93f4a.jpg' dosyası '970.jpg' olarak değiştirildi.
# '5398dd4f-1621_PNG.rf.7e367626dfb3ea2ee8661ecb2e31be00.jpg' dosyası '971.jpg' olarak değiştirildi.
# '53bc80a6-1663_PNG.rf.806493996f980213411ca39950299d01.jpg' dosyası '972.jpg' olarak değiştirildi.
# '54e18b8b-0049.jpg' dosyası '973.jpg' olarak değiştirildi.
# '5535c582-0035.jpg' dosyası '974.jpg' olarak değiştirildi.
# '55c2f987-1750_jpg.rf.10aa88c6b5fb8e3c4c05be923da87537.jpg' dosyası '975.jpg' olarak değiştirildi.
# '55e0495e-1671_jpg.rf.2b05de921321bea3f3982158042fda79.jpg' dosyası '976.jpg' olarak değiştirildi.
# '56538f0e-1672_PNG.rf.4619877de1c7477fdacc0d85b2015627.jpg' dosyası '977.jpg' olarak değiştirildi.
# '5726a329-1_40.jpg' dosyası '978.jpg' olarak değiştirildi.
# '57c9d404-1795_jpg.rf.e149398595abe4ab13782c4caa4e9102.jpg' dosyası '979.jpg' olarak değiştirildi.
# '582b15c9-1771_jpg.rf.1118fce5351a6cdc903bbd0e1c171d85.jpg' dosyası '980.jpg' olarak değiştirildi.
# '5835b201-0229.jpg' dosyası '981.jpg' olarak değiştirildi.
# '58d92291-1_19.jpg' dosyası '982.jpg' olarak değiştirildi.
# '59603489-1632_PNG.rf.d73ba021479cfecd5560ee3d259f4fb4.jpg' dosyası '983.jpg' olarak değiştirildi.
# '596367e7-106.jpeg' dosyası '984.jpeg' olarak değiştirildi.
# '59d39757-1735_PNG.rf.82b871de5a1d781af5f3baab3cf03687.jpg' dosyası '985.jpg' olarak değiştirildi.
# '5b5d768c-73.jpeg' dosyası '986.jpeg' olarak değiştirildi.
# '5baa4e15-1778_jpg.rf.d1ad8c0f211636c63f4e19f52941fb98.jpg' dosyası '987.jpg' olarak değiştirildi.
# '5cad6e06-1725_PNG.rf.74473d308ec6f51028fe7a4c298e17fe.jpg' dosyası '988.jpg' olarak değiştirildi.
# '5cbb5ad5-39.jpeg' dosyası '989.jpeg' olarak değiştirildi.
# '5ce8ce0c-0075.jpg' dosyası '990.jpg' olarak değiştirildi.
# '5cf1b861-1_45.jpg' dosyası '991.jpg' olarak değiştirildi.
# '5dc36d3e-0219.jpg' dosyası '992.jpg' olarak değiştirildi.
# '5df5fb68-1697_PNG.rf.6e3a51c33982dbc6964dfb5ec86de664.jpg' dosyası '993.jpg' olarak değiştirildi.
# '5e404778-0003.jpg' dosyası '994.jpg' olarak değiştirildi.
# '5e74edcd-1668_PNG.rf.605b736cdf039421ecc684c38f72b733.jpg' dosyası '995.jpg' olarak değiştirildi.
# '5ed05a2f-1613_PNG.rf.396debae38885eca5b00f091832ab18f.jpg' dosyası '996.jpg' olarak değiştirildi.
# '5f7aff2c-1786_jpg.rf.60f1132a002824b313c723ed0f972056.jpg' dosyası '997.jpg' olarak değiştirildi.
# '61311d29-70.jpeg' dosyası '998.jpeg' olarak değiştirildi.
# '62b4fde4-1_36.jpg' dosyası '999.jpg' olarak değiştirildi.
# '6462d88b-118.jpeg' dosyası '1000.jpeg' olarak değiştirildi.
# '648cd228-1753_jpg.rf.357a4563f930d6611d0f49b5b6656fc7.jpg' dosyası '1001.jpg' olarak değiştirildi.
# '65a69694-1655_PNG.rf.e0cb12b407fe78eedbc8def68153c63e.jpg' dosyası '1002.jpg' olarak değiştirildi.
# '65b2df56-1691_PNG.rf.ae1bc6b9b25ea4b79738e6a45ddf5995.jpg' dosyası '1003.jpg' olarak değiştirildi.
# '67ac51bb-1602_jpg.rf.8c7a4219cf6dc6b9c7fefde52868491e.jpg' dosyası '1004.jpg' olarak değiştirildi.
# '67d1e2c3-1.jpeg' dosyası '1005.jpeg' olarak değiştirildi.
# '67f13abe-1726_PNG.rf.2777c20eef13bd411988ff6ffe9d5ef6.jpg' dosyası '1006.jpg' olarak değiştirildi.
# '67fdeb95-1755_jpg.rf.193fb2d532426dc3f9441f3f37f7af44.jpg' dosyası '1007.jpg' olarak değiştirildi.
# '68818419-43.jpeg' dosyası '1008.jpeg' olarak değiştirildi.
# '68ed085e-117.jpeg' dosyası '1009.jpeg' olarak değiştirildi.
# '69e08229-1643_PNG.rf.a1b53487e08dbd0722dbefaf04304423.jpg' dosyası '1010.jpg' olarak değiştirildi.
# '6a220461-30.jpeg' dosyası '1011.jpeg' olarak değiştirildi.
# '6abbf616-45.jpeg' dosyası '1012.jpeg' olarak değiştirildi.
# '6ad8d69e-0101.jpg' dosyası '1013.jpg' olarak değiştirildi.
# '6bfc0156-1732_PNG.rf.db83b2e6b7b80a6799b7d72c3d0edbb4.jpg' dosyası '1014.jpg' olarak değiştirildi.
# '6c4426b2-92.jpeg' dosyası '1015.jpeg' olarak değiştirildi.
# '6c5dae14-0096.jpg' dosyası '1016.jpg' olarak değiştirildi.
# '6cf3dde7-119.jpeg' dosyası '1017.jpeg' olarak değiştirildi.
# '6d0ebdf6-1688_PNG.rf.8eb4b86d39af14463008a809a436baa1.jpg' dosyası '1018.jpg' olarak değiştirildi.
# '6dbb4573-1791_jpg.rf.09891e74bae412ac782c8a1e6c2ca4c0.jpg' dosyası '1019.jpg' olarak değiştirildi.
# '6e025529-1_42.jpg' dosyası '1020.jpg' olarak değiştirildi.
# '6eebf6df-1723_jpg.rf.f40fde3a704297994cf38903f8c8d865.jpg' dosyası '1021.jpg' olarak değiştirildi.
# '6f133aa9-27.jpeg' dosyası '1022.jpeg' olarak değiştirildi.
# '700714e1-1_31.jpg' dosyası '1023.jpg' olarak değiştirildi.
# '70255337-0225.jpg' dosyası '1024.jpg' olarak değiştirildi.
# '71279fb1-0089.jpg' dosyası '1025.jpg' olarak değiştirildi.
# '719429c2-109.jpeg' dosyası '1026.jpeg' olarak değiştirildi.
# '71f16ae8-1756_jpg.rf.54428ce468bcc7229771ae36ba8c69be.jpg' dosyası '1027.jpg' olarak değiştirildi.
# '732e1f65-86.jpeg' dosyası '1028.jpeg' olarak değiştirildi.
# '737a47c0-0064.jpg' dosyası '1029.jpg' olarak değiştirildi.
# '74af603e-115.jpeg' dosyası '1030.jpeg' olarak değiştirildi.
# '76995547-76.jpeg' dosyası '1031.jpeg' olarak değiştirildi.
# '77503bf2-0236.jpg' dosyası '1032.jpg' olarak değiştirildi.
# '777d68f1-0091.jpg' dosyası '1033.jpg' olarak değiştirildi.
# '7802ab2a-1_46.jpg' dosyası '1034.jpg' olarak değiştirildi.
# '782651d3-1615_jpg.rf.cff344e4990cfd17ad88510aebcf854c.jpg' dosyası '1035.jpg' olarak değiştirildi.
# '7839c15e-0221.jpg' dosyası '1036.jpg' olarak değiştirildi.
# '7890b6b7-0234.jpg' dosyası '1037.jpg' olarak değiştirildi.
# '78f02b89-1677_jpg.rf.9e4eb3a6fe967ede7e97f250ba3f5bbc.jpg' dosyası '1038.jpg' olarak değiştirildi.
# '791375df-1_14.jpg' dosyası '1039.jpg' olarak değiştirildi.
# '79278cbe-79.jpeg' dosyası '1040.jpeg' olarak değiştirildi.
# '794d7d9f-0085.jpg' dosyası '1041.jpg' olarak değiştirildi.
# '7a0ab92b-77.jpeg' dosyası '1042.jpeg' olarak değiştirildi.
# '7b81089b-104.jpeg' dosyası '1043.jpeg' olarak değiştirildi.
# '7c10c980-1744_jpg.rf.647bdba2f100a85975c9f786348240a3.jpg' dosyası '1044.jpg' olarak değiştirildi.
# '7c833491-97.jpeg' dosyası '1045.jpeg' olarak değiştirildi.
# '7c93e453-1618_PNG.rf.10f7986858962a2856c8aa7a94a71931.jpg' dosyası '1046.jpg' olarak değiştirildi.
# '7ca80f8f-0008.jpg' dosyası '1047.jpg' olarak değiştirildi.
# '7ce843a8-95.jpeg' dosyası '1048.jpeg' olarak değiştirildi.
# '7d011c4a-1603_PNG.rf.6d166768eb36c4b1316c825de79f41df.jpg' dosyası '1049.jpg' olarak değiştirildi.
# '7ecc6207-1_11.jpg' dosyası '1050.jpg' olarak değiştirildi.
# '7ee727b2-0044.jpg' dosyası '1051.jpg' olarak değiştirildi.
# '80389cd3-1696_PNG.rf.b472fc8695d2ab88dd094063d9b24a56.jpg' dosyası '1052.jpg' olarak değiştirildi.
# '803d03ae-1775_jpg.rf.43cdd8244e8caf22e38e5749c9a9d75e.jpg' dosyası '1053.jpg' olarak değiştirildi.
# '805e7b0e-29.jpeg' dosyası '1054.jpeg' olarak değiştirildi.
# '81928856-1781_jpg.rf.7566fa8793b388dfde462ec3bf2d17d8.jpg' dosyası '1055.jpg' olarak değiştirildi.
# '81b2dc95-1713_PNG.rf.8090c7f14ff4b2a08c690f41f6997393.jpg' dosyası '1056.jpg' olarak değiştirildi.
# '81e98155-0224.jpg' dosyası '1057.jpg' olarak değiştirildi.
# '81ee5b03-1607_PNG.rf.d4019e916a08cac70af3e5764e98c8c4.jpg' dosyası '1058.jpg' olarak değiştirildi.
# '8221dab8-1647_jpg.rf.82a8738ed5830f38a07a4280dc2c0243.jpg' dosyası '1059.jpg' olarak değiştirildi.
# '8307a192-1792_jpg.rf.3f9ea897ca3b73a0f7f9533606cb3a2c.jpg' dosyası '1060.jpg' olarak değiştirildi.
# '838742be-0090.jpg' dosyası '1061.jpg' olarak değiştirildi.
# '83aa7d4c-63.jpeg' dosyası '1062.jpeg' olarak değiştirildi.
# '84e4e25b-1764_jpg.rf.114f23651be64b7022449a110efad6e3.jpg' dosyası '1063.jpg' olarak değiştirildi.
# '855608cf-0069.jpg' dosyası '1064.jpg' olarak değiştirildi.
# '86198463-1661_PNG.rf.23a3dd11ce45b233cedc3ac5997e6353.jpg' dosyası '1065.jpg' olarak değiştirildi.
# '8644a21b-0220.jpg' dosyası '1066.jpg' olarak değiştirildi.
# '8680c82c-0226.jpg' dosyası '1067.jpg' olarak değiştirildi.
# '87421135-0081.jpg' dosyası '1068.jpg' olarak değiştirildi.
# '87abf076-1646_jpg.rf.82731b21b4771fdb3592e736be73b1cb.jpg' dosyası '1069.jpg' olarak değiştirildi.
# '88d06ba0-0040.jpg' dosyası '1070.jpg' olarak değiştirildi.
# '89408786-1670_PNG.rf.030aa3a65e8d64e3d96ac5df7497be40.jpg' dosyası '1071.jpg' olarak değiştirildi.
# '89fd03ac-1746_PNG.rf.3489407de06c2a8fbcf9632c42b257ab.jpg' dosyası '1072.jpg' olarak değiştirildi.
# '8a3d7f5d-0230.jpg' dosyası '1073.jpg' olarak değiştirildi.
# '8a7097fe-1_23.jpg' dosyası '1074.jpg' olarak değiştirildi.
# '8ac03289-36.jpeg' dosyası '1075.jpeg' olarak değiştirildi.
# '8b050446-1702_PNG.rf.54f3d5e39a79b1a581827373d8b450a5.jpg' dosyası '1076.jpg' olarak değiştirildi.
# '8ebeebe5-44.jpeg' dosyası '1077.jpeg' olarak değiştirildi.
# '8ef74800-1669_PNG.rf.7e91984f73a9611d0d448e594d8d1d6b.jpg' dosyası '1078.jpg' olarak değiştirildi.
# '8f8faa40-0088.jpg' dosyası '1079.jpg' olarak değiştirildi.
# '90150186-111.jpeg' dosyası '1080.jpeg' olarak değiştirildi.
# '903859c2-1686_PNG.rf.84d6f3a92daff2a89006077572b20254.jpg' dosyası '1081.jpg' olarak değiştirildi.
# '9082763f-1_27.jpg' dosyası '1082.jpg' olarak değiştirildi.
# '909495be-1761_jpg.rf.a11ab1efa0fbecfa5f4fee36de37200e.jpg' dosyası '1083.jpg' olarak değiştirildi.
# '920e0485-1627_jpg.rf.12f3ea3462dcc7bcc2c9508c74efcff2.jpg' dosyası '1084.jpg' olarak değiştirildi.
# '92673a9d-1799_jpg.rf.cecdfc4d5afe05133a94e055a88e88e3.jpg' dosyası '1085.jpg' olarak değiştirildi.
# '93b34211-26.jpeg' dosyası '1086.jpeg' olarak değiştirildi.
# '943070ce-0238.jpg' dosyası '1087.jpg' olarak değiştirildi.
# '94589274-7.jpeg' dosyası '1088.jpeg' olarak değiştirildi.
# '949f393a-1_7.jpg' dosyası '1089.jpg' olarak değiştirildi.
# '94df85f7-1623_jpg.rf.bca18d31cb1b9bca228b0e1ca45c05f3.jpg' dosyası '1090.jpg' olarak değiştirildi.
# '94f02707-1_29.jpg' dosyası '1091.jpg' olarak değiştirildi.
# '9539b4a5-1690_PNG.rf.fc24b50b8be4ba35ef1bbf55a8ab33a0.jpg' dosyası '1092.jpg' olarak değiştirildi.
# '95b6b888-1736_PNG.rf.e9111aef2b6e261ede550407bbcf7137.jpg' dosyası '1093.jpg' olarak değiştirildi.
# '96407bd1-42.jpeg' dosyası '1094.jpeg' olarak değiştirildi.
# '9710649e-1683_PNG.rf.2d59d3265d22c1d97e338e79862b7c47.jpg' dosyası '1095.jpg' olarak değiştirildi.
# '9748d1ae-0083.jpg' dosyası '1096.jpg' olarak değiştirildi.
# '97cd29b2-0072.jpg' dosyası '1097.jpg' olarak değiştirildi.
# '97d8c3f2-51.jpeg' dosyası '1098.jpeg' olarak değiştirildi.
# '97f3a32e-68.jpeg' dosyası '1099.jpeg' olarak değiştirildi.
# '98167d6f-32.jpeg' dosyası '1100.jpeg' olarak değiştirildi.
# '99053d60-1_2.jpg' dosyası '1101.jpg' olarak değiştirildi.
# '99963d7f-0093.jpg' dosyası '1102.jpg' olarak değiştirildi.
# '9a1dab73-67.jpeg' dosyası '1103.jpeg' olarak değiştirildi.
# '9a43428b-100.jpeg' dosyası '1104.jpeg' olarak değiştirildi.
# '9aaf32ea-1703_PNG.rf.18d30225b234fd56acdee9eb74cf1316.jpg' dosyası '1105.jpg' olarak değiştirildi.
# '9ae67235-84.jpeg' dosyası '1106.jpeg' olarak değiştirildi.
# '9bf9f126-1658_PNG.rf.04a4b616055e74857ea642a1e79dd1f7.jpg' dosyası '1107.jpg' olarak değiştirildi.
# '9c13e582-1743_PNG.rf.824d8986d5a288b871ef2d9794fa243d.jpg' dosyası '1108.jpg' olarak değiştirildi.
# '9c9ded32-1_25.jpg' dosyası '1109.jpg' olarak değiştirildi.
# '9db7f854-1737_jpg.rf.c97afea9839adf066d66879dba1ba4b5.jpg' dosyası '1110.jpg' olarak değiştirildi.
# '9f03aaf1-0217.jpg' dosyası '1111.jpg' olarak değiştirildi.
# 'a01412df-1787_jpg.rf.cf706b3fccb03407de68d104809844d4.jpg' dosyası '1112.jpg' olarak değiştirildi.
# 'a0f4772c-0084.jpg' dosyası '1113.jpg' olarak değiştirildi.
# 'a12ddbe3-98.jpeg' dosyası '1114.jpeg' olarak değiştirildi.
# 'a142abaf-75.jpeg' dosyası '1115.jpeg' olarak değiştirildi.
# 'a29f462b-1654_jpg.rf.4113dd7d7a4f4140d5e878a586079707.jpg' dosyası '1116.jpg' olarak değiştirildi.
# 'a2ba7fbd-83.jpeg' dosyası '1117.jpeg' olarak değiştirildi.
# 'a356d54d-0050.jpg' dosyası '1118.jpg' olarak değiştirildi.
# 'a3b6985c-0218.jpg' dosyası '1119.jpg' olarak değiştirildi.
# 'a4437b94-0059.jpg' dosyası '1120.jpg' olarak değiştirildi.
# 'a4a21ae0-72.jpeg' dosyası '1121.jpeg' olarak değiştirildi.
# 'a5edd06c-1719_PNG.rf.a35dd12a163a3b22202401546bbabe64.jpg' dosyası '1122.jpg' olarak değiştirildi.
# 'a60bdaf4-0054.jpg' dosyası '1123.jpg' olarak değiştirildi.
# 'a70c2a64-1612_jpg.rf.db9803ce956db0c3a202d30ac15d868c.jpg' dosyası '1124.jpg' olarak değiştirildi.
# 'a74c3e78-0231.jpg' dosyası '1125.jpg' olarak değiştirildi.
# 'a7b60e87-1_20.jpg' dosyası '1126.jpg' olarak değiştirildi.
# 'a96b80b9-1_41.jpg' dosyası '1127.jpg' olarak değiştirildi.
# 'a9ac4738-1770_jpg.rf.74e197c75231d33c2eed4329f56aa591.jpg' dosyası '1128.jpg' olarak değiştirildi.
# 'a9bbf681-1_13.jpg' dosyası '1129.jpg' olarak değiştirildi.
# 'aa3bdf98-1_24.jpg' dosyası '1130.jpg' olarak değiştirildi.
# 'aa76fbad-1_3.jpg' dosyası '1131.jpg' olarak değiştirildi.
# 'aa96a935-1_15.jpg' dosyası '1132.jpg' olarak değiştirildi.
# 'aab5d11c-1653_jpg.rf.8c8b1ea54bcaf07ad23a6fc49bf378a2.jpg' dosyası '1133.jpg' olarak değiştirildi.
# 'aadccee2-85.jpeg' dosyası '1134.jpeg' olarak değiştirildi.
# 'ab5f0a45-38.jpeg' dosyası '1135.jpeg' olarak değiştirildi.
# 'abc004de-21.jpeg' dosyası '1136.jpeg' olarak değiştirildi.
# 'abea5a1b-0024.jpg' dosyası '1137.jpg' olarak değiştirildi.
# 'abf05682-66.jpeg' dosyası '1138.jpeg' olarak değiştirildi.
# 'ac10d7c3-1767_jpg.rf.2c7f2ac953882c3d16d2bafeae8a8717.jpg' dosyası '1139.jpg' olarak değiştirildi.
# 'ad43c3fb-1657_PNG.rf.81fa0c68dd47d716d2c00ff48054bfd2.jpg' dosyası '1140.jpg' olarak değiştirildi.
# 'af266214-1673_jpg.rf.8a9fd1dfea1062b300f42077e25d4493.jpg' dosyası '1141.jpg' olarak değiştirildi.
# 'af716351-1_33.jpg' dosyası '1142.jpg' olarak değiştirildi.
# 'af892c4f-82.jpeg' dosyası '1143.jpeg' olarak değiştirildi.
# 'afb84d8e-1733_PNG.rf.7514d7665fb47369cdb484e4e2f9e23a.jpg' dosyası '1144.jpg' olarak değiştirildi.
# 'b145c1fc-0213.jpg' dosyası '1145.jpg' olarak değiştirildi.
# 'b256906a-1_21.jpg' dosyası '1146.jpg' olarak değiştirildi.
# 'b28c1191-1759_jpg.rf.c11a51a5e1717867e12bd7fe354d5171.jpg' dosyası '1147.jpg' olarak değiştirildi.
# 'b2f0bbb8-1708_PNG.rf.c0a6aaa77116520cb3fbc45d03d2c1c3.jpg' dosyası '1148.jpg' olarak değiştirildi.
# 'b32ad4bf-101.jpeg' dosyası '1149.jpeg' olarak değiştirildi.
# 'b3b57887-1_34.jpg' dosyası '1150.jpg' olarak değiştirildi.
# 'b45b35b5-0034.jpg' dosyası '1151.jpg' olarak değiştirildi.
# 'b49121ca-1681_PNG.rf.3f20b7d1c96c7cbe0fb51dae645325f1.jpg' dosyası '1152.jpg' olarak değiştirildi.
# 'b4f5849c-1662_PNG.rf.67682d2b339b7fee82dd3c28818886f8.jpg' dosyası '1153.jpg' olarak değiştirildi.
# 'b533df79-0028.jpg' dosyası '1154.jpg' olarak değiştirildi.
# 'b62fbffa-1_22.jpg' dosyası '1155.jpg' olarak değiştirildi.
# 'b720d066-34.jpeg' dosyası '1156.jpeg' olarak değiştirildi.
# 'b78e7299-1629_jpg.rf.466d8c46b45580f5b41679e285aa631e.jpg' dosyası '1157.jpg' olarak değiştirildi.
# 'b7f9e362-1741_PNG.rf.fb85a79ffa9ad2116cc54de893655140.jpg' dosyası '1158.jpg' olarak değiştirildi.
# 'b839b376-55.jpeg' dosyası '1159.jpeg' olarak değiştirildi.
# 'b8d4140b-1620_PNG.rf.c8135c08d7fc7556635622edb312111d.jpg' dosyası '1160.jpg' olarak değiştirildi.
# 'b8ef4543-0042.jpg' dosyası '1161.jpg' olarak değiştirildi.
# 'b93f4047-54.jpeg' dosyası '1162.jpeg' olarak değiştirildi.
# 'b96d0dc4-107.jpeg' dosyası '1163.jpeg' olarak değiştirildi.
# 'b9d22e87-35.jpeg' dosyası '1164.jpeg' olarak değiştirildi.
# 'ba595c96-81.jpeg' dosyası '1165.jpeg' olarak değiştirildi.
# 'bab4441f-1644_PNG.rf.b37c19a29ff3839987ba9b07635ee7de.jpg' dosyası '1166.jpg' olarak değiştirildi.
# 'bb21eb31-1728_PNG.rf.995f7204141083d315a40d46c90cb88a.jpg' dosyası '1167.jpg' olarak değiştirildi.
# 'bb32bcaf-0063.jpg' dosyası '1168.jpg' olarak değiştirildi.
# 'bda32f55-1676_jpg.rf.1c4ef760e03984b95fceccafb558149a.jpg' dosyası '1169.jpg' olarak değiştirildi.
# 'bfeb10b0-2.jpeg' dosyası '1170.jpeg' olarak değiştirildi.
# 'c1521c77-0073.jpg' dosyası '1171.jpg' olarak değiştirildi.
# 'c221f5a4-1721_PNG.rf.c0d9ba50a0fa4b4184435e63515ac7d0.jpg' dosyası '1172.jpg' olarak değiştirildi.
# 'c265d051-0029.jpg' dosyası '1173.jpg' olarak değiştirildi.
# 'c3c6def7-1718_jpg.rf.61431c72a4e9ad50e29a7239a20eb35d.jpg' dosyası '1174.jpg' olarak değiştirildi.
# 'c462f393-1762_jpg.rf.f27eaa7e6fceed5da298124913a70a7e.jpg' dosyası '1175.jpg' olarak değiştirildi.
# 'c47f8da8-0079.jpg' dosyası '1176.jpg' olarak değiştirildi.
# 'c546bafc-1706_PNG.rf.36831c2b410c906b8d47594dddd6f5af.jpg' dosyası '1177.jpg' olarak değiştirildi.
# 'c5fe9820-1_44.jpg' dosyası '1178.jpg' olarak değiştirildi.
# 'c6aaa8a2-1694_jpg.rf.ed6dc5e01fd7c98aa999a58916748a09.jpg' dosyası '1179.jpg' olarak değiştirildi.
# 'c721a9ed-3.jpeg' dosyası '1180.jpeg' olarak değiştirildi.
# 'c7a74425-87.jpeg' dosyası '1181.jpeg' olarak değiştirildi.
# 'c7f8628a-1720_jpg.rf.16d408948cf6119d5a4756c8bccd41b7.jpg' dosyası '1182.jpg' olarak değiştirildi.
# 'c8211eb9-41.jpeg' dosyası '1183.jpeg' olarak değiştirildi.
# 'c9188ba4-20.jpeg' dosyası '1184.jpeg' olarak değiştirildi.
# 'c9540f1b-0222.jpg' dosyası '1185.jpg' olarak değiştirildi.
# 'cafc08b6-1793_jpg.rf.d3f40cdf81e882b2d5f728a2d8a1116e.jpg' dosyası '1186.jpg' olarak değiştirildi.
# 'cc20ecce-105.jpeg' dosyası '1187.jpeg' olarak değiştirildi.
# 'cd44812a-57.jpeg' dosyası '1188.jpeg' olarak değiştirildi.
# 'cd4a4aeb-1675_jpg.rf.e01028657d3096eec2b2de21149b3d66.jpg' dosyası '1189.jpg' olarak değiştirildi.
# 'cf444842-1754_jpg.rf.e81151bda74098dbd185717b9895327c.jpg' dosyası '1190.jpg' olarak değiştirildi.
# 'cfb91fb1-0033.jpg' dosyası '1191.jpg' olarak değiştirildi.
# 'd03bd268-60.jpeg' dosyası '1192.jpeg' olarak değiştirildi.
# 'd05f3296-1659_jpg.rf.8d7bb2e6cfdcc0e159f0b474d736cd23.jpg' dosyası '1193.jpg' olarak değiştirildi.
# 'd0742092-1622_PNG.rf.e36fec1f97a252f70d588f68afe30348.jpg' dosyası '1194.jpg' olarak değiştirildi.
# 'd0995fae-80.jpeg' dosyası '1195.jpeg' olarak değiştirildi.
# 'd21e6439-1_50.jpg' dosyası '1196.jpg' olarak değiştirildi.
# 'd2ee9016-1772_jpg.rf.4bd8bed20b8bd1ad01c92fb1a4754188.jpg' dosyası '1197.jpg' olarak değiştirildi.
# 'd2fc6a50-1785_jpg.rf.2d90f49b241b0b35743780d3005757f3.jpg' dosyası '1198.jpg' olarak değiştirildi.
# 'd3ef9536-90.jpeg' dosyası '1199.jpeg' olarak değiştirildi.
# 'd3f28551-0006.jpg' dosyası '1200.jpg' olarak değiştirildi.
# 'd8f834e7-0046.jpg' dosyası '1201.jpg' olarak değiştirildi.
# 'd9567c05-1777_jpg.rf.c66c9ebc785b4da31e26ea4c4e4a62a1.jpg' dosyası '1202.jpg' olarak değiştirildi.
# 'dab1a68a-58.jpeg' dosyası '1203.jpeg' olarak değiştirildi.
# 'dc678330-1716_PNG.rf.cfbf2315987a71caf669148f9a7c49c8.jpg' dosyası '1204.jpg' olarak değiştirildi.
# 'dc95075d-0227.jpg' dosyası '1205.jpg' olarak değiştirildi.
# 'ddc29556-14.jpeg' dosyası '1206.jpeg' olarak değiştirildi.
# 'dddb4611-1619_PNG.rf.68121fa178da57a3fd9cda380e621e7f.jpg' dosyası '1207.jpg' olarak değiştirildi.
# 'de87817d-102.jpeg' dosyası '1208.jpeg' olarak değiştirildi.
# 'df0754a1-1_38.jpg' dosyası '1209.jpg' olarak değiştirildi.
# 'df375901-1798_jpg.rf.9a493318f212c6c98f4a3f05a13eea76.jpg' dosyası '1210.jpg' olarak değiştirildi.
# 'e081c843-1680_PNG.rf.595af6bbc3bb467115095dad4bfbd882.jpg' dosyası '1211.jpg' olarak değiştirildi.
# 'e0f36324-0092.jpg' dosyası '1212.jpg' olarak değiştirildi.
# 'e17759a4-1707_PNG.rf.5b7aedaf6c782601d5c84f9f9c424f0c.jpg' dosyası '1213.jpg' olarak değiştirildi.
# 'e1d24eab-1_30.jpg' dosyası '1214.jpg' olarak değiştirildi.
# 'e38e7016-46.jpeg' dosyası '1215.jpeg' olarak değiştirildi.
# 'e4a2b888-8.jpeg' dosyası '1216.jpeg' olarak değiştirildi.
# 'e5b0c2ed-62.jpeg' dosyası '1217.jpeg' olarak değiştirildi.
# 'e6982b76-1666_jpg.rf.e68005fe22293d8ed65be81b5b55284d.jpg' dosyası '1218.jpg' olarak değiştirildi.
# 'e70d1094-0087.jpg' dosyası '1219.jpg' olarak değiştirildi.
# 'e7127bc8-1_32.jpg' dosyası '1220.jpg' olarak değiştirildi.
# 'e73e7e75-1639_jpg.rf.b4eac3ce5250218c0d71ec912d61d963.jpg' dosyası '1221.jpg' olarak değiştirildi.
# 'e92b2b29-24.jpeg' dosyası '1222.jpeg' olarak değiştirildi.
# 'e94cb7b6-1617_jpg.rf.ffd5a7b7438d823a2343a12dada12089.jpg' dosyası '1223.jpg' olarak değiştirildi.
# 'e9d316ee-1_26.jpg' dosyası '1224.jpg' olarak değiştirildi.
# 'e9e29f7a-1757_jpg.rf.0350296277c5e74975cb293635e7b5dc.jpg' dosyası '1225.jpg' olarak değiştirildi.
# 'eb00d7b8-1727_jpg.rf.ad46560655772135795a2e4222114f09.jpg' dosyası '1226.jpg' olarak değiştirildi.
# 'ebcbf784-96.jpeg' dosyası '1227.jpeg' olarak değiştirildi.
# 'ec797a9c-6.jpeg' dosyası '1228.jpeg' olarak değiştirildi.
# 'eca6a23e-0070.jpg' dosyası '1229.jpg' olarak değiştirildi.
# 'ed90f69c-0080.jpg' dosyası '1230.jpg' olarak değiştirildi.
# 'edfda87b-0009.jpg' dosyası '1231.jpg' olarak değiştirildi.
# 'eec1b9d0-1752_jpg.rf.da77149bb6e9ba4f77b32966f7ebcad9.jpg' dosyası '1232.jpg' olarak değiştirildi.
# 'ef74cb90-1722_PNG.rf.ec0f20690e2589ea7c280eb51e5f1d26.jpg' dosyası '1233.jpg' olarak değiştirildi.
# 'f351df95-69.jpeg' dosyası '1234.jpeg' olarak değiştirildi.
# 'f4911c6a-1751_jpg.rf.d9e04a1de46a4a8b41783115c3cc9287.jpg' dosyası '1235.jpg' olarak değiştirildi.
# 'f4cae116-1667_PNG.rf.ecd602065f602d50f1ec516562c2965b.jpg' dosyası '1236.jpg' olarak değiştirildi.
# 'f4ec2535-1614_PNG.rf.75684e57f15200631b982e4b8c2c3c0a.jpg' dosyası '1237.jpg' olarak değiştirildi.
# 'f5640b71-1609_jpg.rf.0948d1a01e1a2f3b2bee3b24df4eb1c4.jpg' dosyası '1238.jpg' olarak değiştirildi.
# 'f5be5af7-0082.jpg' dosyası '1239.jpg' olarak değiştirildi.
# 'f6727d0c-1739_jpg.rf.bcde1e5fe8247bf993bb8884a93255ae.jpg' dosyası '1240.jpg' olarak değiştirildi.
# 'f6f65f7a-1_43.jpg' dosyası '1241.jpg' olarak değiştirildi.
# 'f70d040e-1611_PNG.rf.60c1f6ab00a0c01c086bb26321984b09.jpg' dosyası '1242.jpg' olarak değiştirildi.
# 'f72a7067-1715_jpg.rf.e4bac7da8a02b72bc21c762435c65426.jpg' dosyası '1243.jpg' olarak değiştirildi.
# 'f793f894-0005.jpg' dosyası '1244.jpg' olarak değiştirildi.
# 'f9207dd2-0037.jpg' dosyası '1245.jpg' olarak değiştirildi.
# 'f95acc38-0052.jpg' dosyası '1246.jpg' olarak değiştirildi.
# 'fa654e5c-0086.jpg' dosyası '1247.jpg' olarak değiştirildi.
# 'fab5c405-112.jpeg' dosyası '1248.jpeg' olarak değiştirildi.
# 'fafdd005-1656_PNG.rf.121cc7aacdda6227ead175776ac86d8b.jpg' dosyası '1249.jpg' olarak değiştirildi.
# 'fd1ad646-1_1.jpg' dosyası '1250.jpg' olarak değiştirildi.
# 'fd948ebb-19.jpeg' dosyası '1251.jpeg' olarak değiştirildi.
# Dosya isimlendirme işlemi tamamlandı.
